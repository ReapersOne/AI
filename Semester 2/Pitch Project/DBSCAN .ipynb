# %%
import pandas as pd
import numpy as np
import seaborn as sns
import json
from bs4 import BeautifulSoup
import requests
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tracks_features.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204025 entries, 0 to 1204024
# Data columns (total 24 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   id                1204025 non-null  object
#  1   name              1204025 non-null  object
#  2   album             1204025 non-null  object
#  3   album_id          1204025 non-null  object
#  4   artists           1204025 non-null  object
#  5   artist_ids        1204025 non-null  object
#  6   track_number      1204025 non-null  int64
#  7   disc_number       1204025 non-null  int64
#  8   explicit          1204025 non-null  bool
#  9   danceability      1204025 non-null  float64
#  10  energy            1204025 non-null  float64
#  11  key               1204025 non-null  int64
#  12  loudness          1204025 non-null  float64
#  13  mode              1204025 non-null  int64
#  14  speechiness       1204025 non-null  float64
#  15  acousticness      1204025 non-null  float64
#  16  instrumentalness  1204025 non-null  float64
#  17  liveness          1204025 non-null  float64
#  18  valence           1204025 non-null  float64
#  19  tempo             1204025 non-null  float64
#  20  duration_ms       1204025 non-null  int64
#  21  time_signature    1204025 non-null  float64
#  22  year              1204025 non-null  int64
#  23  release_date      1204025 non-null  object
# dtypes: bool(1), float64(10), int64(6), object(7)
# memory usage: 212.4+ MB

# %%
track_counts = df.groupby(['id', 'name', 'artists']).size().reset_index(name='count')

min_count = track_counts['count'].min()
max_count = track_counts['count'].max()
track_counts['popularity_score'] = (
    ((track_counts['count'] - min_count) / (max_count - min_count) * 9 + 1
).astype(int))

df_with_popularity = df.merge(
    track_counts[['id', 'popularity_score']],
    on='id',
    how='left'
)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30332\4092747566.py in <module>
#       4 max_count = track_counts['count'].max()
#       5 track_counts['popularity_score'] = (
# ----> 6     ((track_counts['count'] - min_count) / (max_count - min_count) * 9 + 1
#       7 ).astype(int))
#       8
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
#     421     def convert(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     578         values = self.values
#     579
# --> 580         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     581
#     582         new_values = maybe_coerce_values(new_values)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1290
#    1291     try:
# -> 1292         new_values = astype_array(values, dtype, copy=copy)
#    1293     except (ValueError, TypeError):
#    1294         # e.g. astype_nansafe can fail on object-dtype of strings
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1235
#    1236     else:
# -> 1237         values = astype_nansafe(values, dtype, copy=copy)
#    1238
#    1239     # in pandas we don't store numpy str dtypes, so convert to object
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1146
#    1147     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1148         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1149
#    1150     elif is_object_dtype(arr.dtype):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1191     """
#    1192     if not np.isfinite(values).all():
# -> 1193         raise IntCastingNaNError(
#    1194             "Cannot convert non-finite values (NA or inf) to integer"
#    1195         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
df_first_1000 = df.head(1000)

# %%
X = df_first_1000[['tempo', 'danceability']]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

eps = 0.7
min_samples = 100

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan.fit(X_scaled)

df_first_1000['cluster'] = dbscan.labels_

print(df_first_1000.head())

n_clusters = len(set(dbscan.labels_)) - (1 if -1 in dbscan.labels_ else 0)
n_noise = list(dbscan.labels_).count(-1)

print(f"Number of clusters: {n_clusters}")
print(f"Number of noise points: {n_noise}")

print(df_first_1000['cluster'].value_counts())
# Out:
#                        id                   name                      album  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify  The Battle Of Los Angeles
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio  The Battle Of Los Angeles
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb  The Battle Of Los Angeles
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check  The Battle Of Los Angeles
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire  The Battle Of Los Angeles
#
#                  album_id                       artists  \
# 0  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 1  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 2  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 3  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
# 4  2eia0myWFgoHuttJytCxgX  ['Rage Against The Machine']
#
#                    artist_ids  track_number  disc_number  explicit  \
# 0  ['2d0hyoQ5ynDBnkvAbJKORj']             1            1     False
# 1  ['2d0hyoQ5ynDBnkvAbJKORj']             2            1      True
# 2  ['2d0hyoQ5ynDBnkvAbJKORj']             3            1     False
# 3  ['2d0hyoQ5ynDBnkvAbJKORj']             4            1      True
# 4  ['2d0hyoQ5ynDBnkvAbJKORj']             5            1     False
#
#    danceability  ...  acousticness  instrumentalness  liveness  valence  \
# 0         0.470  ...       0.02610          0.000011    0.3560    0.503
# 1         0.599  ...       0.01290          0.000071    0.1550    0.489
# 2         0.315  ...       0.02340          0.000002    0.1220    0.370
# 3         0.440  ...       0.16300          0.000004    0.1210    0.574
# 4         0.426  ...       0.00162          0.105000    0.0789    0.539
#
#      tempo  duration_ms  time_signature  year  release_date  cluster
# 0  117.906       210133             4.0  1999    1999-11-02        0
# 1  103.680       206200             4.0  1999    1999-11-02        0
# 2  149.749       298893             4.0  1999    1999-11-02        0
# 3   96.752       213640             4.0  1999    1999-11-02        0
# 4  127.059       205600             4.0  1999    1999-11-02        0
#
# [5 rows x 25 columns]
# Number of clusters: 1
# Number of noise points: 126
#  0    874
# -1    126
# Name: cluster, dtype: int64
# C:\Users\wreep\AppData\Local\Temp\ipykernel_30332\3736875716.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_first_1000['cluster'] = dbscan.labels_

# %%
features = ['tempo', 'danceability']
X = df_first_1000[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

best_score = -1
best_params = {'eps': None, 'min_samples': None}

for eps in np.arange(0.1, 1.1, 0.1):  
    for min_samples in range(1, 101):  
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        labels = dbscan.fit_predict(X_scaled)
        
        if len(np.unique(labels)) > 1:  
            score = silhouette_score(X_scaled, labels)
            print(f"eps={eps:.1f}, min_samples={min_samples}, Silhouette Score={score:.3f}")

            if score > best_score:
                best_score = score
                best_params['eps'] = eps
                best_params['min_samples'] = min_samples
        else:
            print(f"eps={eps:.1f}, min_samples={min_samples}, No valid clusters found.")

print("\nBest Parameters:")
print(f"eps={best_params['eps']}, min_samples={best_params['min_samples']}, Best Silhouette Score={best_score:.3f}")

final_dbscan = DBSCAN(eps=best_params['eps'], min_samples=best_params['min_samples'])
df['cluster'] = final_dbscan.fit_predict(X_scaled)

print("\nCluster Distribution:")
print(df['cluster'].value_counts())
# Out:
# eps=0.1, min_samples=1, Silhouette Score=-0.094
# eps=0.1, min_samples=2, Silhouette Score=-0.125
# eps=0.1, min_samples=3, Silhouette Score=-0.184
# eps=0.1, min_samples=4, Silhouette Score=-0.248
# eps=0.1, min_samples=5, Silhouette Score=-0.243
# eps=0.1, min_samples=6, Silhouette Score=-0.310
# eps=0.1, min_samples=7, Silhouette Score=-0.386
# eps=0.1, min_samples=8, Silhouette Score=-0.450
# eps=0.1, min_samples=9, Silhouette Score=-0.458
# eps=0.1, min_samples=10, Silhouette Score=-0.434
# eps=0.1, min_samples=11, No valid clusters found.
# eps=0.1, min_samples=12, No valid clusters found.
# eps=0.1, min_samples=13, No valid clusters found.
# eps=0.1, min_samples=14, No valid clusters found.
# eps=0.1, min_samples=15, No valid clusters found.
# eps=0.1, min_samples=16, No valid clusters found.
# eps=0.1, min_samples=17, No valid clusters found.
# eps=0.1, min_samples=18, No valid clusters found.
# eps=0.1, min_samples=19, No valid clusters found.
# eps=0.1, min_samples=20, No valid clusters found.
# eps=0.1, min_samples=21, No valid clusters found.
# eps=0.1, min_samples=22, No valid clusters found.
# eps=0.1, min_samples=23, No valid clusters found.
# eps=0.1, min_samples=24, No valid clusters found.
# eps=0.1, min_samples=25, No valid clusters found.
# eps=0.1, min_samples=26, No valid clusters found.
# eps=0.1, min_samples=27, No valid clusters found.
# eps=0.1, min_samples=28, No valid clusters found.
# eps=0.1, min_samples=29, No valid clusters found.
# eps=0.1, min_samples=30, No valid clusters found.
# eps=0.1, min_samples=31, No valid clusters found.
# eps=0.1, min_samples=32, No valid clusters found.
# eps=0.1, min_samples=33, No valid clusters found.
# eps=0.1, min_samples=34, No valid clusters found.
# eps=0.1, min_samples=35, No valid clusters found.
# eps=0.1, min_samples=36, No valid clusters found.
# eps=0.1, min_samples=37, No valid clusters found.
# eps=0.1, min_samples=38, No valid clusters found.
# eps=0.1, min_samples=39, No valid clusters found.
# eps=0.1, min_samples=40, No valid clusters found.
# eps=0.1, min_samples=41, No valid clusters found.
# eps=0.1, min_samples=42, No valid clusters found.
# eps=0.1, min_samples=43, No valid clusters found.
# eps=0.1, min_samples=44, No valid clusters found.
# eps=0.1, min_samples=45, No valid clusters found.
# eps=0.1, min_samples=46, No valid clusters found.
# eps=0.1, min_samples=47, No valid clusters found.
# eps=0.1, min_samples=48, No valid clusters found.
# eps=0.1, min_samples=49, No valid clusters found.
# eps=0.1, min_samples=50, No valid clusters found.
# eps=0.1, min_samples=51, No valid clusters found.
# eps=0.1, min_samples=52, No valid clusters found.
# eps=0.1, min_samples=53, No valid clusters found.
# eps=0.1, min_samples=54, No valid clusters found.
# eps=0.1, min_samples=55, No valid clusters found.
# eps=0.1, min_samples=56, No valid clusters found.
# eps=0.1, min_samples=57, No valid clusters found.
# eps=0.1, min_samples=58, No valid clusters found.
# eps=0.1, min_samples=59, No valid clusters found.
# eps=0.1, min_samples=60, No valid clusters found.
# eps=0.1, min_samples=61, No valid clusters found.
# eps=0.1, min_samples=62, No valid clusters found.
# eps=0.1, min_samples=63, No valid clusters found.
# eps=0.1, min_samples=64, No valid clusters found.
# eps=0.1, min_samples=65, No valid clusters found.
# eps=0.1, min_samples=66, No valid clusters found.
# eps=0.1, min_samples=67, No valid clusters found.
# eps=0.1, min_samples=68, No valid clusters found.
# eps=0.1, min_samples=69, No valid clusters found.
# eps=0.1, min_samples=70, No valid clusters found.
# eps=0.1, min_samples=71, No valid clusters found.
# eps=0.1, min_samples=72, No valid clusters found.
# eps=0.1, min_samples=73, No valid clusters found.
# eps=0.1, min_samples=74, No valid clusters found.
# eps=0.1, min_samples=75, No valid clusters found.
# eps=0.1, min_samples=76, No valid clusters found.
# eps=0.1, min_samples=77, No valid clusters found.
# eps=0.1, min_samples=78, No valid clusters found.
# eps=0.1, min_samples=79, No valid clusters found.
# eps=0.1, min_samples=80, No valid clusters found.
# eps=0.1, min_samples=81, No valid clusters found.
# eps=0.1, min_samples=82, No valid clusters found.
# eps=0.1, min_samples=83, No valid clusters found.
# eps=0.1, min_samples=84, No valid clusters found.
# eps=0.1, min_samples=85, No valid clusters found.
# eps=0.1, min_samples=86, No valid clusters found.
# eps=0.1, min_samples=87, No valid clusters found.
# eps=0.1, min_samples=88, No valid clusters found.
# eps=0.1, min_samples=89, No valid clusters found.
# eps=0.1, min_samples=90, No valid clusters found.
# eps=0.1, min_samples=91, No valid clusters found.
# eps=0.1, min_samples=92, No valid clusters found.
# eps=0.1, min_samples=93, No valid clusters found.
# eps=0.1, min_samples=94, No valid clusters found.
# eps=0.1, min_samples=95, No valid clusters found.
# eps=0.1, min_samples=96, No valid clusters found.
# eps=0.1, min_samples=97, No valid clusters found.
# eps=0.1, min_samples=98, No valid clusters found.
# eps=0.1, min_samples=99, No valid clusters found.
# eps=0.1, min_samples=100, No valid clusters found.
# eps=0.2, min_samples=1, Silhouette Score=-0.263
# eps=0.2, min_samples=2, Silhouette Score=-0.233
# eps=0.2, min_samples=3, Silhouette Score=-0.227
# eps=0.2, min_samples=4, Silhouette Score=-0.208
# eps=0.2, min_samples=5, Silhouette Score=-0.117
# eps=0.2, min_samples=6, Silhouette Score=-0.095
# eps=0.2, min_samples=7, Silhouette Score=0.160
# eps=0.2, min_samples=8, Silhouette Score=0.124
# eps=0.2, min_samples=9, Silhouette Score=-0.196
# eps=0.2, min_samples=10, Silhouette Score=-0.180
# eps=0.2, min_samples=11, Silhouette Score=-0.209
# eps=0.2, min_samples=12, Silhouette Score=-0.070
# eps=0.2, min_samples=13, Silhouette Score=-0.206
# eps=0.2, min_samples=14, Silhouette Score=-0.300
# eps=0.2, min_samples=15, Silhouette Score=-0.316
# eps=0.2, min_samples=16, Silhouette Score=-0.190
# eps=0.2, min_samples=17, Silhouette Score=-0.168
# eps=0.2, min_samples=18, Silhouette Score=-0.216
# eps=0.2, min_samples=19, Silhouette Score=-0.249
# eps=0.2, min_samples=20, Silhouette Score=-0.284
# eps=0.2, min_samples=21, Silhouette Score=-0.313
# eps=0.2, min_samples=22, Silhouette Score=-0.239
# eps=0.2, min_samples=23, Silhouette Score=-0.256
# eps=0.2, min_samples=24, Silhouette Score=-0.306
# eps=0.2, min_samples=25, Silhouette Score=-0.325
# eps=0.2, min_samples=26, Silhouette Score=-0.284
# eps=0.2, min_samples=27, Silhouette Score=-0.287
# eps=0.2, min_samples=28, No valid clusters found.
# eps=0.2, min_samples=29, No valid clusters found.
# eps=0.2, min_samples=30, No valid clusters found.
# eps=0.2, min_samples=31, No valid clusters found.
# eps=0.2, min_samples=32, No valid clusters found.
# eps=0.2, min_samples=33, No valid clusters found.
# eps=0.2, min_samples=34, No valid clusters found.
# eps=0.2, min_samples=35, No valid clusters found.
# eps=0.2, min_samples=36, No valid clusters found.
# eps=0.2, min_samples=37, No valid clusters found.
# eps=0.2, min_samples=38, No valid clusters found.
# eps=0.2, min_samples=39, No valid clusters found.
# eps=0.2, min_samples=40, No valid clusters found.
# eps=0.2, min_samples=41, No valid clusters found.
# eps=0.2, min_samples=42, No valid clusters found.
# eps=0.2, min_samples=43, No valid clusters found.
# eps=0.2, min_samples=44, No valid clusters found.
# eps=0.2, min_samples=45, No valid clusters found.
# eps=0.2, min_samples=46, No valid clusters found.
# eps=0.2, min_samples=47, No valid clusters found.
# eps=0.2, min_samples=48, No valid clusters found.
# eps=0.2, min_samples=49, No valid clusters found.
# eps=0.2, min_samples=50, No valid clusters found.
# eps=0.2, min_samples=51, No valid clusters found.
# eps=0.2, min_samples=52, No valid clusters found.
# eps=0.2, min_samples=53, No valid clusters found.
# eps=0.2, min_samples=54, No valid clusters found.
# eps=0.2, min_samples=55, No valid clusters found.
# eps=0.2, min_samples=56, No valid clusters found.
# eps=0.2, min_samples=57, No valid clusters found.
# eps=0.2, min_samples=58, No valid clusters found.
# eps=0.2, min_samples=59, No valid clusters found.
# eps=0.2, min_samples=60, No valid clusters found.
# eps=0.2, min_samples=61, No valid clusters found.
# eps=0.2, min_samples=62, No valid clusters found.
# eps=0.2, min_samples=63, No valid clusters found.
# eps=0.2, min_samples=64, No valid clusters found.
# eps=0.2, min_samples=65, No valid clusters found.
# eps=0.2, min_samples=66, No valid clusters found.
# eps=0.2, min_samples=67, No valid clusters found.
# eps=0.2, min_samples=68, No valid clusters found.
# eps=0.2, min_samples=69, No valid clusters found.
# eps=0.2, min_samples=70, No valid clusters found.
# eps=0.2, min_samples=71, No valid clusters found.
# eps=0.2, min_samples=72, No valid clusters found.
# eps=0.2, min_samples=73, No valid clusters found.
# eps=0.2, min_samples=74, No valid clusters found.
# eps=0.2, min_samples=75, No valid clusters found.
# eps=0.2, min_samples=76, No valid clusters found.
# eps=0.2, min_samples=77, No valid clusters found.
# eps=0.2, min_samples=78, No valid clusters found.
# eps=0.2, min_samples=79, No valid clusters found.
# eps=0.2, min_samples=80, No valid clusters found.
# eps=0.2, min_samples=81, No valid clusters found.
# eps=0.2, min_samples=82, No valid clusters found.
# eps=0.2, min_samples=83, No valid clusters found.
# eps=0.2, min_samples=84, No valid clusters found.
# eps=0.2, min_samples=85, No valid clusters found.
# eps=0.2, min_samples=86, No valid clusters found.
# eps=0.2, min_samples=87, No valid clusters found.
# eps=0.2, min_samples=88, No valid clusters found.
# eps=0.2, min_samples=89, No valid clusters found.
# eps=0.2, min_samples=90, No valid clusters found.
# eps=0.2, min_samples=91, No valid clusters found.
# eps=0.2, min_samples=92, No valid clusters found.
# eps=0.2, min_samples=93, No valid clusters found.
# eps=0.2, min_samples=94, No valid clusters found.
# eps=0.2, min_samples=95, No valid clusters found.
# eps=0.2, min_samples=96, No valid clusters found.
# eps=0.2, min_samples=97, No valid clusters found.
# eps=0.2, min_samples=98, No valid clusters found.
# eps=0.2, min_samples=99, No valid clusters found.
# eps=0.2, min_samples=100, No valid clusters found.
# eps=0.3, min_samples=1, Silhouette Score=-0.198
# eps=0.3, min_samples=2, Silhouette Score=-0.104
# eps=0.3, min_samples=3, Silhouette Score=0.055
# eps=0.3, min_samples=4, Silhouette Score=0.081
# eps=0.3, min_samples=5, Silhouette Score=0.077
# eps=0.3, min_samples=6, Silhouette Score=0.296
# eps=0.3, min_samples=7, Silhouette Score=0.382
# eps=0.3, min_samples=8, Silhouette Score=0.382
# eps=0.3, min_samples=9, Silhouette Score=0.153
# eps=0.3, min_samples=10, Silhouette Score=0.354
# eps=0.3, min_samples=11, Silhouette Score=0.153
# eps=0.3, min_samples=12, Silhouette Score=0.335
# eps=0.3, min_samples=13, Silhouette Score=0.333
# eps=0.3, min_samples=14, Silhouette Score=0.329
# eps=0.3, min_samples=15, Silhouette Score=0.202
# eps=0.3, min_samples=16, Silhouette Score=0.317
# eps=0.3, min_samples=17, Silhouette Score=0.316
# eps=0.3, min_samples=18, Silhouette Score=0.144
# eps=0.3, min_samples=19, Silhouette Score=0.308
# eps=0.3, min_samples=20, Silhouette Score=0.303
# eps=0.3, min_samples=21, Silhouette Score=0.112
# eps=0.3, min_samples=22, Silhouette Score=0.123
# eps=0.3, min_samples=23, Silhouette Score=0.293
# eps=0.3, min_samples=24, Silhouette Score=0.276
# eps=0.3, min_samples=25, Silhouette Score=0.272
# eps=0.3, min_samples=26, Silhouette Score=0.268
# eps=0.3, min_samples=27, Silhouette Score=0.243
# eps=0.3, min_samples=28, Silhouette Score=0.237
# eps=0.3, min_samples=29, Silhouette Score=0.230
# eps=0.3, min_samples=30, Silhouette Score=0.221
# eps=0.3, min_samples=31, Silhouette Score=0.200
# eps=0.3, min_samples=32, Silhouette Score=0.188
# eps=0.3, min_samples=33, Silhouette Score=0.165
# eps=0.3, min_samples=34, Silhouette Score=0.157
# eps=0.3, min_samples=35, Silhouette Score=0.145
# eps=0.3, min_samples=36, Silhouette Score=0.128
# eps=0.3, min_samples=37, Silhouette Score=0.106
# eps=0.3, min_samples=38, Silhouette Score=-0.073
# eps=0.3, min_samples=39, Silhouette Score=-0.081
# eps=0.3, min_samples=40, Silhouette Score=-0.087
# eps=0.3, min_samples=41, Silhouette Score=0.028
# eps=0.3, min_samples=42, Silhouette Score=0.021
# eps=0.3, min_samples=43, Silhouette Score=0.008
# eps=0.3, min_samples=44, Silhouette Score=-0.016
# eps=0.3, min_samples=45, Silhouette Score=-0.150
# eps=0.3, min_samples=46, Silhouette Score=-0.167
# eps=0.3, min_samples=47, Silhouette Score=-0.174
# eps=0.3, min_samples=48, Silhouette Score=-0.118
# eps=0.3, min_samples=49, Silhouette Score=-0.143
# eps=0.3, min_samples=50, Silhouette Score=-0.155
# eps=0.3, min_samples=51, Silhouette Score=-0.156
# eps=0.3, min_samples=52, Silhouette Score=-0.161
# eps=0.3, min_samples=53, Silhouette Score=-0.238
# eps=0.3, min_samples=54, Silhouette Score=-0.238
# eps=0.3, min_samples=55, No valid clusters found.
# eps=0.3, min_samples=56, No valid clusters found.
# eps=0.3, min_samples=57, No valid clusters found.
# eps=0.3, min_samples=58, No valid clusters found.
# eps=0.3, min_samples=59, No valid clusters found.
# eps=0.3, min_samples=60, No valid clusters found.
# eps=0.3, min_samples=61, No valid clusters found.
# eps=0.3, min_samples=62, No valid clusters found.
# eps=0.3, min_samples=63, No valid clusters found.
# eps=0.3, min_samples=64, No valid clusters found.
# eps=0.3, min_samples=65, No valid clusters found.
# eps=0.3, min_samples=66, No valid clusters found.
# eps=0.3, min_samples=67, No valid clusters found.
# eps=0.3, min_samples=68, No valid clusters found.
# eps=0.3, min_samples=69, No valid clusters found.
# eps=0.3, min_samples=70, No valid clusters found.
# eps=0.3, min_samples=71, No valid clusters found.
# eps=0.3, min_samples=72, No valid clusters found.
# eps=0.3, min_samples=73, No valid clusters found.
# eps=0.3, min_samples=74, No valid clusters found.
# eps=0.3, min_samples=75, No valid clusters found.
# eps=0.3, min_samples=76, No valid clusters found.
# eps=0.3, min_samples=77, No valid clusters found.
# eps=0.3, min_samples=78, No valid clusters found.
# eps=0.3, min_samples=79, No valid clusters found.
# eps=0.3, min_samples=80, No valid clusters found.
# eps=0.3, min_samples=81, No valid clusters found.
# eps=0.3, min_samples=82, No valid clusters found.
# eps=0.3, min_samples=83, No valid clusters found.
# eps=0.3, min_samples=84, No valid clusters found.
# eps=0.3, min_samples=85, No valid clusters found.
# eps=0.3, min_samples=86, No valid clusters found.
# eps=0.3, min_samples=87, No valid clusters found.
# eps=0.3, min_samples=88, No valid clusters found.
# eps=0.3, min_samples=89, No valid clusters found.
# eps=0.3, min_samples=90, No valid clusters found.
# eps=0.3, min_samples=91, No valid clusters found.
# eps=0.3, min_samples=92, No valid clusters found.
# eps=0.3, min_samples=93, No valid clusters found.
# eps=0.3, min_samples=94, No valid clusters found.
# eps=0.3, min_samples=95, No valid clusters found.
# eps=0.3, min_samples=96, No valid clusters found.
# eps=0.3, min_samples=97, No valid clusters found.
# eps=0.3, min_samples=98, No valid clusters found.
# eps=0.3, min_samples=99, No valid clusters found.
# eps=0.3, min_samples=100, No valid clusters found.
# eps=0.4, min_samples=1, Silhouette Score=0.047
# eps=0.4, min_samples=2, Silhouette Score=0.100
# eps=0.4, min_samples=3, Silhouette Score=0.194
# eps=0.4, min_samples=4, Silhouette Score=0.236
# eps=0.4, min_samples=5, Silhouette Score=0.409
# eps=0.4, min_samples=6, Silhouette Score=0.404
# eps=0.4, min_samples=7, Silhouette Score=0.404
# eps=0.4, min_samples=8, Silhouette Score=0.401
# eps=0.4, min_samples=9, Silhouette Score=0.397
# eps=0.4, min_samples=10, Silhouette Score=0.411
# eps=0.4, min_samples=11, Silhouette Score=0.411
# eps=0.4, min_samples=12, Silhouette Score=0.398
# eps=0.4, min_samples=13, Silhouette Score=0.399
# eps=0.4, min_samples=14, Silhouette Score=0.389
# eps=0.4, min_samples=15, Silhouette Score=0.374
# eps=0.4, min_samples=16, Silhouette Score=0.369
# eps=0.4, min_samples=17, Silhouette Score=0.368
# eps=0.4, min_samples=18, Silhouette Score=0.368
# eps=0.4, min_samples=19, Silhouette Score=0.364
# eps=0.4, min_samples=20, Silhouette Score=0.363
# eps=0.4, min_samples=21, Silhouette Score=0.362
# eps=0.4, min_samples=22, Silhouette Score=0.359
# eps=0.4, min_samples=23, Silhouette Score=0.359
# eps=0.4, min_samples=24, Silhouette Score=0.359
# eps=0.4, min_samples=25, Silhouette Score=0.357
# eps=0.4, min_samples=26, Silhouette Score=0.351
# eps=0.4, min_samples=27, Silhouette Score=0.346
# eps=0.4, min_samples=28, Silhouette Score=0.347
# eps=0.4, min_samples=29, Silhouette Score=0.347
# eps=0.4, min_samples=30, Silhouette Score=0.340
# eps=0.4, min_samples=31, Silhouette Score=0.337
# eps=0.4, min_samples=32, Silhouette Score=0.332
# eps=0.4, min_samples=33, Silhouette Score=0.330
# eps=0.4, min_samples=34, Silhouette Score=0.324
# eps=0.4, min_samples=35, Silhouette Score=0.316
# eps=0.4, min_samples=36, Silhouette Score=0.141
# eps=0.4, min_samples=37, Silhouette Score=0.315
# eps=0.4, min_samples=38, Silhouette Score=0.309
# eps=0.4, min_samples=39, Silhouette Score=0.305
# eps=0.4, min_samples=40, Silhouette Score=0.302
# eps=0.4, min_samples=41, Silhouette Score=0.300
# eps=0.4, min_samples=42, Silhouette Score=0.295
# eps=0.4, min_samples=43, Silhouette Score=0.295
# eps=0.4, min_samples=44, Silhouette Score=0.286
# eps=0.4, min_samples=45, Silhouette Score=0.281
# eps=0.4, min_samples=46, Silhouette Score=0.271
# eps=0.4, min_samples=47, Silhouette Score=0.270
# eps=0.4, min_samples=48, Silhouette Score=0.250
# eps=0.4, min_samples=49, Silhouette Score=0.249
# eps=0.4, min_samples=50, Silhouette Score=0.243
# eps=0.4, min_samples=51, Silhouette Score=0.243
# eps=0.4, min_samples=52, Silhouette Score=0.234
# eps=0.4, min_samples=53, Silhouette Score=0.230
# eps=0.4, min_samples=54, Silhouette Score=0.223
# eps=0.4, min_samples=55, Silhouette Score=0.213
# eps=0.4, min_samples=56, Silhouette Score=0.207
# eps=0.4, min_samples=57, Silhouette Score=0.205
# eps=0.4, min_samples=58, Silhouette Score=0.196
# eps=0.4, min_samples=59, Silhouette Score=0.190
# eps=0.4, min_samples=60, Silhouette Score=0.175
# eps=0.4, min_samples=61, Silhouette Score=0.168
# eps=0.4, min_samples=62, Silhouette Score=0.163
# eps=0.4, min_samples=63, Silhouette Score=0.147
# eps=0.4, min_samples=64, Silhouette Score=0.123
# eps=0.4, min_samples=65, Silhouette Score=0.116
# eps=0.4, min_samples=66, Silhouette Score=0.109
# eps=0.4, min_samples=67, Silhouette Score=0.102
# eps=0.4, min_samples=68, Silhouette Score=0.092
# eps=0.4, min_samples=69, Silhouette Score=0.081
# eps=0.4, min_samples=70, Silhouette Score=0.081
# eps=0.4, min_samples=71, Silhouette Score=0.064
# eps=0.4, min_samples=72, Silhouette Score=0.060
# eps=0.4, min_samples=73, Silhouette Score=0.055
# eps=0.4, min_samples=74, Silhouette Score=0.030
# eps=0.4, min_samples=75, Silhouette Score=0.013
# eps=0.4, min_samples=76, Silhouette Score=-0.000
# eps=0.4, min_samples=77, Silhouette Score=-0.000
# eps=0.4, min_samples=78, Silhouette Score=-0.040
# eps=0.4, min_samples=79, Silhouette Score=-0.091
# eps=0.4, min_samples=80, Silhouette Score=-0.091
# eps=0.4, min_samples=81, Silhouette Score=-0.106
# eps=0.4, min_samples=82, Silhouette Score=-0.113
# eps=0.4, min_samples=83, Silhouette Score=-0.145
# eps=0.4, min_samples=84, Silhouette Score=-0.151
# eps=0.4, min_samples=85, Silhouette Score=-0.151
# eps=0.4, min_samples=86, Silhouette Score=-0.154
# eps=0.4, min_samples=87, Silhouette Score=-0.182
# eps=0.4, min_samples=88, Silhouette Score=-0.189
# eps=0.4, min_samples=89, No valid clusters found.
# eps=0.4, min_samples=90, No valid clusters found.
# eps=0.4, min_samples=91, No valid clusters found.
# eps=0.4, min_samples=92, No valid clusters found.
# eps=0.4, min_samples=93, No valid clusters found.
# eps=0.4, min_samples=94, No valid clusters found.
# eps=0.4, min_samples=95, No valid clusters found.
# eps=0.4, min_samples=96, No valid clusters found.
# eps=0.4, min_samples=97, No valid clusters found.
# eps=0.4, min_samples=98, No valid clusters found.
# eps=0.4, min_samples=99, No valid clusters found.
# eps=0.4, min_samples=100, No valid clusters found.
# eps=0.5, min_samples=1, Silhouette Score=0.206
# eps=0.5, min_samples=2, Silhouette Score=0.206
# eps=0.5, min_samples=3, Silhouette Score=0.245
# eps=0.5, min_samples=4, Silhouette Score=0.245
# eps=0.5, min_samples=5, Silhouette Score=0.245
# eps=0.5, min_samples=6, Silhouette Score=0.245
# eps=0.5, min_samples=7, Silhouette Score=0.245
# eps=0.5, min_samples=8, Silhouette Score=0.245
# eps=0.5, min_samples=9, Silhouette Score=0.343
# eps=0.5, min_samples=10, Silhouette Score=0.373
# eps=0.5, min_samples=11, Silhouette Score=0.412
# eps=0.5, min_samples=12, Silhouette Score=0.412
# eps=0.5, min_samples=13, Silhouette Score=0.420
# eps=0.5, min_samples=14, Silhouette Score=0.430
# eps=0.5, min_samples=15, Silhouette Score=0.423
# eps=0.5, min_samples=16, Silhouette Score=0.420
# eps=0.5, min_samples=17, Silhouette Score=0.420
# eps=0.5, min_samples=18, Silhouette Score=0.411
# eps=0.5, min_samples=19, Silhouette Score=0.411
# eps=0.5, min_samples=20, Silhouette Score=0.408
# eps=0.5, min_samples=21, Silhouette Score=0.405
# eps=0.5, min_samples=22, Silhouette Score=0.400
# eps=0.5, min_samples=23, Silhouette Score=0.397
# eps=0.5, min_samples=24, Silhouette Score=0.393
# eps=0.5, min_samples=25, Silhouette Score=0.393
# eps=0.5, min_samples=26, Silhouette Score=0.388
# eps=0.5, min_samples=27, Silhouette Score=0.388
# eps=0.5, min_samples=28, Silhouette Score=0.391
# eps=0.5, min_samples=29, Silhouette Score=0.386
# eps=0.5, min_samples=30, Silhouette Score=0.381
# eps=0.5, min_samples=31, Silhouette Score=0.379
# eps=0.5, min_samples=32, Silhouette Score=0.379
# eps=0.5, min_samples=33, Silhouette Score=0.374
# eps=0.5, min_samples=34, Silhouette Score=0.371
# eps=0.5, min_samples=35, Silhouette Score=0.372
# eps=0.5, min_samples=36, Silhouette Score=0.369
# eps=0.5, min_samples=37, Silhouette Score=0.369
# eps=0.5, min_samples=38, Silhouette Score=0.369
# eps=0.5, min_samples=39, Silhouette Score=0.370
# eps=0.5, min_samples=40, Silhouette Score=0.369
# eps=0.5, min_samples=41, Silhouette Score=0.365
# eps=0.5, min_samples=42, Silhouette Score=0.364
# eps=0.5, min_samples=43, Silhouette Score=0.363
# eps=0.5, min_samples=44, Silhouette Score=0.362
# eps=0.5, min_samples=45, Silhouette Score=0.361
# eps=0.5, min_samples=46, Silhouette Score=0.361
# eps=0.5, min_samples=47, Silhouette Score=0.354
# eps=0.5, min_samples=48, Silhouette Score=0.354
# eps=0.5, min_samples=49, Silhouette Score=0.349
# eps=0.5, min_samples=50, Silhouette Score=0.347
# eps=0.5, min_samples=51, Silhouette Score=0.346
# eps=0.5, min_samples=52, Silhouette Score=0.345
# eps=0.5, min_samples=53, Silhouette Score=0.343
# eps=0.5, min_samples=54, Silhouette Score=0.345
# eps=0.5, min_samples=55, Silhouette Score=0.343
# eps=0.5, min_samples=56, Silhouette Score=0.336
# eps=0.5, min_samples=57, Silhouette Score=0.336
# eps=0.5, min_samples=58, Silhouette Score=0.334
# eps=0.5, min_samples=59, Silhouette Score=0.334
# eps=0.5, min_samples=60, Silhouette Score=0.329
# eps=0.5, min_samples=61, Silhouette Score=0.321
# eps=0.5, min_samples=62, Silhouette Score=0.322
# eps=0.5, min_samples=63, Silhouette Score=0.316
# eps=0.5, min_samples=64, Silhouette Score=0.311
# eps=0.5, min_samples=65, Silhouette Score=0.312
# eps=0.5, min_samples=66, Silhouette Score=0.307
# eps=0.5, min_samples=67, Silhouette Score=0.305
# eps=0.5, min_samples=68, Silhouette Score=0.305
# eps=0.5, min_samples=69, Silhouette Score=0.303
# eps=0.5, min_samples=70, Silhouette Score=0.302
# eps=0.5, min_samples=71, Silhouette Score=0.283
# eps=0.5, min_samples=72, Silhouette Score=0.280
# eps=0.5, min_samples=73, Silhouette Score=0.278
# eps=0.5, min_samples=74, Silhouette Score=0.273
# eps=0.5, min_samples=75, Silhouette Score=0.268
# eps=0.5, min_samples=76, Silhouette Score=0.262
# eps=0.5, min_samples=77, Silhouette Score=0.260
# eps=0.5, min_samples=78, Silhouette Score=0.259
# eps=0.5, min_samples=79, Silhouette Score=0.249
# eps=0.5, min_samples=80, Silhouette Score=0.247
# eps=0.5, min_samples=81, Silhouette Score=0.246
# eps=0.5, min_samples=82, Silhouette Score=0.245
# eps=0.5, min_samples=83, Silhouette Score=0.243
# eps=0.5, min_samples=84, Silhouette Score=0.237
# eps=0.5, min_samples=85, Silhouette Score=0.225
# eps=0.5, min_samples=86, Silhouette Score=0.222
# eps=0.5, min_samples=87, Silhouette Score=0.221
# eps=0.5, min_samples=88, Silhouette Score=0.216
# eps=0.5, min_samples=89, Silhouette Score=0.216
# eps=0.5, min_samples=90, Silhouette Score=0.216
# eps=0.5, min_samples=91, Silhouette Score=0.209
# eps=0.5, min_samples=92, Silhouette Score=0.207
# eps=0.5, min_samples=93, Silhouette Score=0.203
# eps=0.5, min_samples=94, Silhouette Score=0.195
# eps=0.5, min_samples=95, Silhouette Score=0.195
# eps=0.5, min_samples=96, Silhouette Score=0.187
# eps=0.5, min_samples=97, Silhouette Score=0.187
# eps=0.5, min_samples=98, Silhouette Score=0.182
# eps=0.5, min_samples=99, Silhouette Score=0.175
# eps=0.5, min_samples=100, Silhouette Score=0.173
# eps=0.6, min_samples=1, No valid clusters found.
# eps=0.6, min_samples=2, No valid clusters found.
# eps=0.6, min_samples=3, No valid clusters found.
# eps=0.6, min_samples=4, No valid clusters found.
# eps=0.6, min_samples=5, No valid clusters found.
# eps=0.6, min_samples=6, No valid clusters found.
# eps=0.6, min_samples=7, No valid clusters found.
# eps=0.6, min_samples=8, No valid clusters found.
# eps=0.6, min_samples=9, No valid clusters found.
# eps=0.6, min_samples=10, No valid clusters found.
# eps=0.6, min_samples=11, No valid clusters found.
# eps=0.6, min_samples=12, No valid clusters found.
# eps=0.6, min_samples=13, Silhouette Score=0.447
# eps=0.6, min_samples=14, Silhouette Score=0.446
# eps=0.6, min_samples=15, Silhouette Score=0.440
# eps=0.6, min_samples=16, Silhouette Score=0.440
# eps=0.6, min_samples=17, Silhouette Score=0.436
# eps=0.6, min_samples=18, Silhouette Score=0.436
# eps=0.6, min_samples=19, Silhouette Score=0.445
# eps=0.6, min_samples=20, Silhouette Score=0.437
# eps=0.6, min_samples=21, Silhouette Score=0.433
# eps=0.6, min_samples=22, Silhouette Score=0.433
# eps=0.6, min_samples=23, Silhouette Score=0.430
# eps=0.6, min_samples=24, Silhouette Score=0.433
# eps=0.6, min_samples=25, Silhouette Score=0.430
# eps=0.6, min_samples=26, Silhouette Score=0.429
# eps=0.6, min_samples=27, Silhouette Score=0.424
# eps=0.6, min_samples=28, Silhouette Score=0.419
# eps=0.6, min_samples=29, Silhouette Score=0.422
# eps=0.6, min_samples=30, Silhouette Score=0.420
# eps=0.6, min_samples=31, Silhouette Score=0.420
# eps=0.6, min_samples=32, Silhouette Score=0.420
# eps=0.6, min_samples=33, Silhouette Score=0.421
# eps=0.6, min_samples=34, Silhouette Score=0.421
# eps=0.6, min_samples=35, Silhouette Score=0.420
# eps=0.6, min_samples=36, Silhouette Score=0.410
# eps=0.6, min_samples=37, Silhouette Score=0.410
# eps=0.6, min_samples=38, Silhouette Score=0.404
# eps=0.6, min_samples=39, Silhouette Score=0.406
# eps=0.6, min_samples=40, Silhouette Score=0.406
# eps=0.6, min_samples=41, Silhouette Score=0.406
# eps=0.6, min_samples=42, Silhouette Score=0.405
# eps=0.6, min_samples=43, Silhouette Score=0.405
# eps=0.6, min_samples=44, Silhouette Score=0.405
# eps=0.6, min_samples=45, Silhouette Score=0.400
# eps=0.6, min_samples=46, Silhouette Score=0.392
# eps=0.6, min_samples=47, Silhouette Score=0.391
# eps=0.6, min_samples=48, Silhouette Score=0.391
# eps=0.6, min_samples=49, Silhouette Score=0.387
# eps=0.6, min_samples=50, Silhouette Score=0.387
# eps=0.6, min_samples=51, Silhouette Score=0.385
# eps=0.6, min_samples=52, Silhouette Score=0.384
# eps=0.6, min_samples=53, Silhouette Score=0.384
# eps=0.6, min_samples=54, Silhouette Score=0.384
# eps=0.6, min_samples=55, Silhouette Score=0.377
# eps=0.6, min_samples=56, Silhouette Score=0.376
# eps=0.6, min_samples=57, Silhouette Score=0.372
# eps=0.6, min_samples=58, Silhouette Score=0.372
# eps=0.6, min_samples=59, Silhouette Score=0.371
# eps=0.6, min_samples=60, Silhouette Score=0.371
# eps=0.6, min_samples=61, Silhouette Score=0.370
# eps=0.6, min_samples=62, Silhouette Score=0.371
# eps=0.6, min_samples=63, Silhouette Score=0.369
# eps=0.6, min_samples=64, Silhouette Score=0.369
# eps=0.6, min_samples=65, Silhouette Score=0.368
# eps=0.6, min_samples=66, Silhouette Score=0.368
# eps=0.6, min_samples=67, Silhouette Score=0.368
# eps=0.6, min_samples=68, Silhouette Score=0.366
# eps=0.6, min_samples=69, Silhouette Score=0.366
# eps=0.6, min_samples=70, Silhouette Score=0.365
# eps=0.6, min_samples=71, Silhouette Score=0.363
# eps=0.6, min_samples=72, Silhouette Score=0.362
# eps=0.6, min_samples=73, Silhouette Score=0.359
# eps=0.6, min_samples=74, Silhouette Score=0.358
# eps=0.6, min_samples=75, Silhouette Score=0.354
# eps=0.6, min_samples=76, Silhouette Score=0.354
# eps=0.6, min_samples=77, Silhouette Score=0.351
# eps=0.6, min_samples=78, Silhouette Score=0.345
# eps=0.6, min_samples=79, Silhouette Score=0.345
# eps=0.6, min_samples=80, Silhouette Score=0.345
# eps=0.6, min_samples=81, Silhouette Score=0.345
# eps=0.6, min_samples=82, Silhouette Score=0.344
# eps=0.6, min_samples=83, Silhouette Score=0.343
# eps=0.6, min_samples=84, Silhouette Score=0.342
# eps=0.6, min_samples=85, Silhouette Score=0.339
# eps=0.6, min_samples=86, Silhouette Score=0.338
# eps=0.6, min_samples=87, Silhouette Score=0.340
# eps=0.6, min_samples=88, Silhouette Score=0.336
# eps=0.6, min_samples=89, Silhouette Score=0.335
# eps=0.6, min_samples=90, Silhouette Score=0.334
# eps=0.6, min_samples=91, Silhouette Score=0.332
# eps=0.6, min_samples=92, Silhouette Score=0.332
# eps=0.6, min_samples=93, Silhouette Score=0.332
# eps=0.6, min_samples=94, Silhouette Score=0.329
# eps=0.6, min_samples=95, Silhouette Score=0.328
# eps=0.6, min_samples=96, Silhouette Score=0.322
# eps=0.6, min_samples=97, Silhouette Score=0.320
# eps=0.6, min_samples=98, Silhouette Score=0.317
# eps=0.6, min_samples=99, Silhouette Score=0.316
# eps=0.6, min_samples=100, Silhouette Score=0.317
# eps=0.7, min_samples=1, No valid clusters found.
# eps=0.7, min_samples=2, No valid clusters found.
# eps=0.7, min_samples=3, No valid clusters found.
# eps=0.7, min_samples=4, No valid clusters found.
# eps=0.7, min_samples=5, No valid clusters found.
# eps=0.7, min_samples=6, No valid clusters found.
# eps=0.7, min_samples=7, No valid clusters found.
# eps=0.7, min_samples=8, No valid clusters found.
# eps=0.7, min_samples=9, No valid clusters found.
# eps=0.7, min_samples=10, No valid clusters found.
# eps=0.7, min_samples=11, No valid clusters found.
# eps=0.7, min_samples=12, No valid clusters found.
# eps=0.7, min_samples=13, No valid clusters found.
# eps=0.7, min_samples=14, No valid clusters found.
# eps=0.7, min_samples=15, No valid clusters found.
# eps=0.7, min_samples=16, No valid clusters found.
# eps=0.7, min_samples=17, Silhouette Score=0.446
# eps=0.7, min_samples=18, Silhouette Score=0.446
# eps=0.7, min_samples=19, Silhouette Score=0.437
# eps=0.7, min_samples=20, Silhouette Score=0.437
# eps=0.7, min_samples=21, Silhouette Score=0.437
# eps=0.7, min_samples=22, Silhouette Score=0.437
# eps=0.7, min_samples=23, Silhouette Score=0.437
# eps=0.7, min_samples=24, Silhouette Score=0.453
# eps=0.7, min_samples=25, Silhouette Score=0.453
# eps=0.7, min_samples=26, Silhouette Score=0.451
# eps=0.7, min_samples=27, Silhouette Score=0.446
# eps=0.7, min_samples=28, Silhouette Score=0.446
# eps=0.7, min_samples=29, Silhouette Score=0.446
# eps=0.7, min_samples=30, Silhouette Score=0.446
# eps=0.7, min_samples=31, Silhouette Score=0.446
# eps=0.7, min_samples=32, Silhouette Score=0.444
# eps=0.7, min_samples=33, Silhouette Score=0.444
# eps=0.7, min_samples=34, Silhouette Score=0.444
# eps=0.7, min_samples=35, Silhouette Score=0.443
# eps=0.7, min_samples=36, Silhouette Score=0.444
# eps=0.7, min_samples=37, Silhouette Score=0.444
# eps=0.7, min_samples=38, Silhouette Score=0.444
# eps=0.7, min_samples=39, Silhouette Score=0.444
# eps=0.7, min_samples=40, Silhouette Score=0.444
# eps=0.7, min_samples=41, Silhouette Score=0.442
# eps=0.7, min_samples=42, Silhouette Score=0.440
# eps=0.7, min_samples=43, Silhouette Score=0.440
# eps=0.7, min_samples=44, Silhouette Score=0.431
# eps=0.7, min_samples=45, Silhouette Score=0.431
# eps=0.7, min_samples=46, Silhouette Score=0.431
# eps=0.7, min_samples=47, Silhouette Score=0.430
# eps=0.7, min_samples=48, Silhouette Score=0.430
# eps=0.7, min_samples=49, Silhouette Score=0.430
# eps=0.7, min_samples=50, Silhouette Score=0.430
# eps=0.7, min_samples=51, Silhouette Score=0.429
# eps=0.7, min_samples=52, Silhouette Score=0.429
# eps=0.7, min_samples=53, Silhouette Score=0.427
# eps=0.7, min_samples=54, Silhouette Score=0.426
# eps=0.7, min_samples=55, Silhouette Score=0.422
# eps=0.7, min_samples=56, Silhouette Score=0.422
# eps=0.7, min_samples=57, Silhouette Score=0.422
# eps=0.7, min_samples=58, Silhouette Score=0.420
# eps=0.7, min_samples=59, Silhouette Score=0.418
# eps=0.7, min_samples=60, Silhouette Score=0.417
# eps=0.7, min_samples=61, Silhouette Score=0.417
# eps=0.7, min_samples=62, Silhouette Score=0.414
# eps=0.7, min_samples=63, Silhouette Score=0.414
# eps=0.7, min_samples=64, Silhouette Score=0.411
# eps=0.7, min_samples=65, Silhouette Score=0.411
# eps=0.7, min_samples=66, Silhouette Score=0.411
# eps=0.7, min_samples=67, Silhouette Score=0.404
# eps=0.7, min_samples=68, Silhouette Score=0.404
# eps=0.7, min_samples=69, Silhouette Score=0.401
# eps=0.7, min_samples=70, Silhouette Score=0.401
# eps=0.7, min_samples=71, Silhouette Score=0.401
# eps=0.7, min_samples=72, Silhouette Score=0.401
# eps=0.7, min_samples=73, Silhouette Score=0.399
# eps=0.7, min_samples=74, Silhouette Score=0.397
# eps=0.7, min_samples=75, Silhouette Score=0.397
# eps=0.7, min_samples=76, Silhouette Score=0.397
# eps=0.7, min_samples=77, Silhouette Score=0.397
# eps=0.7, min_samples=78, Silhouette Score=0.397
# eps=0.7, min_samples=79, Silhouette Score=0.395
# eps=0.7, min_samples=80, Silhouette Score=0.394
# eps=0.7, min_samples=81, Silhouette Score=0.393
# eps=0.7, min_samples=82, Silhouette Score=0.390
# eps=0.7, min_samples=83, Silhouette Score=0.386
# eps=0.7, min_samples=84, Silhouette Score=0.386
# eps=0.7, min_samples=85, Silhouette Score=0.384
# eps=0.7, min_samples=86, Silhouette Score=0.383
# eps=0.7, min_samples=87, Silhouette Score=0.378
# eps=0.7, min_samples=88, Silhouette Score=0.375
# eps=0.7, min_samples=89, Silhouette Score=0.375
# eps=0.7, min_samples=90, Silhouette Score=0.375
# eps=0.7, min_samples=91, Silhouette Score=0.374
# eps=0.7, min_samples=92, Silhouette Score=0.374
# eps=0.7, min_samples=93, Silhouette Score=0.374
# eps=0.7, min_samples=94, Silhouette Score=0.374
# eps=0.7, min_samples=95, Silhouette Score=0.372
# eps=0.7, min_samples=96, Silhouette Score=0.370
# eps=0.7, min_samples=97, Silhouette Score=0.369
# eps=0.7, min_samples=98, Silhouette Score=0.368
# eps=0.7, min_samples=99, Silhouette Score=0.365
# eps=0.7, min_samples=100, Silhouette Score=0.365
# eps=0.8, min_samples=1, No valid clusters found.
# eps=0.8, min_samples=2, No valid clusters found.
# eps=0.8, min_samples=3, No valid clusters found.
# eps=0.8, min_samples=4, No valid clusters found.
# eps=0.8, min_samples=5, No valid clusters found.
# eps=0.8, min_samples=6, No valid clusters found.
# eps=0.8, min_samples=7, No valid clusters found.
# eps=0.8, min_samples=8, No valid clusters found.
# eps=0.8, min_samples=9, No valid clusters found.
# eps=0.8, min_samples=10, No valid clusters found.
# eps=0.8, min_samples=11, No valid clusters found.
# eps=0.8, min_samples=12, No valid clusters found.
# eps=0.8, min_samples=13, No valid clusters found.
# eps=0.8, min_samples=14, No valid clusters found.
# eps=0.8, min_samples=15, No valid clusters found.
# eps=0.8, min_samples=16, No valid clusters found.
# eps=0.8, min_samples=17, No valid clusters found.
# eps=0.8, min_samples=18, No valid clusters found.
# eps=0.8, min_samples=19, No valid clusters found.
# eps=0.8, min_samples=20, No valid clusters found.
# eps=0.8, min_samples=21, No valid clusters found.
# eps=0.8, min_samples=22, No valid clusters found.
# eps=0.8, min_samples=23, No valid clusters found.
# eps=0.8, min_samples=24, Silhouette Score=0.442
# eps=0.8, min_samples=25, Silhouette Score=0.442
# eps=0.8, min_samples=26, Silhouette Score=0.442
# eps=0.8, min_samples=27, Silhouette Score=0.442
# eps=0.8, min_samples=28, Silhouette Score=0.442
# eps=0.8, min_samples=29, Silhouette Score=0.442
# eps=0.8, min_samples=30, Silhouette Score=0.435
# eps=0.8, min_samples=31, Silhouette Score=0.435
# eps=0.8, min_samples=32, Silhouette Score=0.435
# eps=0.8, min_samples=33, Silhouette Score=0.452
# eps=0.8, min_samples=34, Silhouette Score=0.452
# eps=0.8, min_samples=35, Silhouette Score=0.452
# eps=0.8, min_samples=36, Silhouette Score=0.452
# eps=0.8, min_samples=37, Silhouette Score=0.452
# eps=0.8, min_samples=38, Silhouette Score=0.450
# eps=0.8, min_samples=39, Silhouette Score=0.450
# eps=0.8, min_samples=40, Silhouette Score=0.450
# eps=0.8, min_samples=41, Silhouette Score=0.451
# eps=0.8, min_samples=42, Silhouette Score=0.451
# eps=0.8, min_samples=43, Silhouette Score=0.452
# eps=0.8, min_samples=44, Silhouette Score=0.452
# eps=0.8, min_samples=45, Silhouette Score=0.452
# eps=0.8, min_samples=46, Silhouette Score=0.452
# eps=0.8, min_samples=47, Silhouette Score=0.452
# eps=0.8, min_samples=48, Silhouette Score=0.452
# eps=0.8, min_samples=49, Silhouette Score=0.452
# eps=0.8, min_samples=50, Silhouette Score=0.442
# eps=0.8, min_samples=51, Silhouette Score=0.441
# eps=0.8, min_samples=52, Silhouette Score=0.441
# eps=0.8, min_samples=53, Silhouette Score=0.441
# eps=0.8, min_samples=54, Silhouette Score=0.437
# eps=0.8, min_samples=55, Silhouette Score=0.438
# eps=0.8, min_samples=56, Silhouette Score=0.438
# eps=0.8, min_samples=57, Silhouette Score=0.438
# eps=0.8, min_samples=58, Silhouette Score=0.438
# eps=0.8, min_samples=59, Silhouette Score=0.438
# eps=0.8, min_samples=60, Silhouette Score=0.438
# eps=0.8, min_samples=61, Silhouette Score=0.432
# eps=0.8, min_samples=62, Silhouette Score=0.432
# eps=0.8, min_samples=63, Silhouette Score=0.432
# eps=0.8, min_samples=64, Silhouette Score=0.431
# eps=0.8, min_samples=65, Silhouette Score=0.431
# eps=0.8, min_samples=66, Silhouette Score=0.431
# eps=0.8, min_samples=67, Silhouette Score=0.431
# eps=0.8, min_samples=68, Silhouette Score=0.431
# eps=0.8, min_samples=69, Silhouette Score=0.431
# eps=0.8, min_samples=70, Silhouette Score=0.426
# eps=0.8, min_samples=71, Silhouette Score=0.426
# eps=0.8, min_samples=72, Silhouette Score=0.426
# eps=0.8, min_samples=73, Silhouette Score=0.426
# eps=0.8, min_samples=74, Silhouette Score=0.426
# eps=0.8, min_samples=75, Silhouette Score=0.425
# eps=0.8, min_samples=76, Silhouette Score=0.425
# eps=0.8, min_samples=77, Silhouette Score=0.423
# eps=0.8, min_samples=78, Silhouette Score=0.423
# eps=0.8, min_samples=79, Silhouette Score=0.423
# eps=0.8, min_samples=80, Silhouette Score=0.423
# eps=0.8, min_samples=81, Silhouette Score=0.423
# eps=0.8, min_samples=82, Silhouette Score=0.418
# eps=0.8, min_samples=83, Silhouette Score=0.418
# eps=0.8, min_samples=84, Silhouette Score=0.418
# eps=0.8, min_samples=85, Silhouette Score=0.418
# eps=0.8, min_samples=86, Silhouette Score=0.417
# eps=0.8, min_samples=87, Silhouette Score=0.415
# eps=0.8, min_samples=88, Silhouette Score=0.415
# eps=0.8, min_samples=89, Silhouette Score=0.415
# eps=0.8, min_samples=90, Silhouette Score=0.415
# eps=0.8, min_samples=91, Silhouette Score=0.415
# eps=0.8, min_samples=92, Silhouette Score=0.415
# eps=0.8, min_samples=93, Silhouette Score=0.415
# eps=0.8, min_samples=94, Silhouette Score=0.414
# eps=0.8, min_samples=95, Silhouette Score=0.412
# eps=0.8, min_samples=96, Silhouette Score=0.412
# eps=0.8, min_samples=97, Silhouette Score=0.412
# eps=0.8, min_samples=98, Silhouette Score=0.412
# eps=0.8, min_samples=99, Silhouette Score=0.407
# eps=0.8, min_samples=100, Silhouette Score=0.405
# eps=0.9, min_samples=1, No valid clusters found.
# eps=0.9, min_samples=2, No valid clusters found.
# eps=0.9, min_samples=3, No valid clusters found.
# eps=0.9, min_samples=4, No valid clusters found.
# eps=0.9, min_samples=5, No valid clusters found.
# eps=0.9, min_samples=6, No valid clusters found.
# eps=0.9, min_samples=7, No valid clusters found.
# eps=0.9, min_samples=8, No valid clusters found.
# eps=0.9, min_samples=9, No valid clusters found.
# eps=0.9, min_samples=10, No valid clusters found.
# eps=0.9, min_samples=11, No valid clusters found.
# eps=0.9, min_samples=12, No valid clusters found.
# eps=0.9, min_samples=13, No valid clusters found.
# eps=0.9, min_samples=14, No valid clusters found.
# eps=0.9, min_samples=15, No valid clusters found.
# eps=0.9, min_samples=16, No valid clusters found.
# eps=0.9, min_samples=17, No valid clusters found.
# eps=0.9, min_samples=18, No valid clusters found.
# eps=0.9, min_samples=19, No valid clusters found.
# eps=0.9, min_samples=20, No valid clusters found.
# eps=0.9, min_samples=21, No valid clusters found.
# eps=0.9, min_samples=22, No valid clusters found.
# eps=0.9, min_samples=23, No valid clusters found.
# eps=0.9, min_samples=24, No valid clusters found.
# eps=0.9, min_samples=25, No valid clusters found.
# eps=0.9, min_samples=26, No valid clusters found.
# eps=0.9, min_samples=27, No valid clusters found.
# eps=0.9, min_samples=28, No valid clusters found.
# eps=0.9, min_samples=29, No valid clusters found.
# eps=0.9, min_samples=30, No valid clusters found.
# eps=0.9, min_samples=31, No valid clusters found.
# eps=0.9, min_samples=32, No valid clusters found.
# eps=0.9, min_samples=33, No valid clusters found.
# eps=0.9, min_samples=34, No valid clusters found.
# eps=0.9, min_samples=35, No valid clusters found.
# eps=0.9, min_samples=36, Silhouette Score=0.451
# eps=0.9, min_samples=37, Silhouette Score=0.451
# eps=0.9, min_samples=38, Silhouette Score=0.451
# eps=0.9, min_samples=39, Silhouette Score=0.442
# eps=0.9, min_samples=40, Silhouette Score=0.442
# eps=0.9, min_samples=41, Silhouette Score=0.442
# eps=0.9, min_samples=42, Silhouette Score=0.442
# eps=0.9, min_samples=43, Silhouette Score=0.442
# eps=0.9, min_samples=44, Silhouette Score=0.442
# eps=0.9, min_samples=45, Silhouette Score=0.447
# eps=0.9, min_samples=46, Silhouette Score=0.447
# eps=0.9, min_samples=47, Silhouette Score=0.447
# eps=0.9, min_samples=48, Silhouette Score=0.453
# eps=0.9, min_samples=49, Silhouette Score=0.453
# eps=0.9, min_samples=50, Silhouette Score=0.453
# eps=0.9, min_samples=51, Silhouette Score=0.449
# eps=0.9, min_samples=52, Silhouette Score=0.453
# eps=0.9, min_samples=53, Silhouette Score=0.453
# eps=0.9, min_samples=54, Silhouette Score=0.453
# eps=0.9, min_samples=55, Silhouette Score=0.453
# eps=0.9, min_samples=56, Silhouette Score=0.453
# eps=0.9, min_samples=57, Silhouette Score=0.453
# eps=0.9, min_samples=58, Silhouette Score=0.453
# eps=0.9, min_samples=59, Silhouette Score=0.453
# eps=0.9, min_samples=60, Silhouette Score=0.448
# eps=0.9, min_samples=61, Silhouette Score=0.448
# eps=0.9, min_samples=62, Silhouette Score=0.448
# eps=0.9, min_samples=63, Silhouette Score=0.448
# eps=0.9, min_samples=64, Silhouette Score=0.448
# eps=0.9, min_samples=65, Silhouette Score=0.447
# eps=0.9, min_samples=66, Silhouette Score=0.447
# eps=0.9, min_samples=67, Silhouette Score=0.447
# eps=0.9, min_samples=68, Silhouette Score=0.447
# eps=0.9, min_samples=69, Silhouette Score=0.446
# eps=0.9, min_samples=70, Silhouette Score=0.446
# eps=0.9, min_samples=71, Silhouette Score=0.446
# eps=0.9, min_samples=72, Silhouette Score=0.446
# eps=0.9, min_samples=73, Silhouette Score=0.446
# eps=0.9, min_samples=74, Silhouette Score=0.445
# eps=0.9, min_samples=75, Silhouette Score=0.444
# eps=0.9, min_samples=76, Silhouette Score=0.444
# eps=0.9, min_samples=77, Silhouette Score=0.444
# eps=0.9, min_samples=78, Silhouette Score=0.443
# eps=0.9, min_samples=79, Silhouette Score=0.443
# eps=0.9, min_samples=80, Silhouette Score=0.443
# eps=0.9, min_samples=81, Silhouette Score=0.443
# eps=0.9, min_samples=82, Silhouette Score=0.443
# eps=0.9, min_samples=83, Silhouette Score=0.439
# eps=0.9, min_samples=84, Silhouette Score=0.438
# eps=0.9, min_samples=85, Silhouette Score=0.431
# eps=0.9, min_samples=86, Silhouette Score=0.431
# eps=0.9, min_samples=87, Silhouette Score=0.431
# eps=0.9, min_samples=88, Silhouette Score=0.431
# eps=0.9, min_samples=89, Silhouette Score=0.431
# eps=0.9, min_samples=90, Silhouette Score=0.431
# eps=0.9, min_samples=91, Silhouette Score=0.431
# eps=0.9, min_samples=92, Silhouette Score=0.431
# eps=0.9, min_samples=93, Silhouette Score=0.431
# eps=0.9, min_samples=94, Silhouette Score=0.431
# eps=0.9, min_samples=95, Silhouette Score=0.431
# eps=0.9, min_samples=96, Silhouette Score=0.430
# eps=0.9, min_samples=97, Silhouette Score=0.430
# eps=0.9, min_samples=98, Silhouette Score=0.430
# eps=0.9, min_samples=99, Silhouette Score=0.428
# eps=0.9, min_samples=100, Silhouette Score=0.428
# eps=1.0, min_samples=1, No valid clusters found.
# eps=1.0, min_samples=2, No valid clusters found.
# eps=1.0, min_samples=3, No valid clusters found.
# eps=1.0, min_samples=4, No valid clusters found.
# eps=1.0, min_samples=5, No valid clusters found.
# eps=1.0, min_samples=6, No valid clusters found.
# eps=1.0, min_samples=7, No valid clusters found.
# eps=1.0, min_samples=8, No valid clusters found.
# eps=1.0, min_samples=9, No valid clusters found.
# eps=1.0, min_samples=10, No valid clusters found.
# eps=1.0, min_samples=11, No valid clusters found.
# eps=1.0, min_samples=12, No valid clusters found.
# eps=1.0, min_samples=13, No valid clusters found.
# eps=1.0, min_samples=14, No valid clusters found.
# eps=1.0, min_samples=15, No valid clusters found.
# eps=1.0, min_samples=16, No valid clusters found.
# eps=1.0, min_samples=17, No valid clusters found.
# eps=1.0, min_samples=18, No valid clusters found.
# eps=1.0, min_samples=19, No valid clusters found.
# eps=1.0, min_samples=20, No valid clusters found.
# eps=1.0, min_samples=21, No valid clusters found.
# eps=1.0, min_samples=22, No valid clusters found.
# eps=1.0, min_samples=23, No valid clusters found.
# eps=1.0, min_samples=24, No valid clusters found.
# eps=1.0, min_samples=25, No valid clusters found.
# eps=1.0, min_samples=26, No valid clusters found.
# eps=1.0, min_samples=27, No valid clusters found.
# eps=1.0, min_samples=28, No valid clusters found.
# eps=1.0, min_samples=29, No valid clusters found.
# eps=1.0, min_samples=30, No valid clusters found.
# eps=1.0, min_samples=31, No valid clusters found.
# eps=1.0, min_samples=32, No valid clusters found.
# eps=1.0, min_samples=33, No valid clusters found.
# eps=1.0, min_samples=34, No valid clusters found.
# eps=1.0, min_samples=35, No valid clusters found.
# eps=1.0, min_samples=36, No valid clusters found.
# eps=1.0, min_samples=37, No valid clusters found.
# eps=1.0, min_samples=38, No valid clusters found.
# eps=1.0, min_samples=39, No valid clusters found.
# eps=1.0, min_samples=40, Silhouette Score=0.451
# eps=1.0, min_samples=41, Silhouette Score=0.451
# eps=1.0, min_samples=42, Silhouette Score=0.451
# eps=1.0, min_samples=43, Silhouette Score=0.451
# eps=1.0, min_samples=44, Silhouette Score=0.451
# eps=1.0, min_samples=45, Silhouette Score=0.451
# eps=1.0, min_samples=46, Silhouette Score=0.451
# eps=1.0, min_samples=47, Silhouette Score=0.451
# eps=1.0, min_samples=48, Silhouette Score=0.451
# eps=1.0, min_samples=49, Silhouette Score=0.451
# eps=1.0, min_samples=50, Silhouette Score=0.451
# eps=1.0, min_samples=51, Silhouette Score=0.451
# eps=1.0, min_samples=52, Silhouette Score=0.451
# eps=1.0, min_samples=53, Silhouette Score=0.451
# eps=1.0, min_samples=54, Silhouette Score=0.451
# eps=1.0, min_samples=55, Silhouette Score=0.451
# eps=1.0, min_samples=56, Silhouette Score=0.451
# eps=1.0, min_samples=57, Silhouette Score=0.451
# eps=1.0, min_samples=58, Silhouette Score=0.451
# eps=1.0, min_samples=59, Silhouette Score=0.451
# eps=1.0, min_samples=60, Silhouette Score=0.451
# eps=1.0, min_samples=61, Silhouette Score=0.451
# eps=1.0, min_samples=62, Silhouette Score=0.473
# eps=1.0, min_samples=63, Silhouette Score=0.473
# eps=1.0, min_samples=64, Silhouette Score=0.473
# eps=1.0, min_samples=65, Silhouette Score=0.460
# eps=1.0, min_samples=66, Silhouette Score=0.460
# eps=1.0, min_samples=67, Silhouette Score=0.460
# eps=1.0, min_samples=68, Silhouette Score=0.460
# eps=1.0, min_samples=69, Silhouette Score=0.460
# eps=1.0, min_samples=70, Silhouette Score=0.460
# eps=1.0, min_samples=71, Silhouette Score=0.460
# eps=1.0, min_samples=72, Silhouette Score=0.460
# eps=1.0, min_samples=73, Silhouette Score=0.460
# eps=1.0, min_samples=74, Silhouette Score=0.460
# eps=1.0, min_samples=75, Silhouette Score=0.456
# eps=1.0, min_samples=76, Silhouette Score=0.456
# eps=1.0, min_samples=77, Silhouette Score=0.456
# eps=1.0, min_samples=78, Silhouette Score=0.456
# eps=1.0, min_samples=79, Silhouette Score=0.456
# eps=1.0, min_samples=80, Silhouette Score=0.452
# eps=1.0, min_samples=81, Silhouette Score=0.453
# eps=1.0, min_samples=82, Silhouette Score=0.453
# eps=1.0, min_samples=83, Silhouette Score=0.453
# eps=1.0, min_samples=84, Silhouette Score=0.449
# eps=1.0, min_samples=85, Silhouette Score=0.449
# eps=1.0, min_samples=86, Silhouette Score=0.449
# eps=1.0, min_samples=87, Silhouette Score=0.449
# eps=1.0, min_samples=88, Silhouette Score=0.450
# eps=1.0, min_samples=89, Silhouette Score=0.449
# eps=1.0, min_samples=90, Silhouette Score=0.449
# eps=1.0, min_samples=91, Silhouette Score=0.449
# eps=1.0, min_samples=92, Silhouette Score=0.449
# eps=1.0, min_samples=93, Silhouette Score=0.448
# eps=1.0, min_samples=94, Silhouette Score=0.448
# eps=1.0, min_samples=95, Silhouette Score=0.447
# eps=1.0, min_samples=96, Silhouette Score=0.447
# eps=1.0, min_samples=97, Silhouette Score=0.447
# eps=1.0, min_samples=98, Silhouette Score=0.447
# eps=1.0, min_samples=99, Silhouette Score=0.447
# eps=1.0, min_samples=100, Silhouette Score=0.441
#
# Best Parameters:
# eps=1.0, min_samples=62, Best Silhouette Score=0.473
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30332\4102732528.py in <module>
#      28
#      29 final_dbscan = DBSCAN(eps=best_params['eps'], min_samples=best_params['min_samples'])
# ---> 30 df['cluster'] = final_dbscan.fit_predict(X_scaled)
#      31
#      32 print("\nCluster Distribution:")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3653         else:
#    3654             # set column
# -> 3655             self._set_item(key, value)
#    3656
#    3657     def _setitem_slice(self, key: slice, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3830         ensure homogeneity.
#    3831         """
# -> 3832         value = self._sanitize_column(value)
#    3833
#    3834         if (
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4536
#    4537         if is_list_like(value):
# -> 4538             com.require_length_match(value, self.index)
#    4539         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4540
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     555     """
#     556     if len(data) != len(index):
# --> 557         raise ValueError(
#     558             "Length of values "
#     559             f"({len(data)}) "
#
# ValueError: Length of values (1000) does not match length of index (1204025)

# %%
df2 = pd.read_csv("tracks.csv")
df2
jsonFile = json.load(open("vetting_playlist.json"))
print(jsonFile.keys())
tracks_data = [item['track'] for item in jsonFile['tracks']['items']]
artists_data = [artist['name'] for item in tracks_data for artist in item['artists']]
ss = dataF
filtered_df = df2[df2['name'].isin(ss['name'])]
fineldata = filtered_df[filtered_df['popularity'].isin(ss["popularity"])]
fineldata
sns.scatterplot(data=fineldata, x="tempo",y= "danceability")
from sklearn.cluster import DBSCAN
X = fineldata[["tempo", "danceability"]]
cluster = DBSCAN(eps=4, min_samples=5).fit(X)
sns.scatterplot(data=fineldata, x="tempo", y="danceability", hue=cluster.labels_)
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30332\3869527110.py in <module>
#       5 tracks_data = [item['track'] for item in jsonFile['tracks']['items']]
#       6 artists_data = [artist['name'] for item in tracks_data for artist in item['artists']]
# ----> 7 ss = dataF
#       8 filtered_df = df2[df2['name'].isin(ss['name'])]
#       9 fineldata = filtered_df[filtered_df['popularity'].isin(ss["popularity"])]
#
# NameError: name 'dataF' is not defined
