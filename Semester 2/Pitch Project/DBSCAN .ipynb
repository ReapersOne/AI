# %%
import pandas as pd
import numpy as np
import seaborn as sns
import json
from bs4 import BeautifulSoup
import requests
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

# %%
file_paths = [
    'mpd.slice.15000-15999.json',
]

all_data = []

for file_path in file_paths:
    with open(file_path, 'r') as file:
        data = json.load(file)
        for playlist in data['playlists']:
            playlist_name = playlist['name']
            for track in playlist['tracks']:
                all_data.append({
                    "playlist_name": playlist_name,
                    "position_in_playlist": track["pos"],
                    "track_id": track['track_uri'],
                    "track_name": track['track_name'],
                    "artist_name": track['artist_name'],
                    "duration_ms": track['duration_ms'],
                    "album_name": track['album_name']
                })
                # Add and remove for DBSCAN
                if len(all_data) >= 1000:
                    break
            if len(all_data) >= 1000:
                break
        if len(all_data) >= 1000:
            break
df = pd.DataFrame(all_data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   playlist_name         1000 non-null   object
#  1   position_in_playlist  1000 non-null   int64
#  2   track_id              1000 non-null   object
#  3   track_name            1000 non-null   object
#  4   artist_name           1000 non-null   object
#  5   duration_ms           1000 non-null   int64
#  6   album_name            1000 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 54.8+ KB

# %%
track_counts = df.groupby(['track_id', 'track_name', 'artist_name']).size().reset_index(name='count')

min_count = track_counts['count'].min()
max_count = track_counts['count'].max()
track_counts['popularity_score'] = (
    ((track_counts['count'] - min_count) / (max_count - min_count) * 9 + 1
).astype(int))

df_with_popularity = df.merge(
    track_counts[['track_id', 'popularity_score']],
    on='track_id',
    how='left'
)

# %%
X = df_with_popularity[['duration_ms', 'popularity_score']]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

eps = 0.7
min_samples = 100

dbscan = DBSCAN(eps=eps, min_samples=min_samples)
dbscan.fit(X_scaled)

df_with_popularity['cluster'] = dbscan.labels_

print(df_with_popularity.head())

n_clusters = len(set(dbscan.labels_)) - (1 if -1 in dbscan.labels_ else 0)
n_noise = list(dbscan.labels_).count(-1)

print(f"Number of clusters: {n_clusters}")
print(f"Number of noise points: {n_noise}")

print(df_with_popularity['cluster'].value_counts())
# Out:
#    playlist_name  position_in_playlist                              track_id  \
# 0  Wedding Music                     0  spotify:track:2rb4cO7RczQFSvpjTJ4C2P
# 1  Wedding Music                     1  spotify:track:017nSBNU2XHwMV0NCWZCqg
# 2  Wedding Music                     2  spotify:track:0W5TB5VNs0J16suh3r67P1
# 3  Wedding Music                     3  spotify:track:1gBnG1MiTNBBVzmuwP7Wii
# 4  Wedding Music                     4  spotify:track:0b99xsUKkETGwZGzpX987r
#
#                    track_name      artist_name  duration_ms  \
# 0              Always Forever     Phil Wickham       281880
# 1              Divine Romance     Phil Wickham       298026
# 2  Messiah / You're Beautiful     Phil Wickham       293720
# 3         Love Is Not A Fight  Warren Barfield       222986
# 4             When I Say I Do     Matthew West       246000
#
#            album_name  popularity_score  cluster
# 0        Phil Wickham                 1        0
# 1        Phil Wickham                 1        0
# 2             Cannons                 1        0
# 3  Worth Fighting For                 1        0
# 4      Hold You Up EP                 1        0
# Number of clusters: 1
# Number of noise points: 73
#  0    927
# -1     73
# Name: cluster, dtype: int64

# %%
features = ['duration_ms', 'popularity_score']
X = df_with_popularity[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

best_score = -1
best_params = {'eps': None, 'min_samples': None}

for eps in np.arange(0.1, 1.1, 0.1):  
    for min_samples in range(1, 101):  
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        labels = dbscan.fit_predict(X_scaled)
        
        if len(np.unique(labels)) > 1:  
            score = silhouette_score(X_scaled, labels)
            print(f"eps={eps:.1f}, min_samples={min_samples}, Silhouette Score={score:.3f}")

            if score > best_score:
                best_score = score
                best_params['eps'] = eps
                best_params['min_samples'] = min_samples
        else:
            print(f"eps={eps:.1f}, min_samples={min_samples}, No valid clusters found.")

print("\nBest Parameters:")
print(f"eps={best_params['eps']}, min_samples={best_params['min_samples']}, Best Silhouette Score={best_score:.3f}")

final_dbscan = DBSCAN(eps=best_params['eps'], min_samples=best_params['min_samples'])
df['cluster'] = final_dbscan.fit_predict(X_scaled)

print("\nCluster Distribution:")
print(df['cluster'].value_counts())
# Out:
# eps=0.1, min_samples=1, Silhouette Score=0.431
# eps=0.1, min_samples=2, Silhouette Score=0.427
# eps=0.1, min_samples=3, Silhouette Score=0.399
# eps=0.1, min_samples=4, Silhouette Score=0.368
# eps=0.1, min_samples=5, Silhouette Score=0.436
# eps=0.1, min_samples=6, Silhouette Score=0.513
# eps=0.1, min_samples=7, Silhouette Score=0.500
# eps=0.1, min_samples=8, Silhouette Score=0.501
# eps=0.1, min_samples=9, Silhouette Score=0.498
# eps=0.1, min_samples=10, Silhouette Score=0.455
# eps=0.1, min_samples=11, Silhouette Score=0.429
# eps=0.1, min_samples=12, Silhouette Score=0.429
# eps=0.1, min_samples=13, Silhouette Score=0.426
# eps=0.1, min_samples=14, Silhouette Score=0.414
# eps=0.1, min_samples=15, Silhouette Score=0.449
# eps=0.1, min_samples=16, Silhouette Score=0.449
# eps=0.1, min_samples=17, Silhouette Score=0.449
# eps=0.1, min_samples=18, Silhouette Score=0.362
# eps=0.1, min_samples=19, Silhouette Score=0.341
# eps=0.1, min_samples=20, Silhouette Score=0.343
# eps=0.1, min_samples=21, Silhouette Score=0.605
# eps=0.1, min_samples=22, Silhouette Score=0.605
# eps=0.1, min_samples=23, Silhouette Score=0.604
# eps=0.1, min_samples=24, Silhouette Score=0.604
# eps=0.1, min_samples=25, Silhouette Score=0.599
# eps=0.1, min_samples=26, Silhouette Score=0.597
# eps=0.1, min_samples=27, Silhouette Score=0.596
# eps=0.1, min_samples=28, Silhouette Score=0.580
# eps=0.1, min_samples=29, Silhouette Score=0.574
# eps=0.1, min_samples=30, Silhouette Score=0.574
# eps=0.1, min_samples=31, Silhouette Score=0.571
# eps=0.1, min_samples=32, Silhouette Score=0.569
# eps=0.1, min_samples=33, Silhouette Score=0.569
# eps=0.1, min_samples=34, Silhouette Score=0.568
# eps=0.1, min_samples=35, Silhouette Score=0.559
# eps=0.1, min_samples=36, Silhouette Score=0.559
# eps=0.1, min_samples=37, Silhouette Score=0.559
# eps=0.1, min_samples=38, Silhouette Score=0.556
# eps=0.1, min_samples=39, Silhouette Score=0.556
# eps=0.1, min_samples=40, Silhouette Score=0.537
# eps=0.1, min_samples=41, Silhouette Score=0.537
# eps=0.1, min_samples=42, Silhouette Score=0.531
# eps=0.1, min_samples=43, Silhouette Score=0.187
# eps=0.1, min_samples=44, Silhouette Score=0.464
# eps=0.1, min_samples=45, Silhouette Score=0.463
# eps=0.1, min_samples=46, Silhouette Score=0.448
# eps=0.1, min_samples=47, Silhouette Score=0.448
# eps=0.1, min_samples=48, Silhouette Score=0.429
# eps=0.1, min_samples=49, Silhouette Score=0.428
# eps=0.1, min_samples=50, Silhouette Score=0.428
# eps=0.1, min_samples=51, Silhouette Score=0.428
# eps=0.1, min_samples=52, Silhouette Score=0.428
# eps=0.1, min_samples=53, Silhouette Score=0.428
# eps=0.1, min_samples=54, Silhouette Score=0.425
# eps=0.1, min_samples=55, Silhouette Score=0.414
# eps=0.1, min_samples=56, Silhouette Score=0.413
# eps=0.1, min_samples=57, Silhouette Score=0.412
# eps=0.1, min_samples=58, Silhouette Score=0.409
# eps=0.1, min_samples=59, Silhouette Score=0.409
# eps=0.1, min_samples=60, Silhouette Score=0.407
# eps=0.1, min_samples=61, Silhouette Score=0.407
# eps=0.1, min_samples=62, Silhouette Score=0.407
# eps=0.1, min_samples=63, Silhouette Score=0.407
# eps=0.1, min_samples=64, Silhouette Score=0.401
# eps=0.1, min_samples=65, Silhouette Score=0.401
# eps=0.1, min_samples=66, Silhouette Score=0.401
# eps=0.1, min_samples=67, Silhouette Score=0.378
# eps=0.1, min_samples=68, Silhouette Score=0.378
# eps=0.1, min_samples=69, Silhouette Score=0.378
# eps=0.1, min_samples=70, Silhouette Score=0.378
# eps=0.1, min_samples=71, Silhouette Score=0.378
# eps=0.1, min_samples=72, Silhouette Score=0.377
# eps=0.1, min_samples=73, Silhouette Score=0.358
# eps=0.1, min_samples=74, Silhouette Score=0.067
# eps=0.1, min_samples=75, Silhouette Score=0.061
# eps=0.1, min_samples=76, Silhouette Score=0.069
# eps=0.1, min_samples=77, Silhouette Score=0.069
# eps=0.1, min_samples=78, Silhouette Score=0.067
# eps=0.1, min_samples=79, Silhouette Score=0.265
# eps=0.1, min_samples=80, Silhouette Score=0.265
# eps=0.1, min_samples=81, Silhouette Score=0.264
# eps=0.1, min_samples=82, Silhouette Score=0.207
# eps=0.1, min_samples=83, Silhouette Score=0.201
# eps=0.1, min_samples=84, Silhouette Score=0.165
# eps=0.1, min_samples=85, Silhouette Score=0.149
# eps=0.1, min_samples=86, Silhouette Score=0.140
# eps=0.1, min_samples=87, Silhouette Score=0.138
# eps=0.1, min_samples=88, Silhouette Score=-0.090
# eps=0.1, min_samples=89, Silhouette Score=-0.152
# eps=0.1, min_samples=90, Silhouette Score=-0.023
# eps=0.1, min_samples=91, Silhouette Score=-0.025
# eps=0.1, min_samples=92, Silhouette Score=-0.050
# eps=0.1, min_samples=93, Silhouette Score=-0.050
# eps=0.1, min_samples=94, Silhouette Score=-0.050
# eps=0.1, min_samples=95, Silhouette Score=-0.052
# eps=0.1, min_samples=96, Silhouette Score=-0.052
# eps=0.1, min_samples=97, Silhouette Score=-0.204
# eps=0.1, min_samples=98, Silhouette Score=-0.151
# eps=0.1, min_samples=99, Silhouette Score=-0.151
# eps=0.1, min_samples=100, Silhouette Score=-0.174
# eps=0.2, min_samples=1, Silhouette Score=0.502
# eps=0.2, min_samples=2, Silhouette Score=0.610
# eps=0.2, min_samples=3, Silhouette Score=0.598
# eps=0.2, min_samples=4, Silhouette Score=0.588
# eps=0.2, min_samples=5, Silhouette Score=0.591
# eps=0.2, min_samples=6, Silhouette Score=0.745
# eps=0.2, min_samples=7, Silhouette Score=0.745
# eps=0.2, min_samples=8, Silhouette Score=0.745
# eps=0.2, min_samples=9, Silhouette Score=0.745
# eps=0.2, min_samples=10, Silhouette Score=0.720
# eps=0.2, min_samples=11, Silhouette Score=0.720
# eps=0.2, min_samples=12, Silhouette Score=0.720
# eps=0.2, min_samples=13, Silhouette Score=0.707
# eps=0.2, min_samples=14, Silhouette Score=0.707
# eps=0.2, min_samples=15, Silhouette Score=0.693
# eps=0.2, min_samples=16, Silhouette Score=0.693
# eps=0.2, min_samples=17, Silhouette Score=0.684
# eps=0.2, min_samples=18, Silhouette Score=0.684
# eps=0.2, min_samples=19, Silhouette Score=0.679
# eps=0.2, min_samples=20, Silhouette Score=0.679
# eps=0.2, min_samples=21, Silhouette Score=0.713
# eps=0.2, min_samples=22, Silhouette Score=0.709
# eps=0.2, min_samples=23, Silhouette Score=0.709
# eps=0.2, min_samples=24, Silhouette Score=0.704
# eps=0.2, min_samples=25, Silhouette Score=0.704
# eps=0.2, min_samples=26, Silhouette Score=0.699
# eps=0.2, min_samples=27, Silhouette Score=0.694
# eps=0.2, min_samples=28, Silhouette Score=0.694
# eps=0.2, min_samples=29, Silhouette Score=0.674
# eps=0.2, min_samples=30, Silhouette Score=0.674
# eps=0.2, min_samples=31, Silhouette Score=0.674
# eps=0.2, min_samples=32, Silhouette Score=0.674
# eps=0.2, min_samples=33, Silhouette Score=0.671
# eps=0.2, min_samples=34, Silhouette Score=0.667
# eps=0.2, min_samples=35, Silhouette Score=0.667
# eps=0.2, min_samples=36, Silhouette Score=0.663
# eps=0.2, min_samples=37, Silhouette Score=0.659
# eps=0.2, min_samples=38, Silhouette Score=0.657
# eps=0.2, min_samples=39, Silhouette Score=0.657
# eps=0.2, min_samples=40, Silhouette Score=0.657
# eps=0.2, min_samples=41, Silhouette Score=0.653
# eps=0.2, min_samples=42, Silhouette Score=0.653
# eps=0.2, min_samples=43, Silhouette Score=0.646
# eps=0.2, min_samples=44, Silhouette Score=0.635
# eps=0.2, min_samples=45, Silhouette Score=0.631
# eps=0.2, min_samples=46, Silhouette Score=0.630
# eps=0.2, min_samples=47, Silhouette Score=0.630
# eps=0.2, min_samples=48, Silhouette Score=0.630
# eps=0.2, min_samples=49, Silhouette Score=0.629
# eps=0.2, min_samples=50, Silhouette Score=0.623
# eps=0.2, min_samples=51, Silhouette Score=0.619
# eps=0.2, min_samples=52, Silhouette Score=0.615
# eps=0.2, min_samples=53, Silhouette Score=0.615
# eps=0.2, min_samples=54, Silhouette Score=0.615
# eps=0.2, min_samples=55, Silhouette Score=0.607
# eps=0.2, min_samples=56, Silhouette Score=0.607
# eps=0.2, min_samples=57, Silhouette Score=0.604
# eps=0.2, min_samples=58, Silhouette Score=0.604
# eps=0.2, min_samples=59, Silhouette Score=0.598
# eps=0.2, min_samples=60, Silhouette Score=0.598
# eps=0.2, min_samples=61, Silhouette Score=0.598
# eps=0.2, min_samples=62, Silhouette Score=0.598
# eps=0.2, min_samples=63, Silhouette Score=0.598
# eps=0.2, min_samples=64, Silhouette Score=0.590
# eps=0.2, min_samples=65, Silhouette Score=0.588
# eps=0.2, min_samples=66, Silhouette Score=0.588
# eps=0.2, min_samples=67, Silhouette Score=0.586
# eps=0.2, min_samples=68, Silhouette Score=0.580
# eps=0.2, min_samples=69, Silhouette Score=0.578
# eps=0.2, min_samples=70, Silhouette Score=0.570
# eps=0.2, min_samples=71, Silhouette Score=0.570
# eps=0.2, min_samples=72, Silhouette Score=0.563
# eps=0.2, min_samples=73, Silhouette Score=0.561
# eps=0.2, min_samples=74, Silhouette Score=0.561
# eps=0.2, min_samples=75, Silhouette Score=0.561
# eps=0.2, min_samples=76, Silhouette Score=0.561
# eps=0.2, min_samples=77, Silhouette Score=0.561
# eps=0.2, min_samples=78, Silhouette Score=0.557
# eps=0.2, min_samples=79, Silhouette Score=0.557
# eps=0.2, min_samples=80, Silhouette Score=0.554
# eps=0.2, min_samples=81, Silhouette Score=0.551
# eps=0.2, min_samples=82, Silhouette Score=0.551
# eps=0.2, min_samples=83, Silhouette Score=0.549
# eps=0.2, min_samples=84, Silhouette Score=0.545
# eps=0.2, min_samples=85, Silhouette Score=0.545
# eps=0.2, min_samples=86, Silhouette Score=0.543
# eps=0.2, min_samples=87, Silhouette Score=0.530
# eps=0.2, min_samples=88, Silhouette Score=0.530
# eps=0.2, min_samples=89, Silhouette Score=0.530
# eps=0.2, min_samples=90, Silhouette Score=0.528
# eps=0.2, min_samples=91, Silhouette Score=0.521
# eps=0.2, min_samples=92, Silhouette Score=0.520
# eps=0.2, min_samples=93, Silhouette Score=0.516
# eps=0.2, min_samples=94, Silhouette Score=0.516
# eps=0.2, min_samples=95, Silhouette Score=0.514
# eps=0.2, min_samples=96, Silhouette Score=0.510
# eps=0.2, min_samples=97, Silhouette Score=0.510
# eps=0.2, min_samples=98, Silhouette Score=0.507
# eps=0.2, min_samples=99, Silhouette Score=0.505
# eps=0.2, min_samples=100, Silhouette Score=0.505
# eps=0.3, min_samples=1, Silhouette Score=0.546
# eps=0.3, min_samples=2, Silhouette Score=0.679
# eps=0.3, min_samples=3, Silhouette Score=0.731
# eps=0.3, min_samples=4, Silhouette Score=0.721
# eps=0.3, min_samples=5, Silhouette Score=0.756
# eps=0.3, min_samples=6, Silhouette Score=0.756
# eps=0.3, min_samples=7, Silhouette Score=0.746
# eps=0.3, min_samples=8, Silhouette Score=0.746
# eps=0.3, min_samples=9, Silhouette Score=0.746
# eps=0.3, min_samples=10, Silhouette Score=0.746
# eps=0.3, min_samples=11, Silhouette Score=0.746
# eps=0.3, min_samples=12, Silhouette Score=0.743
# eps=0.3, min_samples=13, Silhouette Score=0.742
# eps=0.3, min_samples=14, Silhouette Score=0.742
# eps=0.3, min_samples=15, Silhouette Score=0.742
# eps=0.3, min_samples=16, Silhouette Score=0.735
# eps=0.3, min_samples=17, Silhouette Score=0.732
# eps=0.3, min_samples=18, Silhouette Score=0.732
# eps=0.3, min_samples=19, Silhouette Score=0.730
# eps=0.3, min_samples=20, Silhouette Score=0.727
# eps=0.3, min_samples=21, Silhouette Score=0.716
# eps=0.3, min_samples=22, Silhouette Score=0.716
# eps=0.3, min_samples=23, Silhouette Score=0.713
# eps=0.3, min_samples=24, Silhouette Score=0.713
# eps=0.3, min_samples=25, Silhouette Score=0.713
# eps=0.3, min_samples=26, Silhouette Score=0.708
# eps=0.3, min_samples=27, Silhouette Score=0.729
# eps=0.3, min_samples=28, Silhouette Score=0.729
# eps=0.3, min_samples=29, Silhouette Score=0.717
# eps=0.3, min_samples=30, Silhouette Score=0.717
# eps=0.3, min_samples=31, Silhouette Score=0.715
# eps=0.3, min_samples=32, Silhouette Score=0.715
# eps=0.3, min_samples=33, Silhouette Score=0.715
# eps=0.3, min_samples=34, Silhouette Score=0.713
# eps=0.3, min_samples=35, Silhouette Score=0.713
# eps=0.3, min_samples=36, Silhouette Score=0.713
# eps=0.3, min_samples=37, Silhouette Score=0.713
# eps=0.3, min_samples=38, Silhouette Score=0.713
# eps=0.3, min_samples=39, Silhouette Score=0.708
# eps=0.3, min_samples=40, Silhouette Score=0.708
# eps=0.3, min_samples=41, Silhouette Score=0.706
# eps=0.3, min_samples=42, Silhouette Score=0.706
# eps=0.3, min_samples=43, Silhouette Score=0.706
# eps=0.3, min_samples=44, Silhouette Score=0.706
# eps=0.3, min_samples=45, Silhouette Score=0.701
# eps=0.3, min_samples=46, Silhouette Score=0.701
# eps=0.3, min_samples=47, Silhouette Score=0.699
# eps=0.3, min_samples=48, Silhouette Score=0.678
# eps=0.3, min_samples=49, Silhouette Score=0.678
# eps=0.3, min_samples=50, Silhouette Score=0.678
# eps=0.3, min_samples=51, Silhouette Score=0.678
# eps=0.3, min_samples=52, Silhouette Score=0.678
# eps=0.3, min_samples=53, Silhouette Score=0.678
# eps=0.3, min_samples=54, Silhouette Score=0.678
# eps=0.3, min_samples=55, Silhouette Score=0.678
# eps=0.3, min_samples=56, Silhouette Score=0.678
# eps=0.3, min_samples=57, Silhouette Score=0.675
# eps=0.3, min_samples=58, Silhouette Score=0.675
# eps=0.3, min_samples=59, Silhouette Score=0.673
# eps=0.3, min_samples=60, Silhouette Score=0.663
# eps=0.3, min_samples=61, Silhouette Score=0.663
# eps=0.3, min_samples=62, Silhouette Score=0.663
# eps=0.3, min_samples=63, Silhouette Score=0.663
# eps=0.3, min_samples=64, Silhouette Score=0.663
# eps=0.3, min_samples=65, Silhouette Score=0.663
# eps=0.3, min_samples=66, Silhouette Score=0.663
# eps=0.3, min_samples=67, Silhouette Score=0.663
# eps=0.3, min_samples=68, Silhouette Score=0.663
# eps=0.3, min_samples=69, Silhouette Score=0.663
# eps=0.3, min_samples=70, Silhouette Score=0.655
# eps=0.3, min_samples=71, Silhouette Score=0.655
# eps=0.3, min_samples=72, Silhouette Score=0.653
# eps=0.3, min_samples=73, Silhouette Score=0.648
# eps=0.3, min_samples=74, Silhouette Score=0.648
# eps=0.3, min_samples=75, Silhouette Score=0.646
# eps=0.3, min_samples=76, Silhouette Score=0.646
# eps=0.3, min_samples=77, Silhouette Score=0.646
# eps=0.3, min_samples=78, Silhouette Score=0.646
# eps=0.3, min_samples=79, Silhouette Score=0.640
# eps=0.3, min_samples=80, Silhouette Score=0.640
# eps=0.3, min_samples=81, Silhouette Score=0.640
# eps=0.3, min_samples=82, Silhouette Score=0.640
# eps=0.3, min_samples=83, Silhouette Score=0.638
# eps=0.3, min_samples=84, Silhouette Score=0.638
# eps=0.3, min_samples=85, Silhouette Score=0.635
# eps=0.3, min_samples=86, Silhouette Score=0.635
# eps=0.3, min_samples=87, Silhouette Score=0.623
# eps=0.3, min_samples=88, Silhouette Score=0.622
# eps=0.3, min_samples=89, Silhouette Score=0.622
# eps=0.3, min_samples=90, Silhouette Score=0.622
# eps=0.3, min_samples=91, Silhouette Score=0.620
# eps=0.3, min_samples=92, Silhouette Score=0.615
# eps=0.3, min_samples=93, Silhouette Score=0.613
# eps=0.3, min_samples=94, Silhouette Score=0.613
# eps=0.3, min_samples=95, Silhouette Score=0.613
# eps=0.3, min_samples=96, Silhouette Score=0.613
# eps=0.3, min_samples=97, Silhouette Score=0.609
# eps=0.3, min_samples=98, Silhouette Score=0.609
# eps=0.3, min_samples=99, Silhouette Score=0.609
# eps=0.3, min_samples=100, Silhouette Score=0.607
# eps=0.4, min_samples=1, Silhouette Score=0.745
# eps=0.4, min_samples=2, Silhouette Score=0.745
# eps=0.4, min_samples=3, Silhouette Score=0.748
# eps=0.4, min_samples=4, Silhouette Score=0.748
# eps=0.4, min_samples=5, Silhouette Score=0.743
# eps=0.4, min_samples=6, Silhouette Score=0.743
# eps=0.4, min_samples=7, Silhouette Score=0.759
# eps=0.4, min_samples=8, Silhouette Score=0.758
# eps=0.4, min_samples=9, Silhouette Score=0.760
# eps=0.4, min_samples=10, Silhouette Score=0.760
# eps=0.4, min_samples=11, Silhouette Score=0.759
# eps=0.4, min_samples=12, Silhouette Score=0.759
# eps=0.4, min_samples=13, Silhouette Score=0.759
# eps=0.4, min_samples=14, Silhouette Score=0.754
# eps=0.4, min_samples=15, Silhouette Score=0.754
# eps=0.4, min_samples=16, Silhouette Score=0.754
# eps=0.4, min_samples=17, Silhouette Score=0.754
# eps=0.4, min_samples=18, Silhouette Score=0.751
# eps=0.4, min_samples=19, Silhouette Score=0.749
# eps=0.4, min_samples=20, Silhouette Score=0.747
# eps=0.4, min_samples=21, Silhouette Score=0.747
# eps=0.4, min_samples=22, Silhouette Score=0.747
# eps=0.4, min_samples=23, Silhouette Score=0.745
# eps=0.4, min_samples=24, Silhouette Score=0.745
# eps=0.4, min_samples=25, Silhouette Score=0.742
# eps=0.4, min_samples=26, Silhouette Score=0.742
# eps=0.4, min_samples=27, Silhouette Score=0.739
# eps=0.4, min_samples=28, Silhouette Score=0.739
# eps=0.4, min_samples=29, Silhouette Score=0.739
# eps=0.4, min_samples=30, Silhouette Score=0.739
# eps=0.4, min_samples=31, Silhouette Score=0.752
# eps=0.4, min_samples=32, Silhouette Score=0.742
# eps=0.4, min_samples=33, Silhouette Score=0.742
# eps=0.4, min_samples=34, Silhouette Score=0.742
# eps=0.4, min_samples=35, Silhouette Score=0.742
# eps=0.4, min_samples=36, Silhouette Score=0.742
# eps=0.4, min_samples=37, Silhouette Score=0.742
# eps=0.4, min_samples=38, Silhouette Score=0.742
# eps=0.4, min_samples=39, Silhouette Score=0.742
# eps=0.4, min_samples=40, Silhouette Score=0.734
# eps=0.4, min_samples=41, Silhouette Score=0.732
# eps=0.4, min_samples=42, Silhouette Score=0.732
# eps=0.4, min_samples=43, Silhouette Score=0.732
# eps=0.4, min_samples=44, Silhouette Score=0.729
# eps=0.4, min_samples=45, Silhouette Score=0.729
# eps=0.4, min_samples=46, Silhouette Score=0.724
# eps=0.4, min_samples=47, Silhouette Score=0.717
# eps=0.4, min_samples=48, Silhouette Score=0.715
# eps=0.4, min_samples=49, Silhouette Score=0.715
# eps=0.4, min_samples=50, Silhouette Score=0.715
# eps=0.4, min_samples=51, Silhouette Score=0.715
# eps=0.4, min_samples=52, Silhouette Score=0.715
# eps=0.4, min_samples=53, Silhouette Score=0.715
# eps=0.4, min_samples=54, Silhouette Score=0.715
# eps=0.4, min_samples=55, Silhouette Score=0.715
# eps=0.4, min_samples=56, Silhouette Score=0.715
# eps=0.4, min_samples=57, Silhouette Score=0.715
# eps=0.4, min_samples=58, Silhouette Score=0.715
# eps=0.4, min_samples=59, Silhouette Score=0.715
# eps=0.4, min_samples=60, Silhouette Score=0.710
# eps=0.4, min_samples=61, Silhouette Score=0.710
# eps=0.4, min_samples=62, Silhouette Score=0.707
# eps=0.4, min_samples=63, Silhouette Score=0.705
# eps=0.4, min_samples=64, Silhouette Score=0.705
# eps=0.4, min_samples=65, Silhouette Score=0.705
# eps=0.4, min_samples=66, Silhouette Score=0.705
# eps=0.4, min_samples=67, Silhouette Score=0.705
# eps=0.4, min_samples=68, Silhouette Score=0.705
# eps=0.4, min_samples=69, Silhouette Score=0.705
# eps=0.4, min_samples=70, Silhouette Score=0.705
# eps=0.4, min_samples=71, Silhouette Score=0.685
# eps=0.4, min_samples=72, Silhouette Score=0.682
# eps=0.4, min_samples=73, Silhouette Score=0.682
# eps=0.4, min_samples=74, Silhouette Score=0.682
# eps=0.4, min_samples=75, Silhouette Score=0.682
# eps=0.4, min_samples=76, Silhouette Score=0.682
# eps=0.4, min_samples=77, Silhouette Score=0.682
# eps=0.4, min_samples=78, Silhouette Score=0.680
# eps=0.4, min_samples=79, Silhouette Score=0.680
# eps=0.4, min_samples=80, Silhouette Score=0.680
# eps=0.4, min_samples=81, Silhouette Score=0.680
# eps=0.4, min_samples=82, Silhouette Score=0.680
# eps=0.4, min_samples=83, Silhouette Score=0.680
# eps=0.4, min_samples=84, Silhouette Score=0.679
# eps=0.4, min_samples=85, Silhouette Score=0.679
# eps=0.4, min_samples=86, Silhouette Score=0.676
# eps=0.4, min_samples=87, Silhouette Score=0.676
# eps=0.4, min_samples=88, Silhouette Score=0.676
# eps=0.4, min_samples=89, Silhouette Score=0.676
# eps=0.4, min_samples=90, Silhouette Score=0.674
# eps=0.4, min_samples=91, Silhouette Score=0.674
# eps=0.4, min_samples=92, Silhouette Score=0.674
# eps=0.4, min_samples=93, Silhouette Score=0.674
# eps=0.4, min_samples=94, Silhouette Score=0.674
# eps=0.4, min_samples=95, Silhouette Score=0.674
# eps=0.4, min_samples=96, Silhouette Score=0.674
# eps=0.4, min_samples=97, Silhouette Score=0.673
# eps=0.4, min_samples=98, Silhouette Score=0.673
# eps=0.4, min_samples=99, Silhouette Score=0.671
# eps=0.4, min_samples=100, Silhouette Score=0.665
# eps=0.5, min_samples=1, Silhouette Score=0.765
# eps=0.5, min_samples=2, Silhouette Score=0.765
# eps=0.5, min_samples=3, Silhouette Score=0.774
# eps=0.5, min_samples=4, Silhouette Score=0.748
# eps=0.5, min_samples=5, Silhouette Score=0.746
# eps=0.5, min_samples=6, Silhouette Score=0.743
# eps=0.5, min_samples=7, Silhouette Score=0.771
# eps=0.5, min_samples=8, Silhouette Score=0.769
# eps=0.5, min_samples=9, Silhouette Score=0.769
# eps=0.5, min_samples=10, Silhouette Score=0.769
# eps=0.5, min_samples=11, Silhouette Score=0.766
# eps=0.5, min_samples=12, Silhouette Score=0.766
# eps=0.5, min_samples=13, Silhouette Score=0.761
# eps=0.5, min_samples=14, Silhouette Score=0.761
# eps=0.5, min_samples=15, Silhouette Score=0.761
# eps=0.5, min_samples=16, Silhouette Score=0.761
# eps=0.5, min_samples=17, Silhouette Score=0.758
# eps=0.5, min_samples=18, Silhouette Score=0.758
# eps=0.5, min_samples=19, Silhouette Score=0.758
# eps=0.5, min_samples=20, Silhouette Score=0.758
# eps=0.5, min_samples=21, Silhouette Score=0.758
# eps=0.5, min_samples=22, Silhouette Score=0.758
# eps=0.5, min_samples=23, Silhouette Score=0.754
# eps=0.5, min_samples=24, Silhouette Score=0.754
# eps=0.5, min_samples=25, Silhouette Score=0.754
# eps=0.5, min_samples=26, Silhouette Score=0.754
# eps=0.5, min_samples=27, Silhouette Score=0.754
# eps=0.5, min_samples=28, Silhouette Score=0.754
# eps=0.5, min_samples=29, Silhouette Score=0.751
# eps=0.5, min_samples=30, Silhouette Score=0.751
# eps=0.5, min_samples=31, Silhouette Score=0.751
# eps=0.5, min_samples=32, Silhouette Score=0.751
# eps=0.5, min_samples=33, Silhouette Score=0.749
# eps=0.5, min_samples=34, Silhouette Score=0.749
# eps=0.5, min_samples=35, Silhouette Score=0.743
# eps=0.5, min_samples=36, Silhouette Score=0.743
# eps=0.5, min_samples=37, Silhouette Score=0.754
# eps=0.5, min_samples=38, Silhouette Score=0.752
# eps=0.5, min_samples=39, Silhouette Score=0.752
# eps=0.5, min_samples=40, Silhouette Score=0.752
# eps=0.5, min_samples=41, Silhouette Score=0.752
# eps=0.5, min_samples=42, Silhouette Score=0.752
# eps=0.5, min_samples=43, Silhouette Score=0.752
# eps=0.5, min_samples=44, Silhouette Score=0.752
# eps=0.5, min_samples=45, Silhouette Score=0.752
# eps=0.5, min_samples=46, Silhouette Score=0.752
# eps=0.5, min_samples=47, Silhouette Score=0.752
# eps=0.5, min_samples=48, Silhouette Score=0.752
# eps=0.5, min_samples=49, Silhouette Score=0.752
# eps=0.5, min_samples=50, Silhouette Score=0.752
# eps=0.5, min_samples=51, Silhouette Score=0.752
# eps=0.5, min_samples=52, Silhouette Score=0.752
# eps=0.5, min_samples=53, Silhouette Score=0.752
# eps=0.5, min_samples=54, Silhouette Score=0.752
# eps=0.5, min_samples=55, Silhouette Score=0.752
# eps=0.5, min_samples=56, Silhouette Score=0.749
# eps=0.5, min_samples=57, Silhouette Score=0.749
# eps=0.5, min_samples=58, Silhouette Score=0.749
# eps=0.5, min_samples=59, Silhouette Score=0.743
# eps=0.5, min_samples=60, Silhouette Score=0.739
# eps=0.5, min_samples=61, Silhouette Score=0.732
# eps=0.5, min_samples=62, Silhouette Score=0.732
# eps=0.5, min_samples=63, Silhouette Score=0.732
# eps=0.5, min_samples=64, Silhouette Score=0.728
# eps=0.5, min_samples=65, Silhouette Score=0.726
# eps=0.5, min_samples=66, Silhouette Score=0.726
# eps=0.5, min_samples=67, Silhouette Score=0.726
# eps=0.5, min_samples=68, Silhouette Score=0.726
# eps=0.5, min_samples=69, Silhouette Score=0.724
# eps=0.5, min_samples=70, Silhouette Score=0.724
# eps=0.5, min_samples=71, Silhouette Score=0.724
# eps=0.5, min_samples=72, Silhouette Score=0.724
# eps=0.5, min_samples=73, Silhouette Score=0.724
# eps=0.5, min_samples=74, Silhouette Score=0.724
# eps=0.5, min_samples=75, Silhouette Score=0.722
# eps=0.5, min_samples=76, Silhouette Score=0.722
# eps=0.5, min_samples=77, Silhouette Score=0.722
# eps=0.5, min_samples=78, Silhouette Score=0.722
# eps=0.5, min_samples=79, Silhouette Score=0.722
# eps=0.5, min_samples=80, Silhouette Score=0.722
# eps=0.5, min_samples=81, Silhouette Score=0.722
# eps=0.5, min_samples=82, Silhouette Score=0.722
# eps=0.5, min_samples=83, Silhouette Score=0.717
# eps=0.5, min_samples=84, Silhouette Score=0.717
# eps=0.5, min_samples=85, Silhouette Score=0.717
# eps=0.5, min_samples=86, Silhouette Score=0.715
# eps=0.5, min_samples=87, Silhouette Score=0.715
# eps=0.5, min_samples=88, Silhouette Score=0.715
# eps=0.5, min_samples=89, Silhouette Score=0.715
# eps=0.5, min_samples=90, Silhouette Score=0.715
# eps=0.5, min_samples=91, Silhouette Score=0.710
# eps=0.5, min_samples=92, Silhouette Score=0.710
# eps=0.5, min_samples=93, Silhouette Score=0.709
# eps=0.5, min_samples=94, Silhouette Score=0.707
# eps=0.5, min_samples=95, Silhouette Score=0.707
# eps=0.5, min_samples=96, Silhouette Score=0.705
# eps=0.5, min_samples=97, Silhouette Score=0.705
# eps=0.5, min_samples=98, Silhouette Score=0.705
# eps=0.5, min_samples=99, Silhouette Score=0.705
# eps=0.5, min_samples=100, Silhouette Score=0.703
# eps=0.6, min_samples=1, Silhouette Score=0.765
# eps=0.6, min_samples=2, Silhouette Score=0.765
# eps=0.6, min_samples=3, Silhouette Score=0.774
# eps=0.6, min_samples=4, Silhouette Score=0.774
# eps=0.6, min_samples=5, Silhouette Score=0.774
# eps=0.6, min_samples=6, Silhouette Score=0.774
# eps=0.6, min_samples=7, Silhouette Score=0.748
# eps=0.6, min_samples=8, Silhouette Score=0.771
# eps=0.6, min_samples=9, Silhouette Score=0.769
# eps=0.6, min_samples=10, Silhouette Score=0.769
# eps=0.6, min_samples=11, Silhouette Score=0.766
# eps=0.6, min_samples=12, Silhouette Score=0.766
# eps=0.6, min_samples=13, Silhouette Score=0.766
# eps=0.6, min_samples=14, Silhouette Score=0.766
# eps=0.6, min_samples=15, Silhouette Score=0.766
# eps=0.6, min_samples=16, Silhouette Score=0.766
# eps=0.6, min_samples=17, Silhouette Score=0.766
# eps=0.6, min_samples=18, Silhouette Score=0.764
# eps=0.6, min_samples=19, Silhouette Score=0.764
# eps=0.6, min_samples=20, Silhouette Score=0.764
# eps=0.6, min_samples=21, Silhouette Score=0.761
# eps=0.6, min_samples=22, Silhouette Score=0.761
# eps=0.6, min_samples=23, Silhouette Score=0.761
# eps=0.6, min_samples=24, Silhouette Score=0.760
# eps=0.6, min_samples=25, Silhouette Score=0.760
# eps=0.6, min_samples=26, Silhouette Score=0.760
# eps=0.6, min_samples=27, Silhouette Score=0.760
# eps=0.6, min_samples=28, Silhouette Score=0.760
# eps=0.6, min_samples=29, Silhouette Score=0.760
# eps=0.6, min_samples=30, Silhouette Score=0.760
# eps=0.6, min_samples=31, Silhouette Score=0.755
# eps=0.6, min_samples=32, Silhouette Score=0.755
# eps=0.6, min_samples=33, Silhouette Score=0.755
# eps=0.6, min_samples=34, Silhouette Score=0.755
# eps=0.6, min_samples=35, Silhouette Score=0.755
# eps=0.6, min_samples=36, Silhouette Score=0.755
# eps=0.6, min_samples=37, Silhouette Score=0.751
# eps=0.6, min_samples=38, Silhouette Score=0.751
# eps=0.6, min_samples=39, Silhouette Score=0.764
# eps=0.6, min_samples=40, Silhouette Score=0.764
# eps=0.6, min_samples=41, Silhouette Score=0.764
# eps=0.6, min_samples=42, Silhouette Score=0.761
# eps=0.6, min_samples=43, Silhouette Score=0.761
# eps=0.6, min_samples=44, Silhouette Score=0.761
# eps=0.6, min_samples=45, Silhouette Score=0.761
# eps=0.6, min_samples=46, Silhouette Score=0.761
# eps=0.6, min_samples=47, Silhouette Score=0.757
# eps=0.6, min_samples=48, Silhouette Score=0.757
# eps=0.6, min_samples=49, Silhouette Score=0.757
# eps=0.6, min_samples=50, Silhouette Score=0.757
# eps=0.6, min_samples=51, Silhouette Score=0.757
# eps=0.6, min_samples=52, Silhouette Score=0.757
# eps=0.6, min_samples=53, Silhouette Score=0.757
# eps=0.6, min_samples=54, Silhouette Score=0.757
# eps=0.6, min_samples=55, Silhouette Score=0.757
# eps=0.6, min_samples=56, Silhouette Score=0.757
# eps=0.6, min_samples=57, Silhouette Score=0.757
# eps=0.6, min_samples=58, Silhouette Score=0.757
# eps=0.6, min_samples=59, Silhouette Score=0.757
# eps=0.6, min_samples=60, Silhouette Score=0.752
# eps=0.6, min_samples=61, Silhouette Score=0.752
# eps=0.6, min_samples=62, Silhouette Score=0.752
# eps=0.6, min_samples=63, Silhouette Score=0.752
# eps=0.6, min_samples=64, Silhouette Score=0.752
# eps=0.6, min_samples=65, Silhouette Score=0.752
# eps=0.6, min_samples=66, Silhouette Score=0.752
# eps=0.6, min_samples=67, Silhouette Score=0.752
# eps=0.6, min_samples=68, Silhouette Score=0.752
# eps=0.6, min_samples=69, Silhouette Score=0.752
# eps=0.6, min_samples=70, Silhouette Score=0.752
# eps=0.6, min_samples=71, Silhouette Score=0.752
# eps=0.6, min_samples=72, Silhouette Score=0.752
# eps=0.6, min_samples=73, Silhouette Score=0.752
# eps=0.6, min_samples=74, Silhouette Score=0.752
# eps=0.6, min_samples=75, Silhouette Score=0.752
# eps=0.6, min_samples=76, Silhouette Score=0.752
# eps=0.6, min_samples=77, Silhouette Score=0.752
# eps=0.6, min_samples=78, Silhouette Score=0.742
# eps=0.6, min_samples=79, Silhouette Score=0.742
# eps=0.6, min_samples=80, Silhouette Score=0.742
# eps=0.6, min_samples=81, Silhouette Score=0.742
# eps=0.6, min_samples=82, Silhouette Score=0.742
# eps=0.6, min_samples=83, Silhouette Score=0.742
# eps=0.6, min_samples=84, Silhouette Score=0.738
# eps=0.6, min_samples=85, Silhouette Score=0.738
# eps=0.6, min_samples=86, Silhouette Score=0.738
# eps=0.6, min_samples=87, Silhouette Score=0.733
# eps=0.6, min_samples=88, Silhouette Score=0.733
# eps=0.6, min_samples=89, Silhouette Score=0.733
# eps=0.6, min_samples=90, Silhouette Score=0.733
# eps=0.6, min_samples=91, Silhouette Score=0.733
# eps=0.6, min_samples=92, Silhouette Score=0.733
# eps=0.6, min_samples=93, Silhouette Score=0.733
# eps=0.6, min_samples=94, Silhouette Score=0.733
# eps=0.6, min_samples=95, Silhouette Score=0.733
# eps=0.6, min_samples=96, Silhouette Score=0.733
# eps=0.6, min_samples=97, Silhouette Score=0.733
# eps=0.6, min_samples=98, Silhouette Score=0.733
# eps=0.6, min_samples=99, Silhouette Score=0.733
# eps=0.6, min_samples=100, Silhouette Score=0.728
# eps=0.7, min_samples=1, Silhouette Score=0.765
# eps=0.7, min_samples=2, Silhouette Score=0.765
# eps=0.7, min_samples=3, Silhouette Score=0.774
# eps=0.7, min_samples=4, Silhouette Score=0.774
# eps=0.7, min_samples=5, Silhouette Score=0.774
# eps=0.7, min_samples=6, Silhouette Score=0.774
# eps=0.7, min_samples=7, Silhouette Score=0.774
# eps=0.7, min_samples=8, Silhouette Score=0.742
# eps=0.7, min_samples=9, Silhouette Score=0.771
# eps=0.7, min_samples=10, Silhouette Score=0.771
# eps=0.7, min_samples=11, Silhouette Score=0.771
# eps=0.7, min_samples=12, Silhouette Score=0.771
# eps=0.7, min_samples=13, Silhouette Score=0.768
# eps=0.7, min_samples=14, Silhouette Score=0.768
# eps=0.7, min_samples=15, Silhouette Score=0.768
# eps=0.7, min_samples=16, Silhouette Score=0.767
# eps=0.7, min_samples=17, Silhouette Score=0.767
# eps=0.7, min_samples=18, Silhouette Score=0.767
# eps=0.7, min_samples=19, Silhouette Score=0.766
# eps=0.7, min_samples=20, Silhouette Score=0.766
# eps=0.7, min_samples=21, Silhouette Score=0.766
# eps=0.7, min_samples=22, Silhouette Score=0.766
# eps=0.7, min_samples=23, Silhouette Score=0.766
# eps=0.7, min_samples=24, Silhouette Score=0.766
# eps=0.7, min_samples=25, Silhouette Score=0.764
# eps=0.7, min_samples=26, Silhouette Score=0.764
# eps=0.7, min_samples=27, Silhouette Score=0.764
# eps=0.7, min_samples=28, Silhouette Score=0.764
# eps=0.7, min_samples=29, Silhouette Score=0.764
# eps=0.7, min_samples=30, Silhouette Score=0.764
# eps=0.7, min_samples=31, Silhouette Score=0.764
# eps=0.7, min_samples=32, Silhouette Score=0.764
# eps=0.7, min_samples=33, Silhouette Score=0.764
# eps=0.7, min_samples=34, Silhouette Score=0.764
# eps=0.7, min_samples=35, Silhouette Score=0.762
# eps=0.7, min_samples=36, Silhouette Score=0.762
# eps=0.7, min_samples=37, Silhouette Score=0.762
# eps=0.7, min_samples=38, Silhouette Score=0.762
# eps=0.7, min_samples=39, Silhouette Score=0.760
# eps=0.7, min_samples=40, Silhouette Score=0.760
# eps=0.7, min_samples=41, Silhouette Score=0.768
# eps=0.7, min_samples=42, Silhouette Score=0.768
# eps=0.7, min_samples=43, Silhouette Score=0.768
# eps=0.7, min_samples=44, Silhouette Score=0.766
# eps=0.7, min_samples=45, Silhouette Score=0.764
# eps=0.7, min_samples=46, Silhouette Score=0.764
# eps=0.7, min_samples=47, Silhouette Score=0.764
# eps=0.7, min_samples=48, Silhouette Score=0.764
# eps=0.7, min_samples=49, Silhouette Score=0.764
# eps=0.7, min_samples=50, Silhouette Score=0.764
# eps=0.7, min_samples=51, Silhouette Score=0.764
# eps=0.7, min_samples=52, Silhouette Score=0.764
# eps=0.7, min_samples=53, Silhouette Score=0.764
# eps=0.7, min_samples=54, Silhouette Score=0.764
# eps=0.7, min_samples=55, Silhouette Score=0.764
# eps=0.7, min_samples=56, Silhouette Score=0.764
# eps=0.7, min_samples=57, Silhouette Score=0.764
# eps=0.7, min_samples=58, Silhouette Score=0.761
# eps=0.7, min_samples=59, Silhouette Score=0.761
# eps=0.7, min_samples=60, Silhouette Score=0.761
# eps=0.7, min_samples=61, Silhouette Score=0.761
# eps=0.7, min_samples=62, Silhouette Score=0.761
# eps=0.7, min_samples=63, Silhouette Score=0.761
# eps=0.7, min_samples=64, Silhouette Score=0.761
# eps=0.7, min_samples=65, Silhouette Score=0.759
# eps=0.7, min_samples=66, Silhouette Score=0.759
# eps=0.7, min_samples=67, Silhouette Score=0.759
# eps=0.7, min_samples=68, Silhouette Score=0.757
# eps=0.7, min_samples=69, Silhouette Score=0.757
# eps=0.7, min_samples=70, Silhouette Score=0.757
# eps=0.7, min_samples=71, Silhouette Score=0.757
# eps=0.7, min_samples=72, Silhouette Score=0.757
# eps=0.7, min_samples=73, Silhouette Score=0.757
# eps=0.7, min_samples=74, Silhouette Score=0.757
# eps=0.7, min_samples=75, Silhouette Score=0.757
# eps=0.7, min_samples=76, Silhouette Score=0.757
# eps=0.7, min_samples=77, Silhouette Score=0.757
# eps=0.7, min_samples=78, Silhouette Score=0.757
# eps=0.7, min_samples=79, Silhouette Score=0.757
# eps=0.7, min_samples=80, Silhouette Score=0.757
# eps=0.7, min_samples=81, Silhouette Score=0.757
# eps=0.7, min_samples=82, Silhouette Score=0.757
# eps=0.7, min_samples=83, Silhouette Score=0.757
# eps=0.7, min_samples=84, Silhouette Score=0.757
# eps=0.7, min_samples=85, Silhouette Score=0.757
# eps=0.7, min_samples=86, Silhouette Score=0.757
# eps=0.7, min_samples=87, Silhouette Score=0.757
# eps=0.7, min_samples=88, Silhouette Score=0.757
# eps=0.7, min_samples=89, Silhouette Score=0.757
# eps=0.7, min_samples=90, Silhouette Score=0.757
# eps=0.7, min_samples=91, Silhouette Score=0.757
# eps=0.7, min_samples=92, Silhouette Score=0.757
# eps=0.7, min_samples=93, Silhouette Score=0.757
# eps=0.7, min_samples=94, Silhouette Score=0.757
# eps=0.7, min_samples=95, Silhouette Score=0.757
# eps=0.7, min_samples=96, Silhouette Score=0.757
# eps=0.7, min_samples=97, Silhouette Score=0.757
# eps=0.7, min_samples=98, Silhouette Score=0.757
# eps=0.7, min_samples=99, Silhouette Score=0.757
# eps=0.7, min_samples=100, Silhouette Score=0.757
# eps=0.8, min_samples=1, Silhouette Score=0.765
# eps=0.8, min_samples=2, Silhouette Score=0.765
# eps=0.8, min_samples=3, Silhouette Score=0.774
# eps=0.8, min_samples=4, Silhouette Score=0.774
# eps=0.8, min_samples=5, Silhouette Score=0.774
# eps=0.8, min_samples=6, Silhouette Score=0.774
# eps=0.8, min_samples=7, Silhouette Score=0.774
# eps=0.8, min_samples=8, Silhouette Score=0.774
# eps=0.8, min_samples=9, Silhouette Score=0.774
# eps=0.8, min_samples=10, Silhouette Score=0.772
# eps=0.8, min_samples=11, Silhouette Score=0.772
# eps=0.8, min_samples=12, Silhouette Score=0.771
# eps=0.8, min_samples=13, Silhouette Score=0.771
# eps=0.8, min_samples=14, Silhouette Score=0.771
# eps=0.8, min_samples=15, Silhouette Score=0.771
# eps=0.8, min_samples=16, Silhouette Score=0.771
# eps=0.8, min_samples=17, Silhouette Score=0.770
# eps=0.8, min_samples=18, Silhouette Score=0.770
# eps=0.8, min_samples=19, Silhouette Score=0.769
# eps=0.8, min_samples=20, Silhouette Score=0.769
# eps=0.8, min_samples=21, Silhouette Score=0.769
# eps=0.8, min_samples=22, Silhouette Score=0.769
# eps=0.8, min_samples=23, Silhouette Score=0.769
# eps=0.8, min_samples=24, Silhouette Score=0.769
# eps=0.8, min_samples=25, Silhouette Score=0.769
# eps=0.8, min_samples=26, Silhouette Score=0.769
# eps=0.8, min_samples=27, Silhouette Score=0.769
# eps=0.8, min_samples=28, Silhouette Score=0.769
# eps=0.8, min_samples=29, Silhouette Score=0.765
# eps=0.8, min_samples=30, Silhouette Score=0.765
# eps=0.8, min_samples=31, Silhouette Score=0.765
# eps=0.8, min_samples=32, Silhouette Score=0.764
# eps=0.8, min_samples=33, Silhouette Score=0.764
# eps=0.8, min_samples=34, Silhouette Score=0.764
# eps=0.8, min_samples=35, Silhouette Score=0.764
# eps=0.8, min_samples=36, Silhouette Score=0.764
# eps=0.8, min_samples=37, Silhouette Score=0.764
# eps=0.8, min_samples=38, Silhouette Score=0.764
# eps=0.8, min_samples=39, Silhouette Score=0.764
# eps=0.8, min_samples=40, Silhouette Score=0.764
# eps=0.8, min_samples=41, Silhouette Score=0.760
# eps=0.8, min_samples=42, Silhouette Score=0.760
# eps=0.8, min_samples=43, Silhouette Score=0.771
# eps=0.8, min_samples=44, Silhouette Score=0.771
# eps=0.8, min_samples=45, Silhouette Score=0.771
# eps=0.8, min_samples=46, Silhouette Score=0.771
# eps=0.8, min_samples=47, Silhouette Score=0.771
# eps=0.8, min_samples=48, Silhouette Score=0.771
# eps=0.8, min_samples=49, Silhouette Score=0.771
# eps=0.8, min_samples=50, Silhouette Score=0.771
# eps=0.8, min_samples=51, Silhouette Score=0.771
# eps=0.8, min_samples=52, Silhouette Score=0.771
# eps=0.8, min_samples=53, Silhouette Score=0.771
# eps=0.8, min_samples=54, Silhouette Score=0.771
# eps=0.8, min_samples=55, Silhouette Score=0.771
# eps=0.8, min_samples=56, Silhouette Score=0.771
# eps=0.8, min_samples=57, Silhouette Score=0.771
# eps=0.8, min_samples=58, Silhouette Score=0.771
# eps=0.8, min_samples=59, Silhouette Score=0.771
# eps=0.8, min_samples=60, Silhouette Score=0.771
# eps=0.8, min_samples=61, Silhouette Score=0.767
# eps=0.8, min_samples=62, Silhouette Score=0.767
# eps=0.8, min_samples=63, Silhouette Score=0.767
# eps=0.8, min_samples=64, Silhouette Score=0.767
# eps=0.8, min_samples=65, Silhouette Score=0.767
# eps=0.8, min_samples=66, Silhouette Score=0.767
# eps=0.8, min_samples=67, Silhouette Score=0.767
# eps=0.8, min_samples=68, Silhouette Score=0.767
# eps=0.8, min_samples=69, Silhouette Score=0.767
# eps=0.8, min_samples=70, Silhouette Score=0.767
# eps=0.8, min_samples=71, Silhouette Score=0.767
# eps=0.8, min_samples=72, Silhouette Score=0.767
# eps=0.8, min_samples=73, Silhouette Score=0.767
# eps=0.8, min_samples=74, Silhouette Score=0.767
# eps=0.8, min_samples=75, Silhouette Score=0.765
# eps=0.8, min_samples=76, Silhouette Score=0.763
# eps=0.8, min_samples=77, Silhouette Score=0.763
# eps=0.8, min_samples=78, Silhouette Score=0.763
# eps=0.8, min_samples=79, Silhouette Score=0.763
# eps=0.8, min_samples=80, Silhouette Score=0.763
# eps=0.8, min_samples=81, Silhouette Score=0.763
# eps=0.8, min_samples=82, Silhouette Score=0.763
# eps=0.8, min_samples=83, Silhouette Score=0.763
# eps=0.8, min_samples=84, Silhouette Score=0.763
# eps=0.8, min_samples=85, Silhouette Score=0.761
# eps=0.8, min_samples=86, Silhouette Score=0.761
# eps=0.8, min_samples=87, Silhouette Score=0.761
# eps=0.8, min_samples=88, Silhouette Score=0.761
# eps=0.8, min_samples=89, Silhouette Score=0.761
# eps=0.8, min_samples=90, Silhouette Score=0.761
# eps=0.8, min_samples=91, Silhouette Score=0.761
# eps=0.8, min_samples=92, Silhouette Score=0.759
# eps=0.8, min_samples=93, Silhouette Score=0.759
# eps=0.8, min_samples=94, Silhouette Score=0.757
# eps=0.8, min_samples=95, Silhouette Score=0.757
# eps=0.8, min_samples=96, Silhouette Score=0.757
# eps=0.8, min_samples=97, Silhouette Score=0.757
# eps=0.8, min_samples=98, Silhouette Score=0.757
# eps=0.8, min_samples=99, Silhouette Score=0.757
# eps=0.8, min_samples=100, Silhouette Score=0.757
# eps=0.9, min_samples=1, Silhouette Score=0.765
# eps=0.9, min_samples=2, Silhouette Score=0.765
# eps=0.9, min_samples=3, Silhouette Score=0.774
# eps=0.9, min_samples=4, Silhouette Score=0.774
# eps=0.9, min_samples=5, Silhouette Score=0.774
# eps=0.9, min_samples=6, Silhouette Score=0.774
# eps=0.9, min_samples=7, Silhouette Score=0.774
# eps=0.9, min_samples=8, Silhouette Score=0.774
# eps=0.9, min_samples=9, Silhouette Score=0.774
# eps=0.9, min_samples=10, Silhouette Score=0.772
# eps=0.9, min_samples=11, Silhouette Score=0.772
# eps=0.9, min_samples=12, Silhouette Score=0.771
# eps=0.9, min_samples=13, Silhouette Score=0.771
# eps=0.9, min_samples=14, Silhouette Score=0.771
# eps=0.9, min_samples=15, Silhouette Score=0.771
# eps=0.9, min_samples=16, Silhouette Score=0.771
# eps=0.9, min_samples=17, Silhouette Score=0.771
# eps=0.9, min_samples=18, Silhouette Score=0.771
# eps=0.9, min_samples=19, Silhouette Score=0.771
# eps=0.9, min_samples=20, Silhouette Score=0.771
# eps=0.9, min_samples=21, Silhouette Score=0.771
# eps=0.9, min_samples=22, Silhouette Score=0.771
# eps=0.9, min_samples=23, Silhouette Score=0.771
# eps=0.9, min_samples=24, Silhouette Score=0.771
# eps=0.9, min_samples=25, Silhouette Score=0.771
# eps=0.9, min_samples=26, Silhouette Score=0.771
# eps=0.9, min_samples=27, Silhouette Score=0.771
# eps=0.9, min_samples=28, Silhouette Score=0.771
# eps=0.9, min_samples=29, Silhouette Score=0.771
# eps=0.9, min_samples=30, Silhouette Score=0.771
# eps=0.9, min_samples=31, Silhouette Score=0.768
# eps=0.9, min_samples=32, Silhouette Score=0.768
# eps=0.9, min_samples=33, Silhouette Score=0.767
# eps=0.9, min_samples=34, Silhouette Score=0.767
# eps=0.9, min_samples=35, Silhouette Score=0.767
# eps=0.9, min_samples=36, Silhouette Score=0.767
# eps=0.9, min_samples=37, Silhouette Score=0.767
# eps=0.9, min_samples=38, Silhouette Score=0.767
# eps=0.9, min_samples=39, Silhouette Score=0.766
# eps=0.9, min_samples=40, Silhouette Score=0.766
# eps=0.9, min_samples=41, Silhouette Score=0.766
# eps=0.9, min_samples=42, Silhouette Score=0.766
# eps=0.9, min_samples=43, Silhouette Score=0.771
# eps=0.9, min_samples=44, Silhouette Score=0.771
# eps=0.9, min_samples=45, Silhouette Score=0.771
# eps=0.9, min_samples=46, Silhouette Score=0.771
# eps=0.9, min_samples=47, Silhouette Score=0.771
# eps=0.9, min_samples=48, Silhouette Score=0.771
# eps=0.9, min_samples=49, Silhouette Score=0.771
# eps=0.9, min_samples=50, Silhouette Score=0.771
# eps=0.9, min_samples=51, Silhouette Score=0.771
# eps=0.9, min_samples=52, Silhouette Score=0.771
# eps=0.9, min_samples=53, Silhouette Score=0.771
# eps=0.9, min_samples=54, Silhouette Score=0.771
# eps=0.9, min_samples=55, Silhouette Score=0.771
# eps=0.9, min_samples=56, Silhouette Score=0.771
# eps=0.9, min_samples=57, Silhouette Score=0.771
# eps=0.9, min_samples=58, Silhouette Score=0.771
# eps=0.9, min_samples=59, Silhouette Score=0.771
# eps=0.9, min_samples=60, Silhouette Score=0.771
# eps=0.9, min_samples=61, Silhouette Score=0.771
# eps=0.9, min_samples=62, Silhouette Score=0.771
# eps=0.9, min_samples=63, Silhouette Score=0.771
# eps=0.9, min_samples=64, Silhouette Score=0.771
# eps=0.9, min_samples=65, Silhouette Score=0.771
# eps=0.9, min_samples=66, Silhouette Score=0.771
# eps=0.9, min_samples=67, Silhouette Score=0.771
# eps=0.9, min_samples=68, Silhouette Score=0.771
# eps=0.9, min_samples=69, Silhouette Score=0.771
# eps=0.9, min_samples=70, Silhouette Score=0.771
# eps=0.9, min_samples=71, Silhouette Score=0.771
# eps=0.9, min_samples=72, Silhouette Score=0.771
# eps=0.9, min_samples=73, Silhouette Score=0.771
# eps=0.9, min_samples=74, Silhouette Score=0.771
# eps=0.9, min_samples=75, Silhouette Score=0.771
# eps=0.9, min_samples=76, Silhouette Score=0.771
# eps=0.9, min_samples=77, Silhouette Score=0.767
# eps=0.9, min_samples=78, Silhouette Score=0.767
# eps=0.9, min_samples=79, Silhouette Score=0.767
# eps=0.9, min_samples=80, Silhouette Score=0.767
# eps=0.9, min_samples=81, Silhouette Score=0.767
# eps=0.9, min_samples=82, Silhouette Score=0.767
# eps=0.9, min_samples=83, Silhouette Score=0.767
# eps=0.9, min_samples=84, Silhouette Score=0.767
# eps=0.9, min_samples=85, Silhouette Score=0.767
# eps=0.9, min_samples=86, Silhouette Score=0.767
# eps=0.9, min_samples=87, Silhouette Score=0.767
# eps=0.9, min_samples=88, Silhouette Score=0.767
# eps=0.9, min_samples=89, Silhouette Score=0.767
# eps=0.9, min_samples=90, Silhouette Score=0.767
# eps=0.9, min_samples=91, Silhouette Score=0.767
# eps=0.9, min_samples=92, Silhouette Score=0.767
# eps=0.9, min_samples=93, Silhouette Score=0.767
# eps=0.9, min_samples=94, Silhouette Score=0.767
# eps=0.9, min_samples=95, Silhouette Score=0.767
# eps=0.9, min_samples=96, Silhouette Score=0.767
# eps=0.9, min_samples=97, Silhouette Score=0.767
# eps=0.9, min_samples=98, Silhouette Score=0.767
# eps=0.9, min_samples=99, Silhouette Score=0.767
# eps=0.9, min_samples=100, Silhouette Score=0.767
# eps=1.0, min_samples=1, Silhouette Score=0.765
# eps=1.0, min_samples=2, Silhouette Score=0.765
# eps=1.0, min_samples=3, Silhouette Score=0.774
# eps=1.0, min_samples=4, Silhouette Score=0.774
# eps=1.0, min_samples=5, Silhouette Score=0.774
# eps=1.0, min_samples=6, Silhouette Score=0.774
# eps=1.0, min_samples=7, Silhouette Score=0.774
# eps=1.0, min_samples=8, Silhouette Score=0.774
# eps=1.0, min_samples=9, Silhouette Score=0.774
# eps=1.0, min_samples=10, Silhouette Score=0.772
# eps=1.0, min_samples=11, Silhouette Score=0.772
# eps=1.0, min_samples=12, Silhouette Score=0.772
# eps=1.0, min_samples=13, Silhouette Score=0.771
# eps=1.0, min_samples=14, Silhouette Score=0.771
# eps=1.0, min_samples=15, Silhouette Score=0.771
# eps=1.0, min_samples=16, Silhouette Score=0.771
# eps=1.0, min_samples=17, Silhouette Score=0.771
# eps=1.0, min_samples=18, Silhouette Score=0.771
# eps=1.0, min_samples=19, Silhouette Score=0.771
# eps=1.0, min_samples=20, Silhouette Score=0.771
# eps=1.0, min_samples=21, Silhouette Score=0.771
# eps=1.0, min_samples=22, Silhouette Score=0.771
# eps=1.0, min_samples=23, Silhouette Score=0.771
# eps=1.0, min_samples=24, Silhouette Score=0.771
# eps=1.0, min_samples=25, Silhouette Score=0.771
# eps=1.0, min_samples=26, Silhouette Score=0.771
# eps=1.0, min_samples=27, Silhouette Score=0.771
# eps=1.0, min_samples=28, Silhouette Score=0.771
# eps=1.0, min_samples=29, Silhouette Score=0.771
# eps=1.0, min_samples=30, Silhouette Score=0.771
# eps=1.0, min_samples=31, Silhouette Score=0.771
# eps=1.0, min_samples=32, Silhouette Score=0.771
# eps=1.0, min_samples=33, Silhouette Score=0.771
# eps=1.0, min_samples=34, Silhouette Score=0.771
# eps=1.0, min_samples=35, Silhouette Score=0.771
# eps=1.0, min_samples=36, Silhouette Score=0.771
# eps=1.0, min_samples=37, Silhouette Score=0.768
# eps=1.0, min_samples=38, Silhouette Score=0.768
# eps=1.0, min_samples=39, Silhouette Score=0.768
# eps=1.0, min_samples=40, Silhouette Score=0.768
# eps=1.0, min_samples=41, Silhouette Score=0.768
# eps=1.0, min_samples=42, Silhouette Score=0.768
# eps=1.0, min_samples=43, Silhouette Score=0.766
# eps=1.0, min_samples=44, Silhouette Score=0.766
# eps=1.0, min_samples=45, Silhouette Score=0.771
# eps=1.0, min_samples=46, Silhouette Score=0.771
# eps=1.0, min_samples=47, Silhouette Score=0.771
# eps=1.0, min_samples=48, Silhouette Score=0.771
# eps=1.0, min_samples=49, Silhouette Score=0.771
# eps=1.0, min_samples=50, Silhouette Score=0.771
# eps=1.0, min_samples=51, Silhouette Score=0.771
# eps=1.0, min_samples=52, Silhouette Score=0.771
# eps=1.0, min_samples=53, Silhouette Score=0.771
# eps=1.0, min_samples=54, Silhouette Score=0.771
# eps=1.0, min_samples=55, Silhouette Score=0.771
# eps=1.0, min_samples=56, Silhouette Score=0.771
# eps=1.0, min_samples=57, Silhouette Score=0.771
# eps=1.0, min_samples=58, Silhouette Score=0.771
# eps=1.0, min_samples=59, Silhouette Score=0.771
# eps=1.0, min_samples=60, Silhouette Score=0.771
# eps=1.0, min_samples=61, Silhouette Score=0.771
# eps=1.0, min_samples=62, Silhouette Score=0.771
# eps=1.0, min_samples=63, Silhouette Score=0.771
# eps=1.0, min_samples=64, Silhouette Score=0.771
# eps=1.0, min_samples=65, Silhouette Score=0.771
# eps=1.0, min_samples=66, Silhouette Score=0.771
# eps=1.0, min_samples=67, Silhouette Score=0.771
# eps=1.0, min_samples=68, Silhouette Score=0.771
# eps=1.0, min_samples=69, Silhouette Score=0.771
# eps=1.0, min_samples=70, Silhouette Score=0.771
# eps=1.0, min_samples=71, Silhouette Score=0.771
# eps=1.0, min_samples=72, Silhouette Score=0.771
# eps=1.0, min_samples=73, Silhouette Score=0.771
# eps=1.0, min_samples=74, Silhouette Score=0.771
# eps=1.0, min_samples=75, Silhouette Score=0.771
# eps=1.0, min_samples=76, Silhouette Score=0.771
# eps=1.0, min_samples=77, Silhouette Score=0.771
# eps=1.0, min_samples=78, Silhouette Score=0.771
# eps=1.0, min_samples=79, Silhouette Score=0.771
# eps=1.0, min_samples=80, Silhouette Score=0.771
# eps=1.0, min_samples=81, Silhouette Score=0.771
# eps=1.0, min_samples=82, Silhouette Score=0.771
# eps=1.0, min_samples=83, Silhouette Score=0.771
# eps=1.0, min_samples=84, Silhouette Score=0.771
# eps=1.0, min_samples=85, Silhouette Score=0.771
# eps=1.0, min_samples=86, Silhouette Score=0.771
# eps=1.0, min_samples=87, Silhouette Score=0.771
# eps=1.0, min_samples=88, Silhouette Score=0.771
# eps=1.0, min_samples=89, Silhouette Score=0.771
# eps=1.0, min_samples=90, Silhouette Score=0.771
# eps=1.0, min_samples=91, Silhouette Score=0.771
# eps=1.0, min_samples=92, Silhouette Score=0.771
# eps=1.0, min_samples=93, Silhouette Score=0.771
# eps=1.0, min_samples=94, Silhouette Score=0.771
# eps=1.0, min_samples=95, Silhouette Score=0.771
# eps=1.0, min_samples=96, Silhouette Score=0.771
# eps=1.0, min_samples=97, Silhouette Score=0.771
# eps=1.0, min_samples=98, Silhouette Score=0.771
# eps=1.0, min_samples=99, Silhouette Score=0.771
# eps=1.0, min_samples=100, Silhouette Score=0.771
#
# Best Parameters:
# eps=0.5, min_samples=3, Best Silhouette Score=0.774
#
# Cluster Distribution:
#  0    943
#  1     52
# -1      5
# Name: cluster, dtype: int64

# %%
data.keys()
# Out:
# dict_keys(['info', 'playlists'])
