# %%
import pandas as pd

# %%
df = pd.read_csv("cats.csv")

# %%
df.columns
# Out:
# Index(['Breed', 'Age (Years)', 'Weight (kg)', 'Color', 'Gender', 'ID'], dtype='object')

# %%
df.head()
# Out:
#            Breed  Age (Years)  Weight (kg)          Color  Gender   ID
# 0   Egyptian Mau           12            7          White    Male  181
# 1  Scottish Fold           17            8  Tortoiseshell    Male  907
# 2         Sphynx            9            9         Orange    Male  732
# 3       Oriental            6            7           Gray  Female  464
# 4       Savannah           14            7  Tortoiseshell  Female  451

# %%
df.drop(['Unnamed: 0'], inplace=True, axis=1)

# %%
df[99:100]
# Out:
#           Breed  Age (Years)  Weight (kg)    Color  Gender   ID
# 99  Cornish Rex           11            6  Bicolor  Female  527

# %%
new_row = pd.DataFrame([{'Breed: Tabby', 'Age(Years): 3', 'Weight (kg): 5', 'Color: Orange', 'Gender: Male', 'ID: 998'}])

# %%
df = pd.concat([df, new_row], ignore_index=False)

# %%
df.head(1003)
# Out:
#               Breed  Age (Years)  Weight (kg)          Color  Gender     ID  \
# 0      Egyptian Mau         12.0          7.0          White    Male  181.0
# 1     Scottish Fold         17.0          8.0  Tortoiseshell    Male  907.0
# 2            Sphynx          9.0          9.0         Orange    Male  732.0
# 3          Oriental          6.0          7.0           Gray  Female  464.0
# 4          Savannah         14.0          7.0  Tortoiseshell  Female  451.0
# ...             ...          ...          ...            ...     ...    ...
# 997         Persian         19.0          9.0          Cream    Male  659.0
# 998         Persian         17.0          3.0        Bicolor  Female  124.0
# 999            Manx         18.0          8.0          Black    Male  226.0
# 1000            NaN          NaN          NaN            NaN     NaN    NaN
# 0               NaN          NaN          NaN            NaN     NaN    NaN
#
# ...

# %%
df.drop(1000)
# Out:
#              Breed  Age (Years)  Weight (kg)          Color  Gender     ID  \
# 0     Egyptian Mau         12.0          7.0          White    Male  181.0
# 1    Scottish Fold         17.0          8.0  Tortoiseshell    Male  907.0
# 2           Sphynx          9.0          9.0         Orange    Male  732.0
# 3         Oriental          6.0          7.0           Gray  Female  464.0
# 4         Savannah         14.0          7.0  Tortoiseshell  Female  451.0
# ..             ...          ...          ...            ...     ...    ...
# 996        Burmese          4.0          5.0        Pointed  Female  339.0
# 997        Persian         19.0          9.0          Cream    Male  659.0
# 998        Persian         17.0          3.0        Bicolor  Female  124.0
# 999           Manx         18.0          8.0          Black    Male  226.0
# 0              NaN          NaN          NaN            NaN     NaN    NaN
#
# ...

# %%
df.loc[98]
# Out:
# Breed          Maine Coon
# Age (Years)           9.0
# Weight (kg)           5.0
# Color                Blue
# Gender             Female
# ID                  590.0
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# Name: 98, dtype: object

# %%
df.loc[0]["Color"]
# Out:
# 0    White
# 0      NaN
# Name: Color, dtype: object

# %%
df.loc[len(df)] = ["Tabby", 3, 5, "Orange", "Male", len(df), 0, 1, 2, 3, 4, 5]

# %%
df.drop([1000], inplace=True, axis=0)

# %%
df.head()
# Out:
#            Breed  Age (Years)  Weight (kg)          Color  Gender     ID
# 0   Egyptian Mau         12.0          7.0          White    Male  181.0
# 1  Scottish Fold         17.0          8.0  Tortoiseshell    Male  907.0
# 2         Sphynx          9.0          9.0         Orange    Male  732.0
# 3       Oriental          6.0          7.0           Gray  Female  464.0
# 4       Savannah         14.0          7.0  Tortoiseshell  Female  451.0

# %%
df['Weight (lbs.)'] = df['Weight (kg)'] * 2.205

# %%
df.tail()
# Out:
#         Breed  Age (Years)  Weight (kg)    Color  Gender      ID  \
# 997   Persian         19.0          9.0    Cream    Male   659.0
# 998   Persian         17.0          3.0  Bicolor  Female   124.0
# 999      Manx         18.0          8.0    Black    Male   226.0
# 0         NaN          NaN          NaN      NaN     NaN     NaN
# 1002    Tabby          3.0          5.0   Orange    Male  1002.0
#
#       Weight (lbs.)
# 997          19.845
# 998           6.615
# 999          17.640
# 0               NaN
# 1002         11.025

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27832\1309216581.py in <module>
# ----> 1 df.loc[42]
#
# NameError: name 'df' is not defined
