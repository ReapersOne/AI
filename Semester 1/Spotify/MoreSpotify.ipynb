# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("spotify_songs.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
summary = {
    'Max': df['track_popularity'].max(),
    'Q3': df['track_popularity'].quantile(0.75),
    'Median': df['track_popularity'].median(),
    'Q1': df['track_popularity'].quantile(0.25),
    'Min': df['track_popularity'].min()
}
summary
# Out:
# {'Max': 100, 'Q3': 62.0, 'Median': 45.0, 'Q1': 24.0, 'Min': 0}

# %% [markdown]
# # Track Popularity
# ### Max: 100¶
# ### Q3: 62
# ### Median: 45
# ### Q1: 24
# ### Min: 0
# ##### The shape of the graph shows it is relatively normal, bell curve.
# #####

# %%
sns.histplot(df['track_popularity'], binsa=50 , kde=True)
# Out:
# <AxesSubplot:xlabel='track_popularity', ylabel='Count'>

# %%
sns.boxplot(data=df, x="track_popularity")
# Out:
# <AxesSubplot:xlabel='track_popularity'>

# %%
def avg(col):
    average = col.mean()
    return average

# %%
avg(df['tempo'])
# Out:
# 120.88113154448297

# %%
df['tempo'].median()
# Out:
# 121.984

# %%
avg(df['danceability'])
# Out:
# 0.6548495202996926

# %%
df['danceability'].std()
# Out:
# 0.14508532044765107

# %%
sns.histplot(df['danceability'], bins=50 , kde=True)
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='Count'>

# %%
df.loc[1551]
# Out:
# track_id                                               2XU0oxnq2qxCpomAAuJY8K
# track_name                                                       Dance Monkey
# track_artist                                                      Tones and I
# track_popularity                                                          100
# track_album_id                                         0UywfDKYlyiu1b38DRrzYD
# track_album_name                  Dance Monkey (Stripped Back) / Dance Monkey
# track_album_release_date                                           2019-10-17
# playlist_name               post-teen alternative, indie, pop (large variety)
# playlist_id                                            1y42gwI5cuwjBslPyQNfqb
# playlist_genre                                                            pop
# playlist_subgenre                                               post-teen pop
# danceability                                                            0.824
# ...

# %% [markdown]
# # Impressive with Tones and I's song "Dance Monkey"?
#
# ### I am impressed about the popularity score, considering if it is 100, almost everyone in the world should know this song. I am impressed because compare to the other songs, the popularity score is through the roof and the only song with a popularity score of 100. The only other song that comes into comparison is ROXXANE, which is a popularity score of 99.
#
# ###

# %%
target_count = 98
result = df[df['track_popularity'] == target_count]

# %%
result
# Out:
#                      track_id    track_name track_artist  track_popularity  \
# 1551   2XU0oxnq2qxCpomAAuJY8K  Dance Monkey  Tones and I               100
# 20091  2XU0oxnq2qxCpomAAuJY8K  Dance Monkey  Tones and I               100
#
#                track_album_id                             track_album_name  \
# 1551   0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
# 20091  0UywfDKYlyiu1b38DRrzYD  Dance Monkey (Stripped Back) / Dance Monkey
#
#       track_album_release_date  \
# 1551                2019-10-17
# 20091               2019-10-17
#
#                                            playlist_name  \
# 1551   post-teen alternative, indie, pop (large variety)
# 20091                          Global Top 50 | 2020 Hits
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 1551   1y42gwI5cuwjBslPyQNfqb            pop  ...   6      -6.4     0
# 20091  1KNl4AYfgZtOVm9KHkhPTF          latin  ...   6      -6.4     0
#
# ...

# %%
result
# Out:
#                      track_id track_name    track_artist  track_popularity  \
# 20092  696DnlkuDOXcMAnKlTgXXK    ROXANNE  Arizona Zervas                99
# 21468  696DnlkuDOXcMAnKlTgXXK    ROXANNE  Arizona Zervas                99
# 23104  696DnlkuDOXcMAnKlTgXXK    ROXANNE  Arizona Zervas                99
# 30202  696DnlkuDOXcMAnKlTgXXK    ROXANNE  Arizona Zervas                99
#
#                track_album_id track_album_name track_album_release_date  \
# 20092  6HJDrXs0hpebaRFKA1sF90          ROXANNE               2019-10-10
# 21468  6HJDrXs0hpebaRFKA1sF90          ROXANNE               2019-10-10
# 23104  6HJDrXs0hpebaRFKA1sF90          ROXANNE               2019-10-10
# 30202  6HJDrXs0hpebaRFKA1sF90          ROXANNE               2019-10-10
#
#                                            playlist_name  \
# 20092                          Global Top 50 | 2020 Hits
# 21468                                 Contemporary Urban
# ...

# %%
# Out:
#                      track_id       track_name track_artist  track_popularity  \
# 687    7k4t7uLgtOxPwTpFmtJNTY             Tusa      KAROL G                98
# 711    2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 716    0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 1300   2b8fOow8UzyDFAE27YhOZM         Memories     Maroon 5                98
# 1301   21jGcNKet2qwijlDFuPiPb          Circles  Post Malone                98
# 1605   0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 4713   0sf12qNH5qcw8qpgymFOqD  Blinding Lights   The Weeknd                98
# 5508   0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# 9018   0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# 11113  7k4t7uLgtOxPwTpFmtJNTY             Tusa      KAROL G                98
# 11184  0nbXyq5TXYPCO7pr3N8S4I          The Box  Roddy Ricch                98
# ...

# %%
df['track_popularity'].mean()
# Out:
# 42.477080985593766

# %%
df['track_popularity'].std()
# Out:
# 24.984074486186543

# %%
target_count = 1
result = df[df['energy'] == target_count]

# %%
result
# Out:
#                      track_id                            track_name  \
# 17004  5CwOUooch74h0XarhDfAQK  Rain Forest and Tropical Beach Sound
# 17009  37TdJ5EWlM9Jfw8IqiUHcm          Chill Waves & Wind in Leaves
# 17014  6ADPydLM8fmi6fjO9ZXAb8                           Forest Rain
#
#                      track_artist  track_popularity          track_album_id  \
# 17004  Nature Sounds Nature Music                52  3snlIBZinyiVAFjV6GCeoY
# 17009                Pinetree Way                57  4UvRUxM8fwrChyFg0fglnz
# 17014             Rain Recordings                75  4DlF8SX13AdB37uKVgMziM
#
#                                         track_album_name  \
# 17004  Nature Sounds - Nature Music for Sleep, Yoga a...
# 17009                                              Waves
# 17014                           Peaceful Rain Recordings
#
#       track_album_release_date    playlist_name             playlist_id  \
# 17004               2011-02-16  Tropical Nights  37i9dQZF1DX0ES2mnOVvai
# ...

# %%
df.loc[17004]
# Out:
# track_id                                               5CwOUooch74h0XarhDfAQK
# track_name                               Rain Forest and Tropical Beach Sound
# track_artist                                       Nature Sounds Nature Music
# track_popularity                                                           52
# track_album_id                                         3snlIBZinyiVAFjV6GCeoY
# track_album_name            Nature Sounds - Nature Music for Sleep, Yoga a...
# track_album_release_date                                           2011-02-16
# playlist_name                                                 Tropical Nights
# playlist_id                                            37i9dQZF1DX0ES2mnOVvai
# playlist_genre                                                          latin
# playlist_subgenre                                                    tropical
# danceability                                                             0.16
# ...

# %%
sns.histplot(df['energy'], bins=1000, kde=True)
# Out:
# <AxesSubplot:xlabel='energy', ylabel='Count'>

# %%
df['energy'].std()
# Out:
# 0.18091003391959035

# %% [markdown]
# # Which song has the most energy, and how does it compare to the other songs?

# %% [markdown]
# # Song(s) Energy Levels
#
# ### There are 3 songs with the MOST energy level, saying that it is not the BIGGEST outlier, but certain in the histogram plot it is an outlier.
#
# #### The 3 songs names are, "Rain Forest and Tropical Beach Sound", "Chill Waves & Wind in Leaves", and "Forest Rain".
#
# #### What suprises me about this is that these are not quite songs, but tracks people will listening along to while doing other things, which brings me the question. What does the Energy mean to this Data set? Because They said that the higher the energy, the more energy it has, like death metal. But these songs are not at all like death metal.

# %%
df_pop = df[df['playlist_genre'] == 'pop']
df_rap = df[df['playlist_genre'] == 'rap']

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19376\1078411226.py in <module>
#       6
#       7 # Plot histograms with overlay
# ----> 8 sns.histplot(df[df_pop], kde=False, color='blue', label='Pop', alpha=0.6, bins=30)
#       9 sns.histplot(df[df_rap], kde=False, color='red', label='Rap', alpha=0.6, bins=30)
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3490         # Do we have a (boolean) DataFrame?
#    3491         if isinstance(key, DataFrame):
# -> 3492             return self.where(key)
#    3493
#    3494         # Do we have a (boolean) 1d indexer?
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# ...

# %%
sns.histplot(data=df_pop, x ='speechiness', bins=50 , kde=False, color= 'purple')
sns.histplot(data=df_rap, x ='speechiness', bins=50, kde=False, color= 'green')
# Out:
# <AxesSubplot:xlabel='speechiness', ylabel='Count'>

# %%
pop_mean = df_pop['speechiness'].mean()
rap_mean = df_rap['speechiness'].mean()

# %%
# Out:
# 0.07399126566188474
