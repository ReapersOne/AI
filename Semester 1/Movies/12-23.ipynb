# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
english = pd.read_json("english_movies.json")
french = pd.read_json('french_movies.json')

# %%
english.head()
# Out:
#    adult                     backdrop_path  genre_ids       id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         18      278
# 1  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         18      278
# 2  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         80      278
# 3  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         80      278
# 4  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg         16  1184918
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en  The Shawshank Redemption
# 2                en  The Shawshank Redemption
# 3                en  The Shawshank Redemption
# 4                en            The Wild Robot
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     230.813
# 1  Imprisoned in the 1940s for the double murder ...     230.813
# 2  Imprisoned in the 1940s for the double murder ...     230.813
# ...

# %%
french.head()
# Out:
#    adult                     backdrop_path  genre_ids       id  \
# 0  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 1  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 2  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 3  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 4  False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
#
#   original_language            original_title  \
# 0                fr  Le Comte de Monte-Cristo
# 1                fr  Le Comte de Monte-Cristo
# 2                fr  Le Comte de Monte-Cristo
# 3                fr  Le Comte de Monte-Cristo
# 4                fr  Le Comte de Monte-Cristo
#
#                                             overview  popularity  \
# 0  Edmond Dantes becomes the target of a sinister...     170.237
# 1  Edmond Dantes becomes the target of a sinister...     170.237
# 2  Edmond Dantes becomes the target of a sinister...     170.237
# ...

# %%
print(len(english), len(french))
# Out:
# 730 692

# %%
english = english.drop_duplicates(subset=['id'])
english
# Out:
#      adult                     backdrop_path  genre_ids       id  \
# 0    False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         18      278
# 4    False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg         16  1184918
# 13   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg         18      238
# 17   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         18      240
# 21   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg         18      424
# ..     ...                               ...        ...      ...
# 703  False  /gZWl93sf8AxavYpVT1Un6EF3oCj.jpg         80   475557
# 712  False  /4GWYk5VP9qu1rNSeNAwNaBy9mwS.jpg      10751   399106
# 716  False  /pcDc2WJAYGJTTvRSEIpRZwM3Ola.jpg         28   791373
# 725  False  /aCHn2TXYJfzPXQKA6r9mKPbMlUB.jpg         35    37165
# 729  False  /6aoyUbvu0419XLKLIMoH0TkEicH.jpg         80      103
#
#     original_language                original_title  \
# 0                  en      The Shawshank Redemption
# 4                  en                The Wild Robot
# ...

# %%
french = french.drop_duplicates(subset=['id'])
french
# Out:
#      adult                     backdrop_path  genre_ids       id  \
# 0    False  /i9qxG4UVgfX4AdMGnfRzMYEowLQ.jpg         12  1084736
# 36   False  /bGksau9GGu0uJ8DJQ8DYc9JW5LM.jpg         18    77338
# 40   False  /f72GEQF2lKsdmEULSI9bWCbQylH.jpg         18    29259
# 49   False  /dIHezuC3AmylT8mkXQiWSjz2wJR.jpg         18   265177
# 50   False  /foFq1RZWQIgFuCQ0nyYccywjFyX.jpg         18   531428
# ..     ...                               ...        ...      ...
# 673  False  /rTNMyZ5JcrfKnPamaYOo9wzq3m5.jpg         35  1152014
# 674  False  /cSCxGf1YSsNj3YxIGeWjbLUC9Xl.jpg         18   660000
# 683  False  /sv8nSUSXb7ldLOg4dm6KDIDdSEU.jpg         35    14257
# 687  False  /edaW476pWD9l8t77dFjmnAtWUmR.jpg         18     2767
# 691  False  /jQywhaFDVLPlFw864Bgw5eNtWfi.jpg         27      626
#
#     original_language                     original_title  \
# 0                  fr           Le Comte de Monte-Cristo
# 36                 fr                       Intouchables
# ...

# %%
print(len(english), len(french))
# Out:
# 97 108

# %%
english.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 97 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              97 non-null     bool
#  1   backdrop_path      97 non-null     object
#  2   genre_ids          97 non-null     int64
#  3   id                 97 non-null     int64
#  4   original_language  97 non-null     object
#  5   original_title     97 non-null     object
#  6   overview           97 non-null     object
#  7   popularity         97 non-null     float64
#  8   poster_path        97 non-null     object
#  9   release_date       97 non-null     object
#  10  title              97 non-null     object
#  11  video              97 non-null     bool
#  12  vote_average       97 non-null     float64
#  13  vote_count         97 non-null     int64
#  14  budget             97 non-null     int64
#  15  revenue            97 non-null     int64
# ...

# %%
def get_best_fit(data, x, y):
    '''
    Determines the slope (m) and intercept (b) of the best fit line
    for two variables, x and y.
    '''
    m = 0
    for count in range(100):
        m = m + 1
        b = 0

        # Calculate residuals (y = mx+b)
        res = 0
        for i in range(len(data)):
            pred_y = (m * data.loc[i][x]) + b
            act_y = data.loc[i][y]
            temp = act_y - pred_y 
            temp = temp ** 2
            res = res + temp
        print(res)
    return (m, b, res)

# %%
sns.regplot(data=english, x="budget", y="popularity")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='popularity'>

# %%
english['popularity_sqrt'] = np.sqrt(english['popularity'])
english['budget_sqrt'] = np.sqrt(english['budget'])

# %%
english.head()
# Out:
#     adult                     backdrop_path  genre_ids       id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         18      278
# 4   False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg         16  1184918
# 13  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg         18      238
# 17  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         18      240
# 21  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg         18      424
#
#    original_language            original_title  \
# 0                 en  The Shawshank Redemption
# 4                 en            The Wild Robot
# 13                en             The Godfather
# 17                en     The Godfather Part II
# 21                en          Schindler's List
#
#                                              overview  popularity  \
# 0   Imprisoned in the 1940s for the double murder ...     230.813
# 4   After a shipwreck, an intelligent robot called...    6191.489
# 13  Spanning the years 1945 to 1955, a chronicle o...     195.477
# ...

# %%
sns.regplot(data=english, x="budget_sqrt", y="popularity_sqrt")
# Out:
# <AxesSubplot:xlabel='budget_sqrt', ylabel='popularity_sqrt'>

# %%
def calculate_r_squared(x, y):
    mean_y = sum(y) / len(y)

    sst = sum((yi - mean_y) ** 2 for yi in y)

    n = len(x)
    numerator = sum((x[i] - (sum(x) / n)) * (y[i] - mean_y) for i in range(n))
    denominator = sum((x[i] - (sum(x) / n)) ** 2 for i in range(n))

    m = numerator / denominator  # Slope
    b = mean_y - m * (sum(x) / n)  # Intercept

    predictions = [m * xi + b for xi in x]
    ssr = sum((y[i] - predictions[i]) ** 2 for i in range(n))

    r_squared = 1 - (ssr / sst) if sst != 0 else 0

    return r_squared

x = english['budget']
y = english['popularity']

r_squared = calculate_r_squared(x, y)
print("Coefficient of Determination (R²):", r_squared)
print("The Percentage of R² is: ", r_squared*100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
