# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
# This is the Now Playing Endpoint
url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
now = pd.DataFrame(response["results"])
now.head()
# Out:
#    adult                     backdrop_path             genre_ids       id  \
# 0  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg              [27, 53]  1114513
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg         [878, 27, 35]   933260
# 2  False  /uXDwP5qPhuRyPpQ7WkLbE6t2z5W.jpg          [35, 53, 28]   877817
# 3  False  /1H0l07FGCx3e9G0zLBGiIfHk9Zc.jpg          [18, 80, 53]   889737
# 4  False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg  [28, 14, 27, 53, 80]   957452
#
#   original_language       original_title  \
# 0                en        Speak No Evil
# 1                en        The Substance
# 2                en                Wolfs
# 3                en  Joker: Folie à Deux
# 4                en             The Crow
#
#                                             overview  popularity  \
# 0  When an American family is invited to spend th...    2281.291
# 1  A fading celebrity decides to use a black mark...    1595.704
# 2  Hired to cover up a high-profile crime, a fixe...    1693.793
# 3  While struggling with his dual identity, Arthu...    1372.519
# 4  Soulmates Eric and Shelly are brutally murdere...    1690.146
#
#                         poster_path release_date                title  video  \
# 0  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11        Speak No Evil  False
# 1  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07        The Substance  False
# 2  /vOX1Zng472PC2KnS0B9nRfM8aaZ.jpg   2024-09-20                Wolfs  False
# 3  /if8QiqCI7WAGImKcJCfzp6VTyKA.jpg   2024-10-01  Joker: Folie à Deux  False
# 4  /58QT4cPJ2u2TqWZkterDq9q4yxQ.jpg   2024-08-21             The Crow  False
#
#    vote_average  vote_count
# 0         7.350         502
# 1         7.300         230
# 2         6.594         376
# 3         5.836         434
# 4         5.446         484

# %%
# Popular

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
pop = pd.DataFrame(response["results"])
pop.head()
# Out:
#    adult                     backdrop_path                genre_ids       id  \
# 0  False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg            [28, 35, 878]   533535
# 1  False  /lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg      [16, 10751, 35, 28]   519182
# 2  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg                 [27, 53]  1114513
# 3  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg            [878, 27, 35]   933260
# 4  False  /p5ozvmdgsmbWe0H8Xk7Rc8SCwAB.jpg  [16, 10751, 12, 35, 18]  1022789
#
#   original_language        original_title  \
# 0                en  Deadpool & Wolverine
# 1                en       Despicable Me 4
# 2                en         Speak No Evil
# 3                en         The Substance
# 4                en          Inside Out 2
#
#                                             overview  popularity  \
# 0  A listless Wade Wilson toils away in civilian ...    5099.804
# 1  Gru and Lucy and their girls—Margo, Edith and ...    2524.611
# 2  When an American family is invited to spend th...    2281.291
# 3  A fading celebrity decides to use a black mark...    1595.704
# 4  Teenager Riley's mind headquarters is undergoi...    1561.870
#
#                         poster_path release_date                 title  video  \
# 0  /8cdWjvZQUExUUTzyp4t6EDMubfO.jpg   2024-07-24  Deadpool & Wolverine  False
# 1  /wWba3TaojhK7NdycRhoQpsG0FaH.jpg   2024-06-20       Despicable Me 4  False
# 2  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11         Speak No Evil  False
# 3  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07         The Substance  False
# 4  /vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg   2024-06-11          Inside Out 2  False
#
#    vote_average  vote_count
# 0         7.744        4027
# 1         7.145        1892
# 2         7.347         503
# 3         7.300         230
# 4         7.642        4159

# %%
# Top Rated

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
top = pd.DataFrame(response["results"])

# %%
# Upcoming
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
up = pd.DataFrame(response["results"])

# %%
df = pd.concat([now, pop, top, up])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              80 non-null     bool
#  1   backdrop_path      80 non-null     object
#  2   genre_ids          80 non-null     object
#  3   id                 80 non-null     int64
#  4   original_language  80 non-null     object
#  5   original_title     80 non-null     object
#  6   overview           80 non-null     object
#  7   popularity         80 non-null     float64
#  8   poster_path        80 non-null     object
#  9   release_date       80 non-null     object
#  10  title              80 non-null     object
#  11  video              80 non-null     bool
#  12  vote_average       80 non-null     float64
#  13  vote_count         80 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 8.3+ KB

# %%
df.drop_duplicates(subset='original_title')
# Out:
#     adult                     backdrop_path             genre_ids       id  \
# 0   False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg              [27, 53]  1114513
# 1   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg         [878, 27, 35]   933260
# 2   False  /uXDwP5qPhuRyPpQ7WkLbE6t2z5W.jpg          [35, 53, 28]   877817
# 3   False  /1H0l07FGCx3e9G0zLBGiIfHk9Zc.jpg          [18, 80, 53]   889737
# 4   False  /Asg2UUwipAdE87MxtJy7SQo08XI.jpg  [28, 14, 27, 53, 80]   957452
# ..    ...                               ...                   ...      ...
# 15  False  /tCQfubckzzcuCbsGugkpLhfjS5z.jpg          [28, 53, 80]   970347
# 16  False  /jf1V00dZdNkVfEq7VPk8frrlELk.jpg            [27, 9648]   748230
# 17  False  /oBmwaZ3NVa3JyZnv1qCo0znxjUw.jpg          [27, 80, 53]  1029281
# 18  False  /AjTodtZJlQxycfRPktnUTpknblv.jpg   [16, 12, 35, 10751]  1207830
# 19  False  /t3LicFpYHeYpwqm7L5wDpd22hL5.jpg              [12, 14]      671
#
#    original_language                            original_title  \
# 0                 en                             Speak No Evil
# 1                 en                             The Substance
# 2                 en                                     Wolfs
# 3                 en                       Joker: Folie à Deux
# 4                 en                                  The Crow
# ..               ...                                       ...
# 15                en                                The Killer
# 16                en                               Salem's Lot
# 17                en                           Strange Darling
# 18                en        Gracie & Pedro: Pets to the Rescue
# 19                en  Harry Potter and the Philosopher's Stone
#
#                                              overview  popularity  \
# 0   When an American family is invited to spend th...    2281.291
# 1   A fading celebrity decides to use a black mark...    1595.704
# 2   Hired to cover up a high-profile crime, a fixe...    1693.793
# 3   While struggling with his dual identity, Arthu...    1372.519
# 4   Soulmates Eric and Shelly are brutally murdere...    1690.146
# ..                                                ...         ...
# 15  Zee is a feared contract killer known as "the ...     302.421
# 16  Author Ben Mears returns to his childhood home...     283.882
# 17  Nothing is what it seems when a twisted one-ni...     271.705
# 18  Family frenemies, Gracie and Pedro, must put t...     262.058
# 19  Harry Potter has lived under the stairs at his...     246.557
#
#                          poster_path release_date  \
# 0   /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11
# 1   /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07
# 2   /vOX1Zng472PC2KnS0B9nRfM8aaZ.jpg   2024-09-20
# 3   /if8QiqCI7WAGImKcJCfzp6VTyKA.jpg   2024-10-01
# 4   /58QT4cPJ2u2TqWZkterDq9q4yxQ.jpg   2024-08-21
# ..                               ...          ...
# 15  /6PCnxKZZIVRanWb710pNpYVkCSw.jpg   2024-08-22
# 16  /j7ncdqBVufydVzVtxmXu8Ago4ox.jpg   2024-10-03
# 17  /rhhE4U49hM50s7XCYZ8dHShhM7x.jpg   2024-08-22
# 18  /1agSI7NGvagr720za8XAubtqUoB.jpg   2024-05-01
# 19  /wuMc08IPKEatf9rnMNXvIDxqP4W.jpg   2001-11-16
#
#                                        title  video  vote_average  vote_count
# 0                              Speak No Evil  False         7.350         502
# 1                              The Substance  False         7.300         230
# 2                                      Wolfs  False         6.594         376
# 3                        Joker: Folie à Deux  False         5.836         434
# 4                                   The Crow  False         5.446         484
# ..                                       ...    ...           ...         ...
# 15                                The Killer  False         6.597         252
# 16                               Salem's Lot  False         6.366         138
# 17                           Strange Darling  False         7.011          88
# 18        Gracie & Pedro: Pets to the Rescue  False         7.273          11
# 19  Harry Potter and the Philosopher's Stone  False         7.914       27161
#
# [64 rows x 14 columns]

# %%
df.loc[5]
# Out:
#    adult                     backdrop_path          genre_ids      id  \
# 5  False  /hPIWQT70wQK6akqfLXByEvr62u0.jpg  [28, 53, 27, 878]  726139
# 5  False  /uXDwP5qPhuRyPpQ7WkLbE6t2z5W.jpg       [35, 53, 28]  877817
# 5  False  /6oaL4DP75yABrd5EbC4H2zq5ghc.jpg    [16, 10751, 14]     129
# 5  False  /b3mdmjYTEL70j7nuXATUAD9qgu4.jpg       [16, 14, 12]  823219
#
#   original_language original_title  \
# 5                ko  탈출: 프로젝트 사일런스
# 5                en          Wolfs
# 5                ja       千と千尋の神隠し
# 5                xx           Flow
#
#                                             overview  popularity  \
# 5  Due to sudden deteriorating weather conditions...    1331.711
# 5  Hired to cover up a high-profile crime, a fixe...    1693.793
# 5  A young girl, Chihiro, becomes trapped in a st...     102.743
# 5  The world seems to be coming to an end, teemin...     509.302
#
#                         poster_path release_date            title  video  \
# 5  /fttoFfKikQMwIoV3UVvlCvBhbUw.jpg   2024-07-11  Project Silence  False
# 5  /vOX1Zng472PC2KnS0B9nRfM8aaZ.jpg   2024-09-20            Wolfs  False
# 5  /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20    Spirited Away  False
# 5  /dzDMewC0Hwv01SROiWgKOi4iOc1.jpg   2024-08-30             Flow  False
#
#    vote_average  vote_count
# 5         7.074         102
# 5         6.590         377
# 5         8.537       16370
# 5         8.900          44

# %%
def get_revenue_budget(df):
    '''
    Uses the movie id to get data from the "Details" endpoint
    returns a dataframe of revenue and budget data
    '''
    data = {
        "id":[],
        "budget": [],
        "revenue": []
    }

    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])
        
    return pd.DataFrame(data)

# %%
money_df = get_revenue_budget(df)

# %%
money_df
# Out:
#          id     budget    revenue
# 0   1114513   15000000   57652430
# 1    933260   17500000   10492678
# 2    877817          0          0
# 3    889737  195000000   81100000
# 4    957452   50000000   13690814
# ..      ...        ...        ...
# 75   970347   30000000          0
# 76   748230          0          0
# 77  1029281    4000000    3504687
# 78  1207830          0     664443
# 79      671  125000000  976475550
#
# [80 rows x 3 columns]

# %%
df = pd.merge(df, money_df, how="inner", on="id")

# %%
df.head()
# Out:
#    adult                     backdrop_path      genre_ids       id  \
# 0  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg       [27, 53]  1114513
# 1  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg       [27, 53]  1114513
# 2  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg       [27, 53]  1114513
# 3  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg       [27, 53]  1114513
# 4  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg  [878, 27, 35]   933260
#
#   original_language original_title  \
# 0                en  Speak No Evil
# 1                en  Speak No Evil
# 2                en  Speak No Evil
# 3                en  Speak No Evil
# 4                en  The Substance
#
#                                             overview  popularity  \
# 0  When an American family is invited to spend th...    2281.291
# 1  When an American family is invited to spend th...    2281.291
# 2  When an American family is invited to spend th...    2281.291
# 3  When an American family is invited to spend th...    2281.291
# 4  A fading celebrity decides to use a black mark...    1595.704
#
#                         poster_path release_date          title  video  \
# 0  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11  Speak No Evil  False
# 1  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11  Speak No Evil  False
# 2  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11  Speak No Evil  False
# 3  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11  Speak No Evil  False
# 4  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07  The Substance  False
#
#    vote_average  vote_count    budget   revenue
# 0         7.350         502  15000000  57652430
# 1         7.350         502  15000000  57652430
# 2         7.347         503  15000000  57652430
# 3         7.347         503  15000000  57652430
# 4         7.300         230  17500000  10492678

# %%
sns.regplot(data=df, x="budget", y="revenue")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %%
df['revenue_sqrt'] = np.sqrt(df['revenue'])
df['budget_sqrt'] = np.sqrt(df['budget'])

# %%
df.head()
# Out:
#    adult                     backdrop_path      genre_ids       id  \
# 0  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg       [27, 53]  1114513
# 1  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg       [27, 53]  1114513
# 2  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg       [27, 53]  1114513
# 3  False  /9R9Za5kybgl5AhuCNoK3gngaBdG.jpg       [27, 53]  1114513
# 4  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg  [878, 27, 35]   933260
#
#   original_language original_title  \
# 0                en  Speak No Evil
# 1                en  Speak No Evil
# 2                en  Speak No Evil
# 3                en  Speak No Evil
# 4                en  The Substance
#
#                                             overview  popularity  \
# 0  When an American family is invited to spend th...    2281.291
# 1  When an American family is invited to spend th...    2281.291
# 2  When an American family is invited to spend th...    2281.291
# 3  When an American family is invited to spend th...    2281.291
# 4  A fading celebrity decides to use a black mark...    1595.704
#
#                         poster_path release_date          title  video  \
# 0  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11  Speak No Evil  False
# 1  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11  Speak No Evil  False
# 2  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11  Speak No Evil  False
# 3  /fDtkrO2OAF8LKQTdzYmu1Y7lCLB.jpg   2024-09-11  Speak No Evil  False
# 4  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07  The Substance  False
#
#    vote_average  vote_count    budget   revenue  revenue_sqrt  budget_sqrt
# 0         7.350         502  15000000  57652430   7592.919728  3872.983346
# 1         7.350         502  15000000  57652430   7592.919728  3872.983346
# 2         7.347         503  15000000  57652430   7592.919728  3872.983346
# 3         7.347         503  15000000  57652430   7592.919728  3872.983346
# 4         7.300         230  17500000  10492678   3239.240343  4183.300133

# %%
def get_best_fit(df, x, y):
    '''
    Determines the slope (m) and intercept (b) of 
    the best fit line for two variables, x and y.
    '''
    m = 0
    b = 0
    n = len(df)
    sum_x = df['budget'].sum()
    sum_y = df['revenue'].sum()
    sum_xy = (df['budget'] * df['revenue']).sum()
    sum_x_squared = (df['budget'] ** 2).sum()

    m = (n * sum_xy - sum_x * sum_y) / (n * sum_x_squared - sum_x ** 2)

    b = (sum_y - m * sum_x) / n

    return (m, b)

# %%
get_best_fit(df, "budget", "revenue")
# Out:
# C:\Users\wreep\AppData\Local\Temp\ipykernel_4360\3934841551.py:14: RuntimeWarning: overflow encountered in longlong_scalars
#   m = (n * sum_xy - sum_x * sum_y) / (n * sum_x_squared - sum_x ** 2)
# (1.129348760402462, 118045051.14644769)

# %%
sns.regplot(data=df, x=1.129348760402462, y=118045051.14644769)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4360\2004630414.py in <module>
# ----> 1 sns.regplot(data=df, x=1.129348760402462, y=118045051.14644769)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     849 ):
#     850
# --> 851     plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
#     852                                  scatter, fit_reg, ci, n_boot, units, seed,
#     853                                  order, logistic, lowess, robust, logx,
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     107
#     108         # Extract the data vals from the arguments or passed dataframe
# --> 109         self.establish_variables(data, x=x, y=y, units=units,
#     110                                  x_partial=x_partial, y_partial=y_partial)
#     111
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py in establish_variables(self, data, **kws)
#      49             else:
#      50                 vector = val
# ---> 51             if vector is not None and vector.shape != (1,):
#      52                 vector = np.squeeze(vector)
#      53             if np.ndim(vector) > 1:
#
# AttributeError: 'float' object has no attribute 'shape'
