# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
# This is the Now Playing Endpoint
url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
now = pd.DataFrame(response["results"])
now.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
# 2  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 3  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 4  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en  Venom: The Last Dance
# 2                en          The Substance
# 3                en                 Azrael
# 4                en            Terrifier 3
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    4950.682
# 1  Eddie and Venom are on the run. Hunted by both...    2994.212
# 2  A fading celebrity decides to use a black mark...    2641.055
# 3  In a world where no one speaks, a devout femal...    1151.735
# 4  Five years after surviving Art the Clown's Hal...    1760.315
#
#                         poster_path release_date                  title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 1  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22  Venom: The Last Dance
# 2  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 3  /qpdFKDvJS7oLKTcBLXOaMwUESbs.jpg   2024-09-27                 Azrael
# 4  /63xYQj1BwRFielxsBDXvHIJyXVm.jpg   2024-10-09            Terrifier 3
#
#    video  vote_average  vote_count
# 0  False         8.600        1442
# 1  False         6.672          67
# 2  False         7.288         864
# 3  False         6.089          90
# 4  False         7.163         135

# %%
# Popular

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
pop = pd.DataFrame(response["results"])
pop.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
# 2  False  /9SSEUrSqhljBMzRe4aBTh17rUaC.jpg         [878, 27]   945961
# 3  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 4  False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg     [28, 35, 878]   533535
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en  Venom: The Last Dance
# 2                en         Alien: Romulus
# 3                en          The Substance
# 4                en   Deadpool & Wolverine
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    4950.682
# 1  Eddie and Venom are on the run. Hunted by both...    2994.212
# 2  While scavenging the deep ends of a derelict s...    2982.392
# 3  A fading celebrity decides to use a black mark...    2641.055
# 4  A listless Wade Wilson toils away in civilian ...    1975.796
#
#                         poster_path release_date                  title  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12         The Wild Robot
# 1  /k42Owka8v91trK1qMYwCQCNwJKr.jpg   2024-10-22  Venom: The Last Dance
# 2  /b33nnKl1GSFbao4l3fZDDqsMx0F.jpg   2024-08-13         Alien: Romulus
# 3  /lqoMzCcZYEFK729d6qzt349fB4o.jpg   2024-09-07          The Substance
# 4  /8cdWjvZQUExUUTzyp4t6EDMubfO.jpg   2024-07-24   Deadpool & Wolverine
#
#    video  vote_average  vote_count
# 0  False         8.649        1447
# 1  False         6.600          72
# 2  False         7.300        1857
# 3  False         7.300         867
# 4  False         7.700        4781

# %%
# Top Rated

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
top = pd.DataFrame(response["results"])

# %%
# Upcoming
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
up = pd.DataFrame(response["results"])

# %%
df = pd.concat([now, pop, top, up])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              80 non-null     bool
#  1   backdrop_path      80 non-null     object
#  2   genre_ids          80 non-null     object
#  3   id                 80 non-null     int64
#  4   original_language  80 non-null     object
#  5   original_title     80 non-null     object
#  6   overview           80 non-null     object
#  7   popularity         80 non-null     float64
#  8   poster_path        80 non-null     object
#  9   release_date       80 non-null     object
#  10  title              80 non-null     object
#  11  video              80 non-null     bool
#  12  vote_average       80 non-null     float64
#  13  vote_count         80 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 8.3+ KB

# %%
df.drop_duplicates(subset='original_title')
# Out:
#     adult                     backdrop_path                   genre_ids  \
# 0   False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg            [16, 878, 10751]
# 1   False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg               [28, 878, 12]
# 2   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg               [27, 18, 878]
# 3   False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg                [28, 27, 53]
# 4   False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg                    [27, 53]
# 5   False  /oPUOpnl3pqD8wuidjfUn17mO1yA.jpg    [16, 878, 12, 10751, 28]
# 6   False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg                [35, 14, 27]
# 7   False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg           [878, 53, 27, 18]
# 8   False  /hd1TvTUGjkoYoqvXYfSBpI5Ri9B.jpg           [16, 28, 12, 878]
# 9   False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg                [14, 27, 28]
# 10  False  /of1tQasFGCeHgWPmSgdA1WS6hNW.jpg                [80, 53, 28]
# 11  False  /cVg97LOJgrDZJ7bVmjU2KsGRYnU.jpg                  [27, 9648]
# 12  False  /64tinBsds1nVp4wOCgYhMbSgsRW.jpg                [28, 18, 36]
# 13  False  /reNf6GBzOe48l9WEnFOxXgW56Vg.jpg                [18, 80, 53]
# 14  False  /1fL2S8LKxCVE9KoPRBXeagmBtex.jpg                    [27, 53]
# 15  False  /aFDYcmwEWRiEh58Ri1tMpCUWPBp.jpg  [10770, 10751, 35, 27, 16]
# 16  False   /l8OyAXEp5FKZWmDhqJMbiwAEvz.jpg                    [27, 18]
# 17  False  /fNylhsI3u6NmTxeanFPDEwvT9GS.jpg                [80, 18, 53]
# 18  False  /b3mdmjYTEL70j7nuXATUAD9qgu4.jpg                [16, 14, 12]
# 19  False  /zAqBIeO71BFL7bAtP5TFzVjVamy.jpg                 [10749, 18]
# 2   False  /9SSEUrSqhljBMzRe4aBTh17rUaC.jpg                   [878, 27]
# 4   False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg               [28, 35, 878]
# 7   False  /p5ozvmdgsmbWe0H8Xk7Rc8SCwAB.jpg     [16, 10751, 12, 35, 18]
# 9   False  /lgkPzcOSnTvjeMnuFzozRO5HHw1.jpg         [16, 10751, 35, 28]
# 15  False  /bkENfmxUY3UYsRLizJAhF5IQPvS.jpg                [28, 80, 53]
# 18  False  /p4INKu77iuTG1o1a5N3Y9vqeEGq.jpg                    [27, 53]
# 19  False  /l0Y9OzRWKmlzZcGy4olKaOPXsru.jpg             [10749, 14, 16]
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg                    [18, 80]
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg                    [18, 80]
# 3   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg                    [18, 80]
# 4   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg             [18, 36, 10752]
# 5   False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                        [18]
# 6   False  /6oaL4DP75yABrd5EbC4H2zq5ghc.jpg             [16, 10751, 14]
# 7   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg             [35, 18, 10749]
# 8   False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg            [18, 28, 80, 53]
# 9   False  /8eihUxjQsJ7WvGySkVMC0EwbPAD.jpg                [35, 53, 18]
# 10  False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg                [14, 18, 80]
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg                    [53, 80]
# 12  False  /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg             [16, 10749, 18]
# 13  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg                [12, 14, 28]
# 14  False  /ghgfzbEV7kbpbi1O8eIILKVXEA8.jpg             [35, 18, 10749]
# 15  False  /Adrip2Jqzw56KeuV2nAxucKMNXA.jpg                        [37]
# 16  False  /sJNNMCc6B7KZIY3LH3JMYJJNH5j.jpg                    [28, 18]
# 17  False  /7TF4p86ZafnxFuNqWdhpHXFO244.jpg                    [18, 80]
# 18  False  /gwj4R8Uy1GwejKqfofREKI9Jh7L.jpg             [16, 18, 10752]
# 19  False  /7lyq8hK0MhPHpUXdnqbFvZYSfkk.jpg                 [18, 10749]
# 11  False  /yjPXIgY3QoHe8Kt8nEJCz97UF3q.jpg             [18, 36, 10752]
# 12  False  /co7oxvpWxgd6FZU24DnljDDHYQA.jpg               [878, 53, 27]
# 13  False  /mpMDztY5OmV7i4ypYpWgqsP4DHs.jpg                    [27, 53]
# 14  False  /bizhlTVjifYQUu4Xrdt7m3TYr7d.jpg                    [27, 80]
# 15  False  /jf1V00dZdNkVfEq7VPk8frrlELk.jpg                  [27, 9648]
# 16  False  /e0xnvkG0nZjEfvREuhgFekJZmQr.jpg                    [28, 12]
# 17  False  /iURqo6oIwbeegIwWXx5qrBsDcPk.jpg         [12, 10751, 14, 35]
# 18  False  /5rrGVmRUuCKVbqUu41XIWTXJmNA.jpg                    [12, 14]
# 19  False  /bsaA9qtIR6VTDQykXdBzJc8V5rS.jpg                    [12, 14]
#
#          id original_language                                 original_title  \
# 0   1184918                en                                 The Wild Robot
# 14  /5aj8vVGFwGVbQQs26ywhg4Zxk2L.jpg   2024-05-31
# 15  /j7ncdqBVufydVzVtxmXu8Ago4ox.jpg   2024-10-03
# 16  /2cxhvwyEwRlysAmRH4iodkvo0z5.jpg   2024-11-13
# 17  /qtW6bWUEqfPLaD6KnetIlSG4adf.jpg   2024-07-31
# 18  /fECBtHlr0RB3foNHDiCBXeg9Bv9.jpg   2005-11-16
# 19  /5aOyriWkPec0zUDxmHFP9qMmBaj.jpg   2007-07-08
#
#                                             title  video  vote_average  \
# 0                                  The Wild Robot  False         8.600
# 1                           Venom: The Last Dance  False         6.672
# 2                                   The Substance  False         7.288
# 3                                          Azrael  False         6.089
# 4                                     Terrifier 3  False         7.163
# 5                                Transformers One  False         8.000
# 6                         Beetlejuice Beetlejuice  False         7.215
# 7                                  The Platform 2  False         5.680
# 8                   My Hero Academia: You're Next  False         7.096
# 9                        Hellboy: The Crooked Man  False         5.116
# 10                                The Silent Hour  False         6.515
# 11                                        Smile 2  False         6.904
# 12                                       Uprising  False         7.352
# 13                            Joker: Folie à Deux  False         5.791
# 14                                  Speak No Evil  False         7.300
# 15          SpongeBob Squarepants: Kreepaway Kamp  False         7.074
# 16                                   Never Let Go  False         6.201
# 17                              Woman of the Hour  False         6.700
# 18                                           Flow  False         8.900
# 19                                It Ends with Us  False         7.187
# 2                                  Alien: Romulus  False         7.300
# 4                            Deadpool & Wolverine  False         7.700
# 7                                    Inside Out 2  False         7.613
# 9                                 Despicable Me 4  False         7.100
# 15                                 Blood for Dust  False         5.800
# 18             Winnie-the-Pooh: Blood and Honey 2  False         6.200
# 19                                   Corpse Bride  False         7.600
# 0                        The Shawshank Redemption  False         8.700
# 1                                   The Godfather  False         8.690
# 3                           The Godfather Part II  False         8.573
# 4                                Schindler's List  False         8.600
# 5                                    12 Angry Men  False         8.544
# 6                                   Spirited Away  False         8.538
# 7                     Dilwale Dulhania Le Jayenge  False         8.530
# 8                                 The Dark Knight  False         8.515
# 9                                        Parasite  False         8.505
# 10                                 The Green Mile  False         8.507
# 11                                   Pulp Fiction  False         8.488
# 12                                     Your Name.  False         8.486
# 13  The Lord of the Rings: The Return of the King  False         8.500
# 14                                   Forrest Gump  False         8.472
# 15                 The Good, the Bad and the Ugly  False         8.463
# 16                                  Seven Samurai  False         8.461
# 17                                     GoodFellas  False         8.500
# 18                         Grave of the Fireflies  False         8.455
# 19                                Cinema Paradiso  False         8.400
# 11                                            Lee  False         7.022
# 12                                   Subservience  False         6.800
# 13                                         Bagman  False         6.211
# 14                                       Longlegs  False         6.700
# 15                                    Salem's Lot  False         6.252
# 16                                   Gladiator II  False         0.000
# 17                   Harold and the Purple Crayon  False         7.000
# 18            Harry Potter and the Goblet of Fire  False         7.812
# 19      Harry Potter and the Order of the Phoenix  False         7.700
#
#     vote_count
# 0         1442
# 1           67
# 2          864
# 3           90
# 4          135
# 5          292
# 6         1517
# 7          696
# 8           26
# 9          159
# 10          34
# 11         151
# 12          71
# 13         925
# 14         742
# 15          27
# 16         149
# 17         203
# 18         119
# 19         884
# 2         1857
# 4         4781
# 7         4460
# 9         2047
# 15          43
# 18         247
# 19        9114
# 0        27004
# 1        20507
# 3        12370
# 4        15777
# 5         8586
# 6        16421
# 7         4431
# 8        32752
# 9        18158
# 10       17331
# 11       27786
# 12       11311
# 13       24081
# 14       27316
# 15        8556
# 16        3647
# 17       12788
# 18        5500
# 19        4342
# 11          90
# 12         201
# 13          38
# 14        1114
# 15         304
# 16           0
# 17         160
# 18       20543
# 19       19327

# %%
df.loc[5]
# Out:
#    adult                     backdrop_path                 genre_ids       id  \
# 5  False  /oPUOpnl3pqD8wuidjfUn17mO1yA.jpg  [16, 878, 12, 10751, 28]   698687
# 5  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg                  [27, 53]  1034541
# 5  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                      [18]      389
# 5  False  /hd1TvTUGjkoYoqvXYfSBpI5Ri9B.jpg         [16, 28, 12, 878]  1159311
#
#   original_language                original_title  \
# 5                en              Transformers One
# 5                en                   Terrifier 3
# 5                en                  12 Angry Men
# 5                ja  僕のヒーローアカデミア THE MOVIE ユアネクスト
#
#                                             overview  popularity  \
# 5  The untold origin story of Optimus Prime and M...    1204.038
# 5  Five years after surviving Art the Clown's Hal...    1760.315
# 5  The defense and the prosecution have rested an...     116.474
# 5  In a society devastated by the effects of an a...     899.321
#
#                         poster_path release_date  \
# 5  /iRCgqpdVE4wyLQvGYU3ZP7pAtUc.jpg   2024-09-11
# 5  /63xYQj1BwRFielxsBDXvHIJyXVm.jpg   2024-10-09
# 5  /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10
# 5  /8rdB1wkheEMMqcY8qLAKjCMPcnZ.jpg   2024-08-02
#
#                            title  video  vote_average  vote_count
# 5               Transformers One  False         8.000         292
# 5                    Terrifier 3  False         7.173         142
# 5                   12 Angry Men  False         8.544        8586
# 5  My Hero Academia: You're Next  False         7.100          26

# %%
def get_revenue_budget(df):
    '''
    Uses the movie id to get data from the "Details" endpoint
    returns a dataframe of revenue and budget data
    '''
    data = {
        "id":[],
        "budget": [],
        "revenue": []
    }

    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])
        
    return pd.DataFrame(data)

# %%
money_df = get_revenue_budget(df)

# %%
money_df
# Out:
#          id     budget    revenue
# 0   1184918   78000000  199785520
# 1    912649  110000000          0
# 2    933260   17500000   29106531
# 3   1029235   12000000          0
# 4   1034541    2000000   46694902
# ..      ...        ...        ...
# 75   748230          0          0
# 76   558449  310000000          0
# 77   826510   40000000   24982787
# 78      674  150000000  895921036
# 79      675  150000000  938212738
#
# [80 rows x 3 columns]

# %%
df = pd.merge(df, money_df, how="inner", on="id")

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 2  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 3  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 4  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
#
#   original_language  original_title  \
# 0                en  The Wild Robot
# 1                en  The Wild Robot
# 2                en  The Wild Robot
# 3                en  The Wild Robot
# 4                en  The Wild Robot
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    4950.682
# 1  After a shipwreck, an intelligent robot called...    4950.682
# 2  After a shipwreck, an intelligent robot called...    4950.682
# 3  After a shipwreck, an intelligent robot called...    4950.682
# 4  After a shipwreck, an intelligent robot called...    4950.682
#
#                         poster_path release_date           title  video  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12  The Wild Robot  False
# 1  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12  The Wild Robot  False
# 2  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12  The Wild Robot  False
# 3  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12  The Wild Robot  False
# 4  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12  The Wild Robot  False
#
#    vote_average  vote_count    budget    revenue
# 0         8.600        1442  78000000  199785520
# 1         8.600        1442  78000000  199785520
# 2         8.600        1442  78000000  199785520
# 3         8.600        1442  78000000  199785520
# 4         8.649        1447  78000000  199785520

# %%
sns.regplot(data=df, x="budget", y="revenue")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %%
df['revenue_sqrt'] = np.sqrt(df['revenue'])
df['budget_sqrt'] = np.sqrt(df['budget'])

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 2  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 3  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 4  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
#
#   original_language  original_title  \
# 0                en  The Wild Robot
# 1                en  The Wild Robot
# 2                en  The Wild Robot
# 3                en  The Wild Robot
# 4                en  The Wild Robot
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    4950.682
# 1  After a shipwreck, an intelligent robot called...    4950.682
# 2  After a shipwreck, an intelligent robot called...    4950.682
# 3  After a shipwreck, an intelligent robot called...    4950.682
# 4  After a shipwreck, an intelligent robot called...    4950.682
#
#                         poster_path release_date           title  video  \
# 0  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12  The Wild Robot  False
# 1  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12  The Wild Robot  False
# 2  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12  The Wild Robot  False
# 3  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12  The Wild Robot  False
# 4  /wTnV3PCVW5O92JMrFvvrRcV39RU.jpg   2024-09-12  The Wild Robot  False
#
#    vote_average  vote_count    budget    revenue  revenue_sqrt  budget_sqrt
# 0         8.600        1442  78000000  199785520  14134.550577  8831.760866
# 1         8.600        1442  78000000  199785520  14134.550577  8831.760866
# 2         8.600        1442  78000000  199785520  14134.550577  8831.760866
# 3         8.600        1442  78000000  199785520  14134.550577  8831.760866
# 4         8.649        1447  78000000  199785520  14134.550577  8831.760866

# %%
def get_best_fit(data, x, y):
    '''
    Determines the slope (m) and intercept (b) of the best fit line
    for two variables, x and y.
    '''
    m = 0
    for count in range(100):
        m = m + 1
        b = 0

        # Calculate residuals (y = mx+b)
        res = 0
        for i in range(len(data)):
            pred_y = (m * data.loc[i][x]) + b
            act_y = data.loc[i][y]
            temp = act_y - pred_y 
            temp = temp ** 2
            res = res + temp
        print(res)
    return (m, b, res)

# %%
get_best_fit(df, "budget_sqrt", "revenue_sqrt")
# Out:
# 8250853451.109618
# 8687902508.219238
# 20370303067.328873
# 43298055128.43844
# 77471158691.54811
# 122889613756.65782
# 179553420323.76733
# 247462578392.87698
# 326617087963.9868
# 417016949037.0963
# 518662161612.2059
# 631552725689.3153
# 755688641268.425
# 891069908349.5348
# 1037696526932.6447
# 1195568497017.7546
# 1364685818604.8645
# 1545048491693.9731
# 1736656516285.0818
# 1939509892378.1926
# 2153608619973.3013
# 2378952699070.413
# 2615542129669.5195
# 2863376911770.6323
# 3122457045373.74
# 3392782530478.8506
# 3674353367085.96
# 3967169555195.0693
# 4271231094806.1777
# 4586537985919.29
# 4913090228534.399
# 5250887822651.506
# 5599930768270.617
# 5960219065391.728
# 6331752714014.839
# 6714531714139.951
# 7108556065767.052
# 7513825768896.167
# 7930340823527.27
# 8358101229660.383
# 8797106987295.496
# 9247358096432.602
# 9708854557071.715
# 10181596369212.818
# 10665583532855.93
# 11160816048001.04
# 11667293914648.158
# 12185017132797.26
# 12713985702448.375
# 13254199623601.484
# 13805658896256.59
# 14368363520413.693
# 14942313496072.799
# 15527508823233.92
# 16123949501897.021
# 16731635532062.14
# 17350566913729.227
# 17980743646898.36
# 18622165731569.45
# 19274833167742.566
# 19938745955417.68
# 20613904094594.793
# 21300307585273.9
# 21997956427455.004
columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              150 non-null    bool
#  1   backdrop_path      150 non-null    object
#  2   genre_ids          150 non-null    object
#  3   id                 150 non-null    int64
#  4   original_language  150 non-null    object
#  5   original_title     150 non-null    object
#  6   overview           150 non-null    object
#  7   popularity         150 non-null    float64
#  8   poster_path        150 non-null    object
#  9   release_date       150 non-null    object
#  10  title              150 non-null    object
#  11  video              150 non-null    bool
#  12  vote_average       150 non-null    float64
#  13  vote_count         150 non-null    int64
#  14  budget             150 non-null    int64
#  15  revenue            150 non-null    int64
#  16  revenue_sqrt       150 non-null    float64
#  17  budget_sqrt        150 non-null    float64
# dtypes: bool(2), float64(4), int64(4), object(8)
# memory usage: 24.3+ KB

# %%
def calculate_r_squared(x, y):
    mean_y = sum(y) / len(y)

    sst = sum((yi - mean_y) ** 2 for yi in y)

    n = len(x)
    numerator = sum((x[i] - (sum(x) / n)) * (y[i] - mean_y) for i in range(n))
    denominator = sum((x[i] - (sum(x) / n)) ** 2 for i in range(n))

    m = numerator / denominator  # Slope
    b = mean_y - m * (sum(x) / n)  # Intercept

    predictions = [m * xi + b for xi in x]
    ssr = sum((y[i] - predictions[i]) ** 2 for i in range(n))

    r_squared = 1 - (ssr / sst) if sst != 0 else 0

    return r_squared

x = df['budget']
y = df['popularity']

r_squared = calculate_r_squared(x, y)
print("Coefficient of Determination (R²):", r_squared)
print("The Percentage of R² is: ", r_squared*100)
# Out:
# Coefficient of Determination (R²): 0.11975599481844057
# The Percentage of R² is:  11.975599481844057

# %% [markdown]
# # Is the Coefficient of Determination good for Popularity Score and the Budget?
#
# #### To sum it up, no. It is not good because it only represents 5% of the total Dataset we are looking at, and with the variables, they don't represent a big sum between Popularity Score and Budget.

# %%
# Popular 
action = []
romance = []
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}
response = requests.get(url, headers=headers)
response = response.json()["results"]
for i in range(len(response)):
    genres = response[i]["genre_ids"]
    if 28 in genres and 10749 in genres:
        action.append(response[i])
        romance.append(response[i])
    elif 28 in genres:
        action.append(response[i])
    elif 10749 in genres:
        romance.append(response[i])
action = pd.DataFrame(action)
romance = pd.DataFrame(romance)

# %%
print(len(action), len(romance))
# Out:
# 10 1

# %%
page = 2
while len(action) < 100 or len(romance) < 100:
    url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=" + str(page)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
    }
    response = requests.get(url, headers=headers)
    response = response.json()["results"]
    page += 1
    for i in range(len(response)):
        genres = response[i]["genre_ids"]
        temp = pd.DataFrame(response[i])
        if 28 in genres:
            action = pd.concat([temp, action], ignore_index=True)
        if 10749 in genres:
            romance = pd.concat([temp, romance], ignore_index=True)

# %%
action = action.drop_duplicates(subset=['id'])
action
# Out:
#      adult                     backdrop_path          genre_ids       id  \
# 0    False  /vr6n6ZFUZvedvIlhfYcbCWcaKyW.jpg                 12       58
# 3    False  /7ZP8HtgOIDaBs12krXgUIygqEsy.jpg                878   601796
# 7    False  /er3zBubUy2Mhpu4WHInNWSjUzh7.jpg                 28   173083
# 9    False  /8wwXPG22aNMpPGuXnfm3galoxbI.jpg                 28   675353
# 13   False  /x2thJwMJ6oGlhn7UC4vSwHltEw0.jpg                 28  1115396
# ..     ...                               ...                ...      ...
# 329  False  /hd1TvTUGjkoYoqvXYfSBpI5Ri9B.jpg  [16, 28, 12, 878]  1159311
# 330  False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg       [14, 27, 28]  1087822
# 331  False  /of1tQasFGCeHgWPmSgdA1WS6hNW.jpg       [80, 53, 28]  1047373
# 332  False  /bkENfmxUY3UYsRLizJAhF5IQPvS.jpg       [28, 80, 53]  1025596
# 333  False  /64tinBsds1nVp4wOCgYhMbSgsRW.jpg       [28, 18, 36]  1075676
#
#     original_language                              original_title  \
# 0                  en  Pirates of the Caribbean: Dead Man's Chest
# 3                  ko                                     외계+인 1부
# 7                  ja                                  くノ一忍法帖 影ノ月
# 9                  en                        Sonic the Hedgehog 2
# 13                 en                               Hunting Games
# ..                ...                                         ...
# 329                ja                僕のヒーローアカデミア THE MOVIE ユアネクスト
# 330                en                    Hellboy: The Crooked Man
# 331                en                             The Silent Hour
# 332                en                              Blood for Dust
# 333                ko                                         전,란
#
#                                               overview  popularity  \
# 0    Captain Jack Sparrow works his way out of a bl...     147.174
# 3    Gurus in the late Goryeo dynasty try to obtain...     119.500
# 7    A sexy squad of female ninja assassins is hire...     126.593
# 9    After settling in Green Hills, Sonic is eager ...     172.833
# 13   When a group of ex-military members is hired t...     174.667
# ..                                                 ...         ...
# 329  In a society devastated by the effects of an a...     899.321
# 330  Hellboy and a rookie BPRD agent get stranded i...     807.058
# 331  While working a case as an interpreter, a hear...     756.861
# 332  Reckless Ricky makes serious money dealing ill...     563.575
# 333  In the Joseon Dynasty, two friends who grew up...     569.175
#
#                           poster_path release_date  \
# 0    /uXEqmloGyP7UXAiphJUu2v2pcuE.jpg   2006-07-06
# 3    /8QVDXDiOGHRcAD4oM6MXjE0osSj.jpg   2022-07-20
# 7    /h6KMd51SposSrVIhTpN8bmjhDnc.jpg   2011-06-04
# 9     /6DrHO1jr3qVrViUO6s6kFiAGM7.jpg   2022-03-30
# 13   /xVbEJzdMxIQqpuLgla0hU8qr9mt.jpg   2023-05-12
# ..                                ...          ...
# 329  /8rdB1wkheEMMqcY8qLAKjCMPcnZ.jpg   2024-08-02
# 330  /iz2GabtToVB05gLTVSH7ZvFtsMM.jpg   2024-08-29
# 331  /j736cRzBtEPCm0nHnpRN1prqiqj.jpg   2024-10-03
# 332  /nvaCnkl8RilLhVAQXPFei0tqkqW.jpg   2024-04-19
# 333  /hg9OeaCRSpazrfqYyEFr6BDaZW8.jpg   2024-10-02
#
#                                           title  video  vote_average  \
# 0    Pirates of the Caribbean: Dead Man's Chest  False         7.400
# 3                                      Alienoid  False         6.829
# 7           Lady Ninja: Reflections of Darkness  False         2.000
# 9                          Sonic the Hedgehog 2  False         7.500
# 13                                Hunting Games  False         4.200
# ..                                          ...    ...           ...
# 329               My Hero Academia: You're Next  False         7.096
# 330                    Hellboy: The Crooked Man  False         5.200
# 331                             The Silent Hour  False         6.400
# 332                              Blood for Dust  False         5.800
# 333                                    Uprising  False         7.400
#
#      vote_count
# 0         15813
# 3           419
# 7             3
# 9          4935
# 13           16
# ..          ...
# 329          26
# 330         161
# 331          33
# 332          43
# 333          71
#
# [99 rows x 14 columns]

# %%
print(len(action), len(romance))
action = action[:100]
romance = romance[:100]
# Out:
# 99 101

# %%
print(len(action), len(romance))
# Out:
# 99 100

# %%
action.head()
# Out:
#     adult                     backdrop_path genre_ids       id  \
# 0   False  /vr6n6ZFUZvedvIlhfYcbCWcaKyW.jpg        12       58
# 3   False  /7ZP8HtgOIDaBs12krXgUIygqEsy.jpg       878   601796
# 7   False  /er3zBubUy2Mhpu4WHInNWSjUzh7.jpg        28   173083
# 9   False  /8wwXPG22aNMpPGuXnfm3galoxbI.jpg        28   675353
# 13  False  /x2thJwMJ6oGlhn7UC4vSwHltEw0.jpg        28  1115396
#
#    original_language                              original_title  \
# 0                 en  Pirates of the Caribbean: Dead Man's Chest
# 3                 ko                                     외계+인 1부
# 7                 ja                                  くノ一忍法帖 影ノ月
# 9                 en                        Sonic the Hedgehog 2
# 13                en                               Hunting Games
#
#                                              overview  popularity  \
# 0   Captain Jack Sparrow works his way out of a bl...     147.174
# 3   Gurus in the late Goryeo dynasty try to obtain...     119.500
# 7   A sexy squad of female ninja assassins is hire...     126.593
# 9   After settling in Green Hills, Sonic is eager ...     172.833
# 13  When a group of ex-military members is hired t...     174.667
#
#                          poster_path release_date  \
# 0   /uXEqmloGyP7UXAiphJUu2v2pcuE.jpg   2006-07-06
# 3   /8QVDXDiOGHRcAD4oM6MXjE0osSj.jpg   2022-07-20
# 7   /h6KMd51SposSrVIhTpN8bmjhDnc.jpg   2011-06-04
# 9    /6DrHO1jr3qVrViUO6s6kFiAGM7.jpg   2022-03-30
# 13  /xVbEJzdMxIQqpuLgla0hU8qr9mt.jpg   2023-05-12
#
#                                          title  video  vote_average  \
# 0   Pirates of the Caribbean: Dead Man's Chest  False         7.400
# 3                                     Alienoid  False         6.829
# 7          Lady Ninja: Reflections of Darkness  False         2.000
# 9                         Sonic the Hedgehog 2  False         7.500
# 13                               Hunting Games  False         4.200
#
#     vote_count
# 0        15813
# 3          419
# 7            3
# 9         4935
# 13          16
