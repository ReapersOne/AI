# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
# This is the Now Playing Endpoint
url = "https://api.themoviedb.org/3/movie/now_playing?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
now = pd.DataFrame(response["results"])
now.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 2  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
# 3  False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg          [27, 53]  1034541
# 4  False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg     [28, 878, 12]   912649
#
#   original_language         original_title  \
# 0                en         The Wild Robot
# 1                en          The Substance
# 2                en                 Azrael
# 3                en            Terrifier 3
# 4                en  Venom: The Last Dance
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  Have you ever dreamt of a better version of yo...    3159.484
# 2  In a world where no one speaks, a devout femal...    1635.458
# ...

# %%
# Popular

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
pop = pd.DataFrame(response["results"])
pop.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /9SSEUrSqhljBMzRe4aBTh17rUaC.jpg         [878, 27]   945961
# 2  False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg     [27, 18, 878]   933260
# 3  False  /yDHYTfA3R0jFYba16jBB1ef8oIt.jpg     [28, 35, 878]   533535
# 4  False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg      [28, 27, 53]  1029235
#
#   original_language        original_title  \
# 0                en        The Wild Robot
# 1                en        Alien: Romulus
# 2                en         The Substance
# 3                en  Deadpool & Wolverine
# 4                en                Azrael
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  While scavenging the deep ends of a derelict s...    3904.571
# 2  A fading celebrity decides to usea black marke...    3159.484
# ...

# %%
# Top Rated

url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
top = pd.DataFrame(response["results"])

# %%
# Upcoming
url = "https://api.themoviedb.org/3/movie/upcoming?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3ZThiZDYxZmY3N2EzYTVmYmQ4ZWNhNGQwN2Q3YjlhZSIsIm5iZiI6MTcyNzk3MTE1Ny44NTE1NDgsInN1YiI6IjY2ZmViZTA1MTU5MmVmMWJhOTg0ZTg0MyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.qvYMQmK-V2G_Dx2FCbhsMCMoTn4hvF6B-tZs_wmQgoY"
}

response = requests.get(url, headers=headers)
response = response.json()
up = pd.DataFrame(response["results"])

# %%
df = pd.concat([now, pop, top, up])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              80 non-null     bool
#  1   backdrop_path      80 non-null     object
#  2   genre_ids          80 non-null     object
#  3   id                 80 non-null     int64
#  4   original_language  80 non-null     object
#  5   original_title     80 non-null     object
#  6   overview           80 non-null     object
#  7   popularity         80 non-null     float64
#  8   poster_path        80 non-null     object
#  9   release_date       80 non-null     object
#  10  title              80 non-null     object
#  11  video              80 non-null     bool
#  12  vote_average       80 non-null     float64
#  13  vote_count         80 non-null     int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 8.3+ KB

# %%
df.drop_duplicates(subset='original_title')
# Out:
#     adult                     backdrop_path                    genre_ids  \
# 0   False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg             [16, 878, 10751]
# 1   False  /7h6TqPB3ESmjuVbxCxAeB1c9OB1.jpg                [27, 18, 878]
# 2   False  /4KHEK6AQFHhv4TDtL3KLReePB05.jpg                 [28, 27, 53]
# 3   False  /eQEgKIRF7KeVGBQ8IYcklpU8RPf.jpg                     [27, 53]
# 4   False  /3V4kLQg0kSqPLctI5ziYWabAZYF.jpg                [28, 878, 12]
# 5   False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg                 [35, 14, 27]
# 6   False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg                 [14, 27, 28]
# 7   False  /3m0j3hCS8kMAaP9El6Vy5Lqnyft.jpg            [878, 53, 27, 18]
# 8   False  /64tinBsds1nVp4wOCgYhMbSgsRW.jpg                 [28, 18, 36]
# 9   False  /of1tQasFGCeHgWPmSgdA1WS6hNW.jpg                 [80, 53, 28]
# 10  False  /reNf6GBzOe48l9WEnFOxXgW56Vg.jpg                 [18, 80, 53]
# 11  False   /l8OyAXEp5FKZWmDhqJMbiwAEvz.jpg                     [27, 18]
# ...

# %%
df.loc[5]
# Out:
#    adult                     backdrop_path                genre_ids       id  \
# 5  False  /xi1VSt3DtkevUmzCx2mNlCoDe74.jpg             [35, 14, 27]   917496
# 5  False  /p5ozvmdgsmbWe0H8Xk7Rc8SCwAB.jpg  [16, 10751, 12, 35, 18]  1022789
# 5  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg                     [18]      389
# 5  False  /of1tQasFGCeHgWPmSgdA1WS6hNW.jpg             [80, 53, 28]  1047373
#
#   original_language           original_title  \
# 5                en  Beetlejuice Beetlejuice
# 5                en             Inside Out 2
# 5                en             12 Angry Men
# 5                en          The Silent Hour
#
#                                             overview  popularity  \
# 5  After a family tragedy, three generations of t...    1352.254
# 5  Teenager Riley's mind headquarters is undergoi...    1847.374
# 5  The defense and the prosecution have rested an...      59.426
# 5  While working a case as an interpreter, a hear...     808.001
#
# ...

# %%
def get_revenue_budget(df):
    '''
    Uses the movie id to get data from the "Details" endpoint
    returns a dataframe of revenue and budget data
    '''
    data = {
        "id":[],
        "budget": [],
        "revenue": []
    }

    for i in df["id"]:
        data["id"].append(i)
        url = "https://api.themoviedb.org/3/movie/"+str(i)+"?language=en-US"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
        }

        response = requests.get(url, headers=headers)
        response = response.json()
        data["budget"].append(response["budget"])
        data["revenue"].append(response["revenue"])
        
    return pd.DataFrame(data)

# %%
money_df = get_revenue_budget(df)

# %%
money_df
# Out:
#          id     budget    revenue
# 0   1184918   78000000  197296880
# 1    933260   17500000   29106531
# 2   1029235   12000000          0
# 3   1034541    2000000   41643487
# 4    912649  110000000          0
# ..      ...        ...        ...
# 75  1062215   12000000   12567788
# 76   826510   40000000   24982787
# 77  1225377     800000       5737
# 78   558449  310000000          0
# 79   832964          0    6870131
#
# [80 rows x 3 columns]

# %%
df = pd.merge(df, money_df, how="inner", on="id")

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 2  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 3  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 4  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
#
#   original_language  original_title  \
# 0                en  The Wild Robot
# 1                en  The Wild Robot
# 2                en  The Wild Robot
# 3                en  The Wild Robot
# 4                en  The Wild Robot
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  After a shipwreck, an intelligent robot called...    5200.959
# 2  After a shipwreck, an intelligent robot called...    5200.959
# ...

# %%
sns.regplot(data=df, x="budget", y="revenue")
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>

# %%
df['revenue_sqrt'] = np.sqrt(df['revenue'])
df['budget_sqrt'] = np.sqrt(df['budget'])

# %%
df.head()
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 1  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 2  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 3  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
# 4  False  /417tYZ4XUyJrtyZXj7HpvWf1E8f.jpg  [16, 878, 10751]  1184918
#
#   original_language  original_title  \
# 0                en  The Wild Robot
# 1                en  The Wild Robot
# 2                en  The Wild Robot
# 3                en  The Wild Robot
# 4                en  The Wild Robot
#
#                                             overview  popularity  \
# 0  After a shipwreck, an intelligent robot called...    5200.959
# 1  After a shipwreck, an intelligent robot called...    5200.959
# 2  After a shipwreck, an intelligent robot called...    5200.959
# ...

# %%
def get_best_fit(data, x, y):
    '''
    Determines the slope (m) and intercept (b) of the best fit line
    for two variables, x and y.
    '''
    m = 0
    for count in range(100):
        m = m + 1
        b = 0

        # Calculate residuals (y = mx+b)
        res = 0
        for i in range(len(data)):
            pred_y = (m * data.loc[i][x]) + b
            act_y = data.loc[i][y]
            temp = act_y - pred_y 
            temp = temp ** 2
            res = res + temp
        print(res)
    return (m, b, res)

# %%
get_best_fit(df, "budget_sqrt", "revenue_sqrt")
# Out:
# 7748035334.421312
# 8643241469.842623
# 19979799107.263935
# 41757708246.68521
# 73976968888.10658
# 116637581031.52792
# 169739544676.94913
# 233282859824.37024
# 307267526473.79156
# 391693544625.21277
# 486560914278.63446
# 591869635434.0563
# 707619708091.4769
# 833811132250.8984
# 970443907912.3192
# 1117518035075.7417
# 1275033513741.1614
# 1442990343908.583
# 1621388525578.0054
# 1810228058749.4263
# 2009508943422.8481
# 2219231179598.2686
# 2439394767275.6904
# 2669999706455.1104
# 2911045997136.535
# 3162533639319.953
# 3424462633005.3765
# 3696832978192.7935
# 3979644674882.2173
# 4272897723073.6406
# 4576592122767.06
# 4890727873962.48
# 5215304976659.9
# 5550323430859.33
# 5895783236560.743
# 6251684393764.168
# 6618026902469.584
# 6994810762677.013
# 7382035974386.432
# 7779702537597.847
# 8187810452311.277
# 8606359718526.693
# 9035350336244.11
# 9474782305463.531
# 9924655626184.959
# 10384970298408.377
# 10855726322133.807
# 11336923697361.227
# 11828562424090.656
# ...

# %%
get_best_fit(df, "budget_sqrt", "revenue_sqrt")
# Out:
# 7748035334.421312
# 8643241469.842623
# 19979799107.263935
# 41757708246.68521
# 73976968888.10658
# 116637581031.52792
# 169739544676.94913
# 233282859824.37024
# 307267526473.79156
# 391693544625.21277
# 486560914278.63446
# 591869635434.0563
# 707619708091.4769
# 833811132250.8984
# 970443907912.3192
# 1117518035075.7417
# 1275033513741.1614
# 1442990343908.583
# 1621388525578.0054
# 1810228058749.4263
# 2009508943422.8481
# 2219231179598.2686
# 2439394767275.6904
# 2669999706455.1104
# 2911045997136.535
# 3162533639319.953
# 3424462633005.3765
# 3696832978192.7935
# 3979644674882.2173
# 4272897723073.6406
# 4576592122767.06
# 4890727873962.48
# 5215304976659.9
# 5550323430859.33
# 5895783236560.743
# 6251684393764.168
# 6618026902469.584
# 6994810762677.013
# 7382035974386.432
# 7779702537597.847
# 8187810452311.277
# 8606359718526.693
# 9035350336244.11
# 9474782305463.531
# 9924655626184.959
# 10384970298408.377
# 10855726322133.807
# 11336923697361.227
# 11828562424090.656
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              146 non-null    bool
#  1   backdrop_path      146 non-null    object
#  2   genre_ids          146 non-null    object
#  3   id                 146 non-null    int64
#  4   original_language  146 non-null    object
#  5   original_title     146 non-null    object
#  6   overview           146 non-null    object
#  7   popularity         146 non-null    float64
#  8   poster_path        146 non-null    object
#  9   release_date       146 non-null    object
#  10  title              146 non-null    object
#  11  video              146 non-null    bool
#  12  vote_average       146 non-null    float64
#  13  vote_count         146 non-null    int64
#  14  budget             146 non-null    int64
#  15  revenue            146 non-null    int64
# ...

# %%
def calculate_r_squared(x, y):
    mean_y = sum(y) / len(y)

    sst = sum((yi - mean_y) ** 2 for yi in y)

    n = len(x)
    numerator = sum((x[i] - (sum(x) / n)) * (y[i] - mean_y) for i in range(n))
    denominator = sum((x[i] - (sum(x) / n)) ** 2 for i in range(n))

    m = numerator / denominator  # Slope
    b = mean_y - m * (sum(x) / n)  # Intercept

    predictions = [m * xi + b for xi in x]
    ssr = sum((y[i] - predictions[i]) ** 2 for i in range(n))

    r_squared = 1 - (ssr / sst) if sst != 0 else 0

    return r_squared

x = df['budget']
y = df['popularity']

r_squared = calculate_r_squared(x, y)
print("Coefficient of Determination (R²):", r_squared)
print("The Percentage of R² is: ", r_squared*100)
# Out:
# Coefficient of Determination (R²): 0.09684596888836006
# The Percentage of R² is:  9.684596888836005

# %% [markdown]
# # Is the Coefficient of Determination good for Popularity Score and the Budget?
#
# #### To sum it up, no. It is not good because it only represents 5% of the total Dataset we are looking at, and with the variables, they don't represent a big sum between Popularity Score and Budget.

# %%
# Popular 
action = []
romance = []
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
}
response = requests.get(url, headers=headers)
response = response.json()["results"]
for i in range(len(response)):
    genres = response[i]["genre_ids"]
    if 28 in genres and 10749 in genres:
        action.append(response[i])
        romance.append(response[i])
    elif 28 in genres:
        action.append(response[i])
    elif 10749 in genres:
        romance.append(response[i])
action = pd.DataFrame(action)
romance = pd.DataFrame(romance)

# %%
print(len(action), len(romance))
# Out:
# 9 1

# %%
page = 2
while len(action) < 100 or len(romance) < 100:
    url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=" + str(page)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4Nzk4M2ZiZTk3Njk4OGE5ZTIyMzMwZWJmMDMwYTFhZSIsIm5iZiI6MTcyNzk3MTk0OS45MTA1MjcsInN1YiI6IjYzNzQyNGMyNDZlNzVmMDA5MGE3YmRhYyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.ZsTpMVaVlF8ioN3-WiYEatqWmnGQhCKlILQv4Xi6Eec"
    }
    response = requests.get(url, headers=headers)
    response = response.json()["results"]
    page += 1
    for i in range(len(response)):
        genres = response[i]["genre_ids"]
        temp = pd.DataFrame(response[i])
        if 28 in genres:
            action = pd.concat([temp, action], ignore_index=True)
        if 10749 in genres:
            romance = pd.concat([temp, romance], ignore_index=True)

# %%
action = action.drop_duplicates(subset=['id'])
action
# Out:
#      adult                     backdrop_path     genre_ids       id  \
# 0    False  /wPNI1fd18z5TKBOK9Mv9Rfjb0j0.jpg            53   729165
# 4    False  /vwwHt1hNvPpAUEFW6YHdhy9jJmY.jpg            28  1085046
# 9    False  /kdbLf3aTQsEXqYlH9vA4fzmnSFz.jpg         10752   228150
# 12   False  /vblTCXOWUQGSc837vgbhDRi4HSc.jpg            28   955555
# 16   False  /aA5B2OsN6rccwnhn8TEG4m4V3jI.jpg            80  1059064
# ..     ...                               ...           ...      ...
# 352  False  /g1z1ZvYKcmk9EnVOTYXR6vkNjkZ.jpg  [14, 27, 28]  1087822
# 353  False  /bkENfmxUY3UYsRLizJAhF5IQPvS.jpg  [28, 80, 53]  1025596
# 354  False  /64tinBsds1nVp4wOCgYhMbSgsRW.jpg  [28, 18, 36]  1075676
# 355  False  /of1tQasFGCeHgWPmSgdA1WS6hNW.jpg  [80, 53, 28]  1047373
# 356  False  /tCKWksaQI8XkAQLVou0AlGab5S6.jpg     [28, 878]  1144962
#
#     original_language              original_title  \
# 0                  en                Out of Exile
# ...

# %%
print(len(action), len(romance))
action = action[:100]
romance = romance[:100]
# Out:
# 114 102

# %%
print(len(action), len(romance))
# Out:
# 100 100

# %%
action.head()
# Out:
#     adult                     backdrop_path genre_ids       id  \
# 0   False  /wPNI1fd18z5TKBOK9Mv9Rfjb0j0.jpg        53   729165
# 4   False  /vwwHt1hNvPpAUEFW6YHdhy9jJmY.jpg        28  1085046
# 9   False  /kdbLf3aTQsEXqYlH9vA4fzmnSFz.jpg     10752   228150
# 12  False  /vblTCXOWUQGSc837vgbhDRi4HSc.jpg        28   955555
# 16  False  /aA5B2OsN6rccwnhn8TEG4m4V3jI.jpg        80  1059064
#
#    original_language   original_title  \
# 0                 en     Out of Exile
# 4                 zh      超级英雄美猴王：齐天儿
# 9                 en             Fury
# 12                ko           범죄도시 3
# 16                en  The Instigators
#
#                                              overview  popularity  \
# 0   Recently paroled thief Gabriel Russell tries t...      98.173
# 4   Shimmy, a monkey newly discover superhero powe...     161.538
# 9   In the last months of World War II, as the All...     107.137
# 12  Detective Ma Seok-do changes his affiliation f...     120.781
# ...
